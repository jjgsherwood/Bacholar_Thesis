# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
cross_X = [[457.5, 239.6],
           [230.5, 114.9],
           [620.5, 145.2]]

cross_Y = [[47.9, 23.3],
           [40.5, 32.7],
           [106.7, 65.9]]

cross_Z = [[50.2, 14.0],
           [41.9, 10.8],
           [43.9, 21.1]]

val_X = [[2465, 234],
         [920, 0],
         [719, 205]]

val_Y = [[427.5, 0],
         [412, 0],
         [192, 20.4]]

val_Z = [[98.1, 0],
         [40.5, 0],
         [71.6, 10.6]]

# %%
X = [r"$PCA $",
     r"$NMF_3 $",
     r"$AE_3 $",
     r"$PCA$",
     r"$NMF_3$",
     r"$AE_3$",
     r"$ PCA$",
     r"$ NMF_3$",
     r"$ AE_3$"]

val = np.vstack((val_X, val_Y, val_Z))
Cross = np.vstack((cross_X, cross_Y, cross_Z))

# %%
plt.figure(dpi=800, figsize=(4,4))
plt.errorbar(X, val[:,0], val[:,1], linestyle='None', marker='.', ecolor='r', capsize=5)
plt.grid(b=None, which='both', axis='y')
plt.ylabel(r"$\Delta$ (-)")
plt.yscale("log")
ax = plt.gca()
ax.set_ylim([10,3500])
plt.show()
