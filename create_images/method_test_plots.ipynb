# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Alina4 = [[39.7, 0.0],
          [39.7, 0.0], 
          [57.6, 0.0], 
          [32.7, 0.0], 
          [43.0, 2.3], 
          [103.8, 1.0], 
          [29.0, 2.2]]

Alina2 = [[37.5, 0.0],
          [37.5, 0.0],
          [303.8, 0.0],
          [28.7, 0.0],
          [35.7, 0.2],
          [216.1, 28.1],
          [71.1, 7.7]]

Alina1 = [[354.4, 0.3],
          [354.4, 0.3],
          [761.1, 0.0],
          [162.5, 0.0],
          [331.0, 9.4],
          [1343.3, 132.9],
          [423.6, 75.8]]

time = [6.21, 1.58, 5.29, 5.29, 119.9, 122.0,132.2]
# time = [6.21, 1.58, 5.29, 5.29, 39.9, 42.0,0]

Alina4 = np.array(Alina4)
Alina2 = np.array(Alina2)
Alina1 = np.array(Alina1)

# %%
X = [r"$NFS$",
     r"$PCA$",
     r"$NMF_2$",
     r"$NMF_3$",
     r"$AE_1$",
     r"$AE_2$",
     r"$AE_3$"]

# %%
plt.figure(dpi=800, figsize=(4,4))
plt.errorbar(X, Alina4[:,0], Alina4[:,1], linestyle='None', marker='.', ecolor='r', capsize=5)
plt.grid(b=None, which='major', axis='y')
plt.ylabel(r"$\Delta$ (-)")
plt.show()

# %%
plt.figure(dpi=800, figsize=(4,4))
plt.plot(X, time, 'sr')
plt.grid(b=None, which='both', axis='y')
plt.ylabel("time (sec)")
plt.yscale("log")
ax = plt.gca()
ax.set_ylim([1,210])
plt.show()
