# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from pylab import rcParams
rcParams['figure.figsize'] = 10, 8
rcParams['figure.dpi'] = 300

import torch
from torch import nn
from torch import distributions
from torch.nn.parameter import Parameter

from sklearn import cluster, datasets, mixture
from sklearn.preprocessing import StandardScaler

# %%
class RealNVP(nn.Module):
    def __init__(self, nets, nett, mask, prior):
        super().__init__()
        
        self.prior = prior
        self.mask = nn.Parameter(mask, requires_grad=False)
        self.t = torch.nn.ModuleList([nett() for _ in range(len(masks))])
        self.s = torch.nn.ModuleList([nets() for _ in range(len(masks))])
        
    def f(self, x):
        log_det_J = x.new_zeros(x.shape[0])
        for translate, scale, mask in zip(self.t, self.s, self.mask):
            x1 = y1 = x * mask
            x2 = x * (1 - mask)
            s = scale(x1) * (1 - mask)
            t = translate(x1) * (1 - mask)
            y2 = x2 * torch.exp(s) + t
            x = y1 + y2
            log_det_J += s.sum(dim=1)
        y = x
        return y, log_det_J

    def g(self, y):
        for translate, scale, mask in zip(reversed(self.t), reversed(self.s), reversed(self.mask)):
            y1 = x1 = y * mask
            y2 = y * (1 - mask)
            s = scale(y1) * (1 - mask)
            t = translate(y1) * (1 - mask)
            x2 = (y2 - t) * torch.exp(-s)
            y = x1 + x2
        x = y
        return x
    
    def log_prob(self, x):
        y, logp = self.f(x)
        return self.prior.log_prob(y) + logp
        
    def sample(self, batchSize): 
        y = self.prior.sample((batchSize, 1))
        x = self.g(y)
        return x

# %%
nets = lambda: nn.Sequential(nn.Linear(2, 256), nn.LeakyReLU(), nn.Linear(256, 256), nn.LeakyReLU(), nn.Linear(256, 2), nn.Sigmoid())
"""
nets (net scale)
nets nodes: 2 input nodes, 256 hidden nodes, 256 hidden nodes, 2 output nodes
activations are Relu and last Tanh, (why Tanh?)
"""
nett = lambda: nn.Sequential(nn.Linear(2, 256), nn.LeakyReLU(), nn.Linear(256, 256), nn.LeakyReLU(), nn.Linear(256, 2))
"""
nett (net translation)
nett nodes: 2 input nodes, 256 hidden nodes, 256 hidden nodes, 2 output nodes
activations are Relu and no end activation. (why is this translation?)
"""
masks = torch.from_numpy(np.array([[0, 1], [1, 0]] * 3).astype(np.float32)) #6 coupling layers alternating
prior = distributions.MultivariateNormal(torch.zeros(2), torch.eye(2)) #2D gaussian no correlation
flow = RealNVP(nets, nett, masks, prior)

# %%
optimizer = torch.optim.Adam([p for p in flow.parameters() if p.requires_grad==True], lr=1e-4)
for t in range(5001):    
    noisy_moons = datasets.make_moons(n_samples=100, noise=.05)[0].astype(np.float32)
    loss = -flow.log_prob(torch.from_numpy(noisy_moons)).mean()
    optimizer.zero_grad()
    loss.backward(retain_graph=True)
    optimizer.step()
    
    if t % 500 == 0:
        print('iter %s:' % t, 'loss = %.3f' % loss)
# Out:
# torch.Size([100, 2])
# torch.Size([])
# tensor(11.2149, grad_fn=<NegBackward>)
# iter 0: loss = 11.215
# torch.Size([100, 2])
# torch.Size([])
# tensor(10.2157, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(9.5607, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(8.9064, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(8.1306, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(7.7153, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(7.2012, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(6.7310, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(6.3400, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(6.1092, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(5.8827, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(5.6711, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(5.4705, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(5.1945, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.9107, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.9224, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.7079, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.5954, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.5613, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.3271, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.1909, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.1236, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(4.0280, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.9986, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.7892, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.7709, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.6458, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.5307, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.4882, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.4632, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.3110, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.1968, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.1915, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.1718, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(3.1066, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.9720, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.8841, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.9083, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.8148, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.7340, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.7054, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.6753, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.6725, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.5384, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.5648, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.5658, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.4611, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.4539, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.4252, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.3565, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.3362, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.3569, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.2780, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.3051, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.1868, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.2510, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.2252, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.2143, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.1931, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.1524, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.1844, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.1650, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0800, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0651, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0424, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0309, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0615, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0213, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0432, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0001, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0382, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9950, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9747, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9484, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9592, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9709, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(2.0123, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9465, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9212, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9676, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9296, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9142, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9214, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9002, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9276, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.9039, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8997, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8909, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8784, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8686, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8840, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8387, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8729, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8240, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8582, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8511, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8970, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8302, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8078, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8670, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8006, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8212, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8283, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8276, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8238, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8251, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8083, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8144, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8094, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8030, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8117, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8296, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7906, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8092, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7953, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8047, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7964, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.8014, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7964, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7745, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7793, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7890, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7625, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7800, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7716, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7586, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7676, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7694, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7569, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7744, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7648, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7463, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7505, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7376, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7455, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7495, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7543, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7231, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7299, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7304, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7238, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7305, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7307, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7361, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7600, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7248, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7553, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7283, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7305, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7136, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7342, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7149, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7239, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7178, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7163, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7298, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7304, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7131, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7010, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7472, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7258, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7029, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7026, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7079, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7074, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7036, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.7166, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6797, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6643, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6890, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6622, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6758, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6704, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6777, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6824, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6652, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6530, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6637, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6667, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6592, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6796, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6787, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6580, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6380, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6688, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6335, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6456, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6145, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6463, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6449, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6372, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6353, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6396, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6231, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6241, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6505, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6593, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5902, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6212, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5991, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6020, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6013, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6015, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6422, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5913, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5960, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6174, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6085, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5884, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.6178, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5839, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5986, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5740, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5732, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5688, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5672, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5475, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5726, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5900, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5749, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5833, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5740, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5516, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5742, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5242, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5424, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5344, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5101, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5465, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5034, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5041, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5285, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5038, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5353, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5146, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5224, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5124, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5049, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4620, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4855, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5077, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4885, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4607, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4729, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4845, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.5062, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4520, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4428, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4712, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4552, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4248, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4409, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4296, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4679, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4466, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4041, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4123, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4662, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4457, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4535, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4322, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4238, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4853, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4106, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3867, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4598, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3939, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4029, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3625, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4078, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3711, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3927, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3701, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3974, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.4040, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3333, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3739, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3722, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3934, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3896, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3559, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3760, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3205, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3403, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3314, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3469, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3774, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3741, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2993, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3531, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3303, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3264, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2908, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2813, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3236, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2691, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2897, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3179, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3250, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2985, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3271, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3251, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3402, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2772, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3128, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2796, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3525, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2996, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2912, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2902, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3145, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2772, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2954, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3288, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2366, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2791, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2578, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2976, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2874, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2848, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2547, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2677, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2483, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2573, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2680, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2510, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2388, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2249, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1780, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2194, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.3014, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2231, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2096, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1945, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1775, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2311, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1518, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1796, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1295, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1959, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2466, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1701, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2586, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1822, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1587, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2600, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1954, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1931, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1989, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1680, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1851, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1594, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1260, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1487, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1475, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1221, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0793, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2024, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1085, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1576, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0943, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1290, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1710, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0760, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1141, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1243, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1717, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1064, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1939, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1077, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0949, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0769, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0682, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0694, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1706, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0952, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1161, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0931, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1062, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0635, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0346, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0449, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1617, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1553, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1154, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1232, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0295, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0992, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0540, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0102, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0772, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0382, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0758, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0497, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0427, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9962, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0175, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0802, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0058, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0242, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0172, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0939, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9895, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0733, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0056, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0046, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9290, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9920, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0562, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9363, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.1003, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0347, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9557, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9956, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0096, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9536, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9728, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9679, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9652, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9653, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9648, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9560, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9144, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9266, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0430, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0265, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0373, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0653, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.2272, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9919, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9655, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9420, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9543, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9431, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9962, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0308, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0104, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9600, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9284, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9578, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9608, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0507, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9372, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.8378, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9479, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0252, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0135, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9291, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9172, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.8882, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0223, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9261, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(1.0005, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9129, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.9562, grad_fn=<NegBackward>)
# torch.Size([100, 2])
# torch.Size([])
# tensor(0.8730, grad_fn=<NegBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a1add293e091> in <module>
#       6     print(loss)
#       7     optimizer.zero_grad()
# ----> 8     loss.backward(retain_graph=True)
#       9     optimizer.step()
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
noisy_moons = datasets.make_moons(n_samples=1000, noise=.05)[0].astype(np.float32)
z = flow.f(torch.from_numpy(noisy_moons))[0].detach().numpy()
plt.subplot(221)
plt.scatter(z[:, 0], z[:, 1])
plt.title(r'$z = f(X)$')

z = np.random.multivariate_normal(np.zeros(2), np.eye(2), 1000)
plt.subplot(222)
plt.scatter(z[:, 0], z[:, 1])
plt.title(r'$z \sim p(z)$')

plt.subplot(223)
x = datasets.make_moons(n_samples=1000, noise=.05)[0].astype(np.float32)
plt.scatter(x[:, 0], x[:, 1], c='r')
plt.title(r'$X \sim p(X)$')

plt.subplot(224)
x = flow.sample(1000).detach().numpy()
plt.scatter(x[:, 0, 0], x[:, 0, 1], c='r')
plt.title(r'$X = g(z)$')
# Out:
# torch.Size([1000, 1, 2])
# tensor([[[-0.0049, -0.6277]],
#
#         [[ 0.2162,  0.1855]],
#
#         [[-0.3755, -0.1670]],
#
#         ...,
#
#         [[-1.9406,  0.0808]],
#
#         [[ 1.1365, -0.4996]],
#
#         [[ 0.9104,  0.4168]]])
# Text(0.5, 1.0, '$X = g(z)$')

# %%
print(prior)
# Out:
# MultivariateNormal(loc: torch.Size([2]), covariance_matrix: torch.Size([2, 2]))
