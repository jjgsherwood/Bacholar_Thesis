# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# file = 'Alina_Art_Blue_Paint_PL.txt'
file = 'Alina_Art_Green_Paint_PLnm.txt'
# file = 'Alina_Art_WhitePaint.txt'
df = pd.read_csv('../../data/Raman/raw/' + file, delimiter='\t', skipinitialspace=True, header=None)

# %%
plt.figure(figsize = (7,4), dpi=500)
plt.plot(df[0], df[1])

# %%
# np.save(f'../data/Raman/red2.npy', df[1].values)
# Out:
# 0         80.1872
# 1         81.0068
# 2         81.8264
# 3         82.6458
# 4         83.4661
#           ...
# 3162    2211.1700
# 3163    2211.7300
# 3164    2212.2800
# 3165    2212.8400
# 3166    2213.0500
# Name: 0, Length: 3167, dtype: float64

# %%
# np.save(f'../data/Raman/wavelength.npy', df[0].values)

# %%
wavelength = np.load("../data/Raman/wavelength.npy", 'r')

files = ['blue0', 'blue1', 'blue2', 'blue3', 'blue4',
         'green0', 'green1', 'green2',
         'red0', 'red1', 'red2']

ref_vectors = {}
for file in files:
    ref_vectors[file] = np.load(f"../data/Raman/{file}.npy", 'r')

# %%
plt.figure(figsize = (20,12))
for key, value in ref_vectors.items():
    if 'blue' in key:
        plt.plot(wavelength, value, label=key)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,12))
for key, value in ref_vectors.items():
    if 'red' in key:
        plt.plot(wavelength, value, label=key)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20,12))
for key, value in ref_vectors.items():
    if 'green' in key:
        plt.plot(wavelength, value, label=key)
plt.legend()
plt.show()
