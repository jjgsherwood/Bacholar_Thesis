# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_array, check_is_fitted

import numpy as np
import matplotlib.pyplot as plt
import os
import copy
import inspect
import random
import shutil

from datetime import datetime
from dateutil.relativedelta import relativedelta

from scipy import optimize
from sklearn import decomposition, cluster, model_selection, metrics
import sklearn

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import utils.dataset_utils as dataset
import utils.train_utils as train

# %%
def unit_vector_norm(X):
    X -= X.min() #remove noise offset
    return (X.T / np.sqrt((X**2).sum(axis=1))).T

class View(nn.Module):
    def __init__(self, shape):
        super().__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)

# %%
X = np.load("../data/HSI/Liver_map_150z25_60s_1TCPOBOP.npy", 'r')
Y = np.load("../data/HSI/Liver_map_150z25_60s_2TCPOBOP.npy", 'r')
Z = np.load("../data/HSI/Liver_map_150z25_60s_3OBOB.npy", 'r')
wavelength = np.load("../data/HSI/wavelength.npy", 'r')

shape_X = X.shape 
shape_Y = Y.shape 
shape_Z = Z.shape 

X = copy.copy(X.reshape(-1, X.shape[-1]))
Y = copy.copy(Y.reshape(-1, Y.shape[-1]))
Z = copy.copy(Z.reshape(-1, Z.shape[-1]))

# %%
class AutoEncoderConv(nn.Module):
    def __init__(self, n_components=10, d=1):
        super().__init__()
        h = 30
        self.encode = nn.Sequential( 
            nn.Dropout3d(0.25),
            nn.Flatten(),
            nn.Linear(1000, h),
            nn.ReLU(True),
            nn.Dropout3d(0.5),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),
            nn.Linear(h, n_components)
        )
        
        self.decode = nn.Sequential(
            nn.Linear(n_components, h),
            nn.ReLU(True),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),            
            nn.Linear(h, 1000),
            View((-1,1,1,1,1000))
        )
        
    def forward(self, x):
        return self.decode(self.encode(x))

# %%
def MSE_loss(x, model):
    x_ = model(x)
    return ((x - x_)**2).mean(0).sum()

# %%
class ReferenceVectorClassifierAE(BaseEstimator):
    def __init__(self, **kwargs):
        self.kwargs = {}
        self.k_means_kwargs = {}
        self.ae_kwargs = {}        
        self.set_params(**kwargs)

        _use_cuda = torch.cuda.is_available() and kwargs['cuda']
        if _use_cuda:
            torch.backends.cudnn.enabled = True
            torch.backends.cudnn.benchmark = True
        self.device = torch.device('cuda' if _use_cuda else 'cpu')        
        
    def fit(self, x, **kwargs):
        self.set_params(**kwargs)
        X = unit_vector_norm(x)
        
        ###################### Autoencoder ################################
        self.model = AutoEncoderConv(**self.ae_kwargs).to(self.device)
        
        parameters = filter(lambda x: x.requires_grad, self.model.parameters())
        self.optimizer = optim.Adam(parameters)        
        train_loader, test_loader = dataset.load_liver(X, self.kwargs['batch_size'])
        
        for epoch in range(self.kwargs['epochs']):
            print('-'*50)
            print('Epoch {:3d}/{:3d}'.format(epoch+1, self.kwargs['epochs']))
            start_time = datetime.now()
            train.train(self.model, self.optimizer, train_loader, self.kwargs['loss_func'], self.kwargs['log_step'], self.device)
            end_time = datetime.now()
            time_diff = relativedelta(end_time, start_time)
            print('Elapsed time: {}h {}m {}s'.format(time_diff.hours, time_diff.minutes, time_diff.seconds))
            loss = train.test(self.model, test_loader, self.kwargs['loss_func'], self.device)
            print('Validation| bits: {:2.2f}'.format(loss), flush=True)    
          
        self.model.eval()
        with torch.no_grad():
            z = self.model.encode(dataset.load_liver_all(X).to(self.device)).cpu()
              
        ###################### clustering ################################
        self.clusters = cluster.KMeans(**self.k_means_kwargs).fit(z)
        self.clusters = self.clusters.labels_
        
        one_hot = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        one_hot[range(X.shape[0]), self.clusters] = 1

        ###################### reference spectra ################################
        self.reference_spectra_ = np.array([X[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])
        self.ref_org = np.array([x[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])

        # Return the classifier
        return self

    def predict(self, X):
        """
        predict transforms the data into the reference space. Min weight should be 0 or higher then 'min_weight'
        The error is the NMSE, where the MSE is normalised by the signal strength. 
        error.shape = X.shape[0], so for each data point the error is calculated.
        """
        # Check is fit had been called
        check_is_fitted(self)

        # Input validation
        X = check_array(X)
        X = unit_vector_norm(X)
        
        ###################### RCA ################################
        old_mask = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        mask = np.ones((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        while np.abs(old_mask ^ mask).sum():
            RCA_vector = np.array([optimize.nnls(self.reference_spectra_.T * mask[i], X[i,:])[0] for i in range(X.shape[0])])
            old_mask, mask = mask, (RCA_vector.T / RCA_vector.sum(axis=1)).T >= self.kwargs['min_weight']            
        
        return RCA_vector  
    
    def get_reference_vectors(self):
        return self.reference_spectra_

    def get_org_reference_vectors(self):
        return self.ref_org    
    
    def get_params(self, deep=False):
        return self.kwargs
    
    def set_params(self, **kwargs):
        self.kwargs.update(kwargs)
        self.k_means_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(cluster.KMeans).parameters.keys())})     
        self.ae_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(AutoEncoderConv).parameters.keys())})     
        return self

# %%
def error_map(estimator, X, y=None):
    RCA = estimator.predict(X)
    ref_vec = estimator.get_reference_vectors()
    return ((RCA @ ref_vec - X)**2).mean(1)

def score_func(estimator, X, y=None):
    X = unit_vector_norm(X)
    return error_map(estimator, X).mean()

def print_mean_std(X):
    return f"{X.mean():<12.4e}{X.std():<12.4e}"

def cross_val_X_Y_Z(rvc, X, Y, Z):
    rvc.fit(np.concatenate((X, Y), axis=0))
    return score_func(rvc, Z)

# %%
kwargs = {'n_clusters': 3,
          'n_components': 5, #enough for PCA
          'min_weight': 0,
          'batch_size': 64,
          'cuda': True,
          'log_step': 10,
          'loss_func': MSE_loss,
          'epochs': 3,
          'd':1
         }

header = f"{'mean':12}{'std':12}"

# %%
rvc = ReferenceVectorClassifierAE(**kwargs)

repeat = 10
depths = [0,1,2] + list(range(3,16,2))
error = []
for d in depths:
    print('calculating for d: ',d)
    kwargs['d'] = d
    tmp = []
    for _ in range(repeat):
        while True:
            try:
                rvc.fit(X)
                tmp.append(score_func(rvc, X))
            except ValueError:
                pass
            else: 
                break        
    error.append(tmp)
error = np.array(error)
# Out:
# calculating for d:  0
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:33:01|     0/   52| bits: 26.72
#   2020-05-27 18:33:01|    10/   52| bits: 13.59
#   2020-05-27 18:33:01|    20/   52| bits: 8.20
#   2020-05-27 18:33:01|    30/   52| bits: 4.98
#   2020-05-27 18:33:01|    40/   52| bits: 2.78
#   2020-05-27 18:33:02|    50/   52| bits: 1.51
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.18
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:33:07|     0/   52| bits: 1.34
#   2020-05-27 18:33:07|    10/   52| bits: 0.71
#   2020-05-27 18:33:07|    20/   52| bits: 0.35
#   2020-05-27 18:33:07|    30/   52| bits: 0.19
#   2020-05-27 18:33:07|    40/   52| bits: 0.10
#   2020-05-27 18:33:07|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:33:13|     0/   52| bits: 0.05
#   2020-05-27 18:33:13|    10/   52| bits: 0.03
#   2020-05-27 18:33:13|    20/   52| bits: 0.02
#   2020-05-27 18:33:13|    30/   52| bits: 0.01
#   2020-05-27 18:33:13|    40/   52| bits: 0.01
#   2020-05-27 18:33:13|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:33:18|     0/   52| bits: 25.36
#   2020-05-27 18:33:18|    10/   52| bits: 14.30
#   2020-05-27 18:33:18|    20/   52| bits: 8.69
#   2020-05-27 18:33:18|    30/   52| bits: 5.10
#   2020-05-27 18:33:18|    40/   52| bits: 2.89
#   2020-05-27 18:33:18|    50/   52| bits: 1.52
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.20
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:33:22|     0/   52| bits: 1.33
#   2020-05-27 18:33:23|    10/   52| bits: 0.64
#   2020-05-27 18:33:23|    20/   52| bits: 0.29
#   2020-05-27 18:33:23|    30/   52| bits: 0.12
#   2020-05-27 18:33:23|    40/   52| bits: 0.06
#   2020-05-27 18:33:23|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:33:32|     0/   52| bits: 0.02
#   2020-05-27 18:33:32|    10/   52| bits: 0.02
#   2020-05-27 18:33:32|    20/   52| bits: 0.01
#   2020-05-27 18:33:32|    30/   52| bits: 0.01
#   2020-05-27 18:33:32|    40/   52| bits: 0.01
#   2020-05-27 18:33:32|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:33:37|     0/   52| bits: 30.84
#   2020-05-27 18:33:37|    10/   52| bits: 15.67
#   2020-05-27 18:33:37|    20/   52| bits: 8.86
#   2020-05-27 18:33:38|    30/   52| bits: 4.95
#   2020-05-27 18:33:38|    40/   52| bits: 2.70
#   2020-05-27 18:33:38|    50/   52| bits: 1.42
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.21
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:33:42|     0/   52| bits: 1.24
#   2020-05-27 18:33:42|    10/   52| bits: 0.62
#   2020-05-27 18:33:42|    20/   52| bits: 0.30
#   2020-05-27 18:33:42|    30/   52| bits: 0.15
#   2020-05-27 18:33:42|    40/   52| bits: 0.07
#   2020-05-27 18:33:42|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:33:50|     0/   52| bits: 0.03
#   2020-05-27 18:33:51|    10/   52| bits: 0.02
#   2020-05-27 18:33:51|    20/   52| bits: 0.01
#   2020-05-27 18:33:51|    30/   52| bits: 0.01
#   2020-05-27 18:33:51|    40/   52| bits: 0.01
#   2020-05-27 18:33:51|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:33:56|     0/   52| bits: 24.98
#   2020-05-27 18:33:56|    10/   52| bits: 14.25
#   2020-05-27 18:33:56|    20/   52| bits: 8.25
#   2020-05-27 18:33:57|    30/   52| bits: 4.69
#   2020-05-27 18:33:57|    40/   52| bits: 2.59
#   2020-05-27 18:33:57|    50/   52| bits: 1.35
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.13
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:34:02|     0/   52| bits: 1.18
#   2020-05-27 18:34:02|    10/   52| bits: 0.60
#   2020-05-27 18:34:02|    20/   52| bits: 0.28
#   2020-05-27 18:34:02|    30/   52| bits: 0.13
#   2020-05-27 18:34:02|    40/   52| bits: 0.06
#   2020-05-27 18:34:02|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:34:11|     0/   52| bits: 0.03
#   2020-05-27 18:34:11|    10/   52| bits: 0.02
#   2020-05-27 18:34:11|    20/   52| bits: 0.01
#   2020-05-27 18:34:11|    30/   52| bits: 0.01
#   2020-05-27 18:34:11|    40/   52| bits: 0.01
#   2020-05-27 18:34:11|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:34:16|     0/   52| bits: 22.61
#   2020-05-27 18:34:16|    10/   52| bits: 12.41
#   2020-05-27 18:34:16|    20/   52| bits: 8.15
#   2020-05-27 18:34:16|    30/   52| bits: 5.35
#   2020-05-27 18:34:16|    40/   52| bits: 3.45
#   2020-05-27 18:34:16|    50/   52| bits: 2.21
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.91
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:34:22|     0/   52| bits: 2.03
#   2020-05-27 18:34:22|    10/   52| bits: 1.25
#   2020-05-27 18:34:22|    20/   52| bits: 0.77
#   2020-05-27 18:34:22|    30/   52| bits: 0.45
#   2020-05-27 18:34:22|    40/   52| bits: 0.26
#   2020-05-27 18:34:22|    50/   52| bits: 0.15
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.12
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:34:31|     0/   52| bits: 0.13
#   2020-05-27 18:34:31|    10/   52| bits: 0.08
#   2020-05-27 18:34:31|    20/   52| bits: 0.05
#   2020-05-27 18:34:31|    30/   52| bits: 0.03
#   2020-05-27 18:34:31|    40/   52| bits: 0.02
#   2020-05-27 18:34:31|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:34:36|     0/   52| bits: 21.62
#   2020-05-27 18:34:36|    10/   52| bits: 13.26
#   2020-05-27 18:34:36|    20/   52| bits: 8.40
#   2020-05-27 18:34:36|    30/   52| bits: 5.34
#   2020-05-27 18:34:36|    40/   52| bits: 3.30
#   2020-05-27 18:34:36|    50/   52| bits: 1.99
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.68
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:34:40|     0/   52| bits: 1.77
#   2020-05-27 18:34:41|    10/   52| bits: 1.01
#   2020-05-27 18:34:41|    20/   52| bits: 0.55
#   2020-05-27 18:34:41|    30/   52| bits: 0.29
#   2020-05-27 18:34:41|    40/   52| bits: 0.15
#   2020-05-27 18:34:41|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.07
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:34:50|     0/   52| bits: 0.07
#   2020-05-27 18:34:51|    10/   52| bits: 0.04
#   2020-05-27 18:34:51|    20/   52| bits: 0.03
#   2020-05-27 18:34:51|    30/   52| bits: 0.02
#   2020-05-27 18:34:51|    40/   52| bits: 0.01
#   2020-05-27 18:34:51|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:34:56|     0/   52| bits: 24.07
#   2020-05-27 18:34:56|    10/   52| bits: 13.23
#   2020-05-27 18:34:56|    20/   52| bits: 7.70
#   2020-05-27 18:34:56|    30/   52| bits: 4.41
#   2020-05-27 18:34:56|    40/   52| bits: 2.39
#   2020-05-27 18:34:56|    50/   52| bits: 1.30
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.02
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:35:01|     0/   52| bits: 1.16
#   2020-05-27 18:35:02|    10/   52| bits: 0.60
#   2020-05-27 18:35:02|    20/   52| bits: 0.30
#   2020-05-27 18:35:02|    30/   52| bits: 0.16
#   2020-05-27 18:35:02|    40/   52| bits: 0.08
#   2020-05-27 18:35:02|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:35:10|     0/   52| bits: 0.04
#   2020-05-27 18:35:10|    10/   52| bits: 0.03
#   2020-05-27 18:35:10|    20/   52| bits: 0.02
#   2020-05-27 18:35:10|    30/   52| bits: 0.02
#   2020-05-27 18:35:11|    40/   52| bits: 0.01
#   2020-05-27 18:35:11|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:35:15|     0/   52| bits: 21.76
#   2020-05-27 18:35:15|    10/   52| bits: 13.51
#   2020-05-27 18:35:15|    20/   52| bits: 8.44
#   2020-05-27 18:35:15|    30/   52| bits: 5.15
#   2020-05-27 18:35:15|    40/   52| bits: 3.13
#   2020-05-27 18:35:15|    50/   52| bits: 1.83
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.59
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:35:20|     0/   52| bits: 1.64
#   2020-05-27 18:35:20|    10/   52| bits: 0.94
#   2020-05-27 18:35:20|    20/   52| bits: 0.53
#   2020-05-27 18:35:20|    30/   52| bits: 0.30
#   2020-05-27 18:35:20|    40/   52| bits: 0.17
#   2020-05-27 18:35:20|    50/   52| bits: 0.10
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.08
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:35:28|     0/   52| bits: 0.09
#   2020-05-27 18:35:29|    10/   52| bits: 0.05
#   2020-05-27 18:35:29|    20/   52| bits: 0.03
#   2020-05-27 18:35:29|    30/   52| bits: 0.02
#   2020-05-27 18:35:29|    40/   52| bits: 0.02
#   2020-05-27 18:35:29|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:35:34|     0/   52| bits: 24.72
#   2020-05-27 18:35:34|    10/   52| bits: 13.44
#   2020-05-27 18:35:34|    20/   52| bits: 7.99
#   2020-05-27 18:35:34|    30/   52| bits: 4.77
#   2020-05-27 18:35:34|    40/   52| bits: 2.80
#   2020-05-27 18:35:34|    50/   52| bits: 1.55
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.30
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:35:39|     0/   52| bits: 1.40
#   2020-05-27 18:35:39|    10/   52| bits: 0.73
#   2020-05-27 18:35:39|    20/   52| bits: 0.40
#   2020-05-27 18:35:39|    30/   52| bits: 0.21
#   2020-05-27 18:35:39|    40/   52| bits: 0.11
#   2020-05-27 18:35:39|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:35:48|     0/   52| bits: 0.06
#   2020-05-27 18:35:48|    10/   52| bits: 0.04
#   2020-05-27 18:35:48|    20/   52| bits: 0.02
#   2020-05-27 18:35:48|    30/   52| bits: 0.02
#   2020-05-27 18:35:48|    40/   52| bits: 0.01
#   2020-05-27 18:35:49|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:35:53|     0/   52| bits: 26.82
#   2020-05-27 18:35:54|    10/   52| bits: 14.80
#   2020-05-27 18:35:54|    20/   52| bits: 8.68
#   2020-05-27 18:35:54|    30/   52| bits: 5.10
#   2020-05-27 18:35:54|    40/   52| bits: 3.00
#   2020-05-27 18:35:54|    50/   52| bits: 1.65
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.42
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:35:58|     0/   52| bits: 1.52
#   2020-05-27 18:35:59|    10/   52| bits: 0.84
#   2020-05-27 18:35:59|    20/   52| bits: 0.44
#   2020-05-27 18:35:59|    30/   52| bits: 0.23
#   2020-05-27 18:35:59|    40/   52| bits: 0.12
#   2020-05-27 18:35:59|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:36:07|     0/   52| bits: 0.06
#   2020-05-27 18:36:07|    10/   52| bits: 0.04
#   2020-05-27 18:36:07|    20/   52| bits: 0.02
#   2020-05-27 18:36:07|    30/   52| bits: 0.02
#   2020-05-27 18:36:07|    40/   52| bits: 0.01
#   2020-05-27 18:36:07|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# calculating for d:  1
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:36:13|     0/   52| bits: 19.02
#   2020-05-27 18:36:13|    10/   52| bits: 11.96
#   2020-05-27 18:36:13|    20/   52| bits: 7.70
#   2020-05-27 18:36:13|    30/   52| bits: 5.01
#   2020-05-27 18:36:13|    40/   52| bits: 3.22
#   2020-05-27 18:36:13|    50/   52| bits: 1.95
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.73
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:36:17|     0/   52| bits: 1.77
#   2020-05-27 18:36:18|    10/   52| bits: 1.00
#   2020-05-27 18:36:18|    20/   52| bits: 0.55
#   2020-05-27 18:36:18|    30/   52| bits: 0.27
#   2020-05-27 18:36:18|    40/   52| bits: 0.13
#   2020-05-27 18:36:18|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:36:27|     0/   52| bits: 0.05
#   2020-05-27 18:36:27|    10/   52| bits: 0.03
#   2020-05-27 18:36:27|    20/   52| bits: 0.02
#   2020-05-27 18:36:27|    30/   52| bits: 0.01
#   2020-05-27 18:36:27|    40/   52| bits: 0.01
#   2020-05-27 18:36:28|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:36:32|     0/   52| bits: 26.84
#   2020-05-27 18:36:32|    10/   52| bits: 14.14
#   2020-05-27 18:36:32|    20/   52| bits: 7.96
#   2020-05-27 18:36:32|    30/   52| bits: 4.65
#   2020-05-27 18:36:32|    40/   52| bits: 2.64
#   2020-05-27 18:36:32|    50/   52| bits: 1.50
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.20
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:36:37|     0/   52| bits: 1.32
#   2020-05-27 18:36:37|    10/   52| bits: 0.74
#   2020-05-27 18:36:37|    20/   52| bits: 0.39
#   2020-05-27 18:36:37|    30/   52| bits: 0.21
#   2020-05-27 18:36:38|    40/   52| bits: 0.13
#   2020-05-27 18:36:38|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:36:45|     0/   52| bits: 0.07
#   2020-05-27 18:36:45|    10/   52| bits: 0.05
#   2020-05-27 18:36:46|    20/   52| bits: 0.03
#   2020-05-27 18:36:46|    30/   52| bits: 0.02
#   2020-05-27 18:36:46|    40/   52| bits: 0.02
#   2020-05-27 18:36:46|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:36:52|     0/   52| bits: 19.73
#   2020-05-27 18:36:52|    10/   52| bits: 11.80
#   2020-05-27 18:36:52|    20/   52| bits: 7.38
#   2020-05-27 18:36:52|    30/   52| bits: 4.42
#   2020-05-27 18:36:52|    40/   52| bits: 2.54
#   2020-05-27 18:36:52|    50/   52| bits: 1.34
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.14
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:36:56|     0/   52| bits: 1.20
#   2020-05-27 18:36:56|    10/   52| bits: 0.63
#   2020-05-27 18:36:56|    20/   52| bits: 0.32
#   2020-05-27 18:36:56|    30/   52| bits: 0.17
#   2020-05-27 18:36:56|    40/   52| bits: 0.09
#   2020-05-27 18:36:56|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:37:03|     0/   52| bits: 0.05
#   2020-05-27 18:37:03|    10/   52| bits: 0.03
#   2020-05-27 18:37:03|    20/   52| bits: 0.02
#   2020-05-27 18:37:03|    30/   52| bits: 0.02
#   2020-05-27 18:37:03|    40/   52| bits: 0.02
#   2020-05-27 18:37:03|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:37:11|     0/   52| bits: 31.27
#   2020-05-27 18:37:11|    10/   52| bits: 15.32
#   2020-05-27 18:37:11|    20/   52| bits: 8.09
#   2020-05-27 18:37:11|    30/   52| bits: 4.20
#   2020-05-27 18:37:11|    40/   52| bits: 2.13
#   2020-05-27 18:37:11|    50/   52| bits: 1.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.88
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:37:15|     0/   52| bits: 0.96
#   2020-05-27 18:37:15|    10/   52| bits: 0.46
#   2020-05-27 18:37:15|    20/   52| bits: 0.22
#   2020-05-27 18:37:15|    30/   52| bits: 0.12
#   2020-05-27 18:37:15|    40/   52| bits: 0.06
#   2020-05-27 18:37:15|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:37:21|     0/   52| bits: 0.04
#   2020-05-27 18:37:21|    10/   52| bits: 0.02
#   2020-05-27 18:37:22|    20/   52| bits: 0.02
#   2020-05-27 18:37:22|    30/   52| bits: 0.02
#   2020-05-27 18:37:22|    40/   52| bits: 0.02
#   2020-05-27 18:37:22|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:37:28|     0/   52| bits: 30.34
#   2020-05-27 18:37:29|    10/   52| bits: 14.62
#   2020-05-27 18:37:29|    20/   52| bits: 8.49
#   2020-05-27 18:37:29|    30/   52| bits: 4.85
#   2020-05-27 18:37:29|    40/   52| bits: 2.71
#   2020-05-27 18:37:29|    50/   52| bits: 1.42
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.13
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:37:32|     0/   52| bits: 1.22
#   2020-05-27 18:37:32|    10/   52| bits: 0.60
#   2020-05-27 18:37:33|    20/   52| bits: 0.27
#   2020-05-27 18:37:33|    30/   52| bits: 0.13
#   2020-05-27 18:37:33|    40/   52| bits: 0.06
#   2020-05-27 18:37:33|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:37:37|     0/   52| bits: 0.03
#   2020-05-27 18:37:37|    10/   52| bits: 0.02
#   2020-05-27 18:37:37|    20/   52| bits: 0.01
#   2020-05-27 18:37:37|    30/   52| bits: 0.01
#   2020-05-27 18:37:37|    40/   52| bits: 0.01
#   2020-05-27 18:37:37|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:37:41|     0/   52| bits: 24.03
#   2020-05-27 18:37:41|    10/   52| bits: 13.96
#   2020-05-27 18:37:42|    20/   52| bits: 8.38
#   2020-05-27 18:37:42|    30/   52| bits: 5.09
#   2020-05-27 18:37:42|    40/   52| bits: 3.02
#   2020-05-27 18:37:42|    50/   52| bits: 1.71
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.44
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:37:45|     0/   52| bits: 1.53
#   2020-05-27 18:37:45|    10/   52| bits: 0.83
#   2020-05-27 18:37:45|    20/   52| bits: 0.42
#   2020-05-27 18:37:46|    30/   52| bits: 0.22
#   2020-05-27 18:37:46|    40/   52| bits: 0.12
#   2020-05-27 18:37:46|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:37:50|     0/   52| bits: 0.06
#   2020-05-27 18:37:50|    10/   52| bits: 0.04
#   2020-05-27 18:37:50|    20/   52| bits: 0.03
#   2020-05-27 18:37:50|    30/   52| bits: 0.02
#   2020-05-27 18:37:50|    40/   52| bits: 0.02
#   2020-05-27 18:37:50|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:37:59|     0/   52| bits: 21.95
#   2020-05-27 18:37:59|    10/   52| bits: 12.66
#   2020-05-27 18:37:59|    20/   52| bits: 7.61
#   2020-05-27 18:37:59|    30/   52| bits: 4.48
#   2020-05-27 18:37:59|    40/   52| bits: 2.62
#   2020-05-27 18:37:59|    50/   52| bits: 1.48
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.29
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:38:03|     0/   52| bits: 1.33
#   2020-05-27 18:38:03|    10/   52| bits: 0.74
#   2020-05-27 18:38:03|    20/   52| bits: 0.41
#   2020-05-27 18:38:03|    30/   52| bits: 0.23
#   2020-05-27 18:38:03|    40/   52| bits: 0.13
#   2020-05-27 18:38:03|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:38:07|     0/   52| bits: 0.07
#   2020-05-27 18:38:07|    10/   52| bits: 0.04
#   2020-05-27 18:38:07|    20/   52| bits: 0.03
#   2020-05-27 18:38:07|    30/   52| bits: 0.02
#   2020-05-27 18:38:07|    40/   52| bits: 0.02
#   2020-05-27 18:38:07|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:38:15|     0/   52| bits: 24.69
#   2020-05-27 18:38:15|    10/   52| bits: 14.13
#   2020-05-27 18:38:15|    20/   52| bits: 8.24
#   2020-05-27 18:38:15|    30/   52| bits: 4.92
#   2020-05-27 18:38:15|    40/   52| bits: 2.82
#   2020-05-27 18:38:15|    50/   52| bits: 1.64
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.36
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:38:22|     0/   52| bits: 1.49
#   2020-05-27 18:38:22|    10/   52| bits: 0.82
#   2020-05-27 18:38:22|    20/   52| bits: 0.45
#   2020-05-27 18:38:22|    30/   52| bits: 0.25
#   2020-05-27 18:38:22|    40/   52| bits: 0.14
#   2020-05-27 18:38:22|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:38:26|     0/   52| bits: 0.07
#   2020-05-27 18:38:26|    10/   52| bits: 0.04
#   2020-05-27 18:38:26|    20/   52| bits: 0.03
#   2020-05-27 18:38:26|    30/   52| bits: 0.02
#   2020-05-27 18:38:26|    40/   52| bits: 0.02
#   2020-05-27 18:38:26|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:38:33|     0/   52| bits: 27.38
#   2020-05-27 18:38:33|    10/   52| bits: 15.22
#   2020-05-27 18:38:33|    20/   52| bits: 9.07
#   2020-05-27 18:38:33|    30/   52| bits: 5.42
#   2020-05-27 18:38:33|    40/   52| bits: 3.19
#   2020-05-27 18:38:33|    50/   52| bits: 1.83
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.56
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:38:39|     0/   52| bits: 1.64
#   2020-05-27 18:38:39|    10/   52| bits: 0.90
#   2020-05-27 18:38:39|    20/   52| bits: 0.50
#   2020-05-27 18:38:40|    30/   52| bits: 0.28
#   2020-05-27 18:38:40|    40/   52| bits: 0.16
#   2020-05-27 18:38:40|    50/   52| bits: 0.09
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.08
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:38:43|     0/   52| bits: 0.08
#   2020-05-27 18:38:43|    10/   52| bits: 0.05
#   2020-05-27 18:38:43|    20/   52| bits: 0.03
#   2020-05-27 18:38:44|    30/   52| bits: 0.02
#   2020-05-27 18:38:44|    40/   52| bits: 0.02
#   2020-05-27 18:38:44|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:38:49|     0/   52| bits: 23.92
#   2020-05-27 18:38:50|    10/   52| bits: 12.81
#   2020-05-27 18:38:50|    20/   52| bits: 7.94
#   2020-05-27 18:38:50|    30/   52| bits: 4.91
#   2020-05-27 18:38:50|    40/   52| bits: 3.03
#   2020-05-27 18:38:50|    50/   52| bits: 1.77
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.49
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:38:58|     0/   52| bits: 1.56
#   2020-05-27 18:38:58|    10/   52| bits: 0.88
#   2020-05-27 18:38:58|    20/   52| bits: 0.49
#   2020-05-27 18:38:58|    30/   52| bits: 0.25
#   2020-05-27 18:38:58|    40/   52| bits: 0.13
#   2020-05-27 18:38:59|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:39:02|     0/   52| bits: 0.06
#   2020-05-27 18:39:02|    10/   52| bits: 0.04
#   2020-05-27 18:39:02|    20/   52| bits: 0.03
#   2020-05-27 18:39:02|    30/   52| bits: 0.02
#   2020-05-27 18:39:02|    40/   52| bits: 0.02
#   2020-05-27 18:39:03|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  2
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:39:07|     0/   52| bits: 25.43
#   2020-05-27 18:39:08|    10/   52| bits: 14.52
#   2020-05-27 18:39:08|    20/   52| bits: 8.32
#   2020-05-27 18:39:08|    30/   52| bits: 4.72
#   2020-05-27 18:39:08|    40/   52| bits: 2.61
#   2020-05-27 18:39:08|    50/   52| bits: 1.41
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.23
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:39:16|     0/   52| bits: 1.25
#   2020-05-27 18:39:16|    10/   52| bits: 0.68
#   2020-05-27 18:39:16|    20/   52| bits: 0.37
#   2020-05-27 18:39:17|    30/   52| bits: 0.21
#   2020-05-27 18:39:17|    40/   52| bits: 0.13
#   2020-05-27 18:39:17|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.07
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:39:21|     0/   52| bits: 0.07
#   2020-05-27 18:39:21|    10/   52| bits: 0.05
#   2020-05-27 18:39:21|    20/   52| bits: 0.03
#   2020-05-27 18:39:21|    30/   52| bits: 0.03
#   2020-05-27 18:39:21|    40/   52| bits: 0.02
#   2020-05-27 18:39:21|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:39:26|     0/   52| bits: 30.15
#   2020-05-27 18:39:26|    10/   52| bits: 16.00
#   2020-05-27 18:39:26|    20/   52| bits: 9.59
#   2020-05-27 18:39:26|    30/   52| bits: 5.73
#   2020-05-27 18:39:26|    40/   52| bits: 3.45
#   2020-05-27 18:39:27|    50/   52| bits: 1.97
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.56
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:39:32|     0/   52| bits: 1.78
#   2020-05-27 18:39:32|    10/   52| bits: 0.93
#   2020-05-27 18:39:33|    20/   52| bits: 0.50
#   2020-05-27 18:39:33|    30/   52| bits: 0.27
#   2020-05-27 18:39:33|    40/   52| bits: 0.14
#   2020-05-27 18:39:33|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:39:37|     0/   52| bits: 0.07
#   2020-05-27 18:39:37|    10/   52| bits: 0.04
#   2020-05-27 18:39:38|    20/   52| bits: 0.03
#   2020-05-27 18:39:38|    30/   52| bits: 0.02
#   2020-05-27 18:39:38|    40/   52| bits: 0.02
#   2020-05-27 18:39:38|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:39:42|     0/   52| bits: 20.55
#   2020-05-27 18:39:42|    10/   52| bits: 12.05
#   2020-05-27 18:39:43|    20/   52| bits: 7.62
#   2020-05-27 18:39:43|    30/   52| bits: 4.79
#   2020-05-27 18:39:43|    40/   52| bits: 2.97
#   2020-05-27 18:39:43|    50/   52| bits: 1.76
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.58
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:39:50|     0/   52| bits: 1.59
#   2020-05-27 18:39:50|    10/   52| bits: 0.92
#   2020-05-27 18:39:51|    20/   52| bits: 0.53
#   2020-05-27 18:39:51|    30/   52| bits: 0.29
#   2020-05-27 18:39:51|    40/   52| bits: 0.17
#   2020-05-27 18:39:51|    50/   52| bits: 0.10
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.07
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:39:55|     0/   52| bits: 0.09
#   2020-05-27 18:39:55|    10/   52| bits: 0.05
#   2020-05-27 18:39:55|    20/   52| bits: 0.03
#   2020-05-27 18:39:55|    30/   52| bits: 0.02
#   2020-05-27 18:39:55|    40/   52| bits: 0.02
#   2020-05-27 18:39:55|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:39:59|     0/   52| bits: 20.79
#   2020-05-27 18:39:59|    10/   52| bits: 12.88
#   2020-05-27 18:39:59|    20/   52| bits: 8.16
#   2020-05-27 18:40:00|    30/   52| bits: 4.91
#   2020-05-27 18:40:00|    40/   52| bits: 2.98
#   2020-05-27 18:40:00|    50/   52| bits: 1.69
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.45
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:40:03|     0/   52| bits: 1.54
#   2020-05-27 18:40:03|    10/   52| bits: 0.88
#   2020-05-27 18:40:03|    20/   52| bits: 0.49
#   2020-05-27 18:40:03|    30/   52| bits: 0.28
#   2020-05-27 18:40:04|    40/   52| bits: 0.17
#   2020-05-27 18:40:04|    50/   52| bits: 0.10
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.08
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:40:08|     0/   52| bits: 0.10
#   2020-05-27 18:40:08|    10/   52| bits: 0.06
#   2020-05-27 18:40:08|    20/   52| bits: 0.05
#   2020-05-27 18:40:08|    30/   52| bits: 0.03
#   2020-05-27 18:40:08|    40/   52| bits: 0.02
#   2020-05-27 18:40:08|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:40:16|     0/   52| bits: 25.36
#   2020-05-27 18:40:16|    10/   52| bits: 12.66
#   2020-05-27 18:40:16|    20/   52| bits: 6.97
#   2020-05-27 18:40:17|    30/   52| bits: 3.80
#   2020-05-27 18:40:17|    40/   52| bits: 2.01
#   2020-05-27 18:40:17|    50/   52| bits: 1.04
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.86
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:40:21|     0/   52| bits: 0.90
#   2020-05-27 18:40:21|    10/   52| bits: 0.45
#   2020-05-27 18:40:21|    20/   52| bits: 0.22
#   2020-05-27 18:40:21|    30/   52| bits: 0.11
#   2020-05-27 18:40:21|    40/   52| bits: 0.05
#   2020-05-27 18:40:21|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:40:26|     0/   52| bits: 0.03
#   2020-05-27 18:40:26|    10/   52| bits: 0.02
#   2020-05-27 18:40:26|    20/   52| bits: 0.01
#   2020-05-27 18:40:26|    30/   52| bits: 0.01
#   2020-05-27 18:40:26|    40/   52| bits: 0.01
#   2020-05-27 18:40:26|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:40:35|     0/   52| bits: 29.67
#   2020-05-27 18:40:35|    10/   52| bits: 15.95
#   2020-05-27 18:40:35|    20/   52| bits: 9.28
#   2020-05-27 18:40:35|    30/   52| bits: 5.42
#   2020-05-27 18:40:35|    40/   52| bits: 3.10
#   2020-05-27 18:40:36|    50/   52| bits: 1.76
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.37
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:40:39|     0/   52| bits: 1.53
#   2020-05-27 18:40:39|    10/   52| bits: 0.80
#   2020-05-27 18:40:39|    20/   52| bits: 0.42
#   2020-05-27 18:40:39|    30/   52| bits: 0.21
#   2020-05-27 18:40:40|    40/   52| bits: 0.11
#   2020-05-27 18:40:40|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:40:43|     0/   52| bits: 0.05
#   2020-05-27 18:40:43|    10/   52| bits: 0.02
#   2020-05-27 18:40:43|    20/   52| bits: 0.02
#   2020-05-27 18:40:43|    30/   52| bits: 0.01
#   2020-05-27 18:40:43|    40/   52| bits: 0.01
#   2020-05-27 18:40:44|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:40:51|     0/   52| bits: 22.36
#   2020-05-27 18:40:51|    10/   52| bits: 13.14
#   2020-05-27 18:40:51|    20/   52| bits: 7.97
#   2020-05-27 18:40:51|    30/   52| bits: 4.72
#   2020-05-27 18:40:51|    40/   52| bits: 2.76
#   2020-05-27 18:40:51|    50/   52| bits: 1.51
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.15
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:40:58|     0/   52| bits: 1.34
#   2020-05-27 18:40:58|    10/   52| bits: 0.79
#   2020-05-27 18:40:58|    20/   52| bits: 0.41
#   2020-05-27 18:40:58|    30/   52| bits: 0.22
#   2020-05-27 18:40:58|    40/   52| bits: 0.11
#   2020-05-27 18:40:58|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:41:02|     0/   52| bits: 0.06
#   2020-05-27 18:41:02|    10/   52| bits: 0.03
#   2020-05-27 18:41:02|    20/   52| bits: 0.03
#   2020-05-27 18:41:02|    30/   52| bits: 0.02
#   2020-05-27 18:41:02|    40/   52| bits: 0.02
#   2020-05-27 18:41:02|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:41:09|     0/   52| bits: 23.91
#   2020-05-27 18:41:09|    10/   52| bits: 13.29
#   2020-05-27 18:41:09|    20/   52| bits: 7.44
#   2020-05-27 18:41:09|    30/   52| bits: 4.20
#   2020-05-27 18:41:09|    40/   52| bits: 2.33
#   2020-05-27 18:41:09|    50/   52| bits: 1.27
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.10
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:41:15|     0/   52| bits: 1.12
#   2020-05-27 18:41:16|    10/   52| bits: 0.61
#   2020-05-27 18:41:16|    20/   52| bits: 0.33
#   2020-05-27 18:41:16|    30/   52| bits: 0.19
#   2020-05-27 18:41:16|    40/   52| bits: 0.11
#   2020-05-27 18:41:16|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:41:19|     0/   52| bits: 0.06
#   2020-05-27 18:41:19|    10/   52| bits: 0.04
#   2020-05-27 18:41:20|    20/   52| bits: 0.03
#   2020-05-27 18:41:20|    30/   52| bits: 0.02
#   2020-05-27 18:41:20|    40/   52| bits: 0.02
#   2020-05-27 18:41:20|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:41:25|     0/   52| bits: 23.07
#   2020-05-27 18:41:26|    10/   52| bits: 12.33
#   2020-05-27 18:41:26|    20/   52| bits: 6.89
#   2020-05-27 18:41:26|    30/   52| bits: 3.76
#   2020-05-27 18:41:26|    40/   52| bits: 1.96
#   2020-05-27 18:41:26|    50/   52| bits: 0.99
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.80
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:41:34|     0/   52| bits: 0.85
#   2020-05-27 18:41:34|    10/   52| bits: 0.41
#   2020-05-27 18:41:34|    20/   52| bits: 0.19
#   2020-05-27 18:41:34|    30/   52| bits: 0.09
#   2020-05-27 18:41:34|    40/   52| bits: 0.05
#   2020-05-27 18:41:35|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:41:38|     0/   52| bits: 0.02
#   2020-05-27 18:41:38|    10/   52| bits: 0.02
#   2020-05-27 18:41:38|    20/   52| bits: 0.01
#   2020-05-27 18:41:38|    30/   52| bits: 0.01
#   2020-05-27 18:41:39|    40/   52| bits: 0.01
#   2020-05-27 18:41:39|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:41:44|     0/   52| bits: 22.55
#   2020-05-27 18:41:44|    10/   52| bits: 11.94
#   2020-05-27 18:41:44|    20/   52| bits: 6.56
#   2020-05-27 18:41:44|    30/   52| bits: 3.52
#   2020-05-27 18:41:44|    40/   52| bits: 1.79
#   2020-05-27 18:41:44|    50/   52| bits: 0.87
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.73
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:41:51|     0/   52| bits: 0.75
#   2020-05-27 18:41:52|    10/   52| bits: 0.35
#   2020-05-27 18:41:52|    20/   52| bits: 0.16
#   2020-05-27 18:41:52|    30/   52| bits: 0.08
#   2020-05-27 18:41:53|    40/   52| bits: 0.04
#   2020-05-27 18:41:53|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:41:57|     0/   52| bits: 0.02
#   2020-05-27 18:41:57|    10/   52| bits: 0.01
#   2020-05-27 18:41:57|    20/   52| bits: 0.02
#   2020-05-27 18:41:57|    30/   52| bits: 0.01
#   2020-05-27 18:41:57|    40/   52| bits: 0.01
#   2020-05-27 18:41:57|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  3
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:42:01|     0/   52| bits: 28.47
#   2020-05-27 18:42:01|    10/   52| bits: 16.23
#   2020-05-27 18:42:01|    20/   52| bits: 9.36
#   2020-05-27 18:42:01|    30/   52| bits: 5.37
#   2020-05-27 18:42:01|    40/   52| bits: 2.93
#   2020-05-27 18:42:01|    50/   52| bits: 1.50
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.25
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:42:05|     0/   52| bits: 1.31
#   2020-05-27 18:42:05|    10/   52| bits: 0.61
#   2020-05-27 18:42:05|    20/   52| bits: 0.27
#   2020-05-27 18:42:05|    30/   52| bits: 0.13
#   2020-05-27 18:42:06|    40/   52| bits: 0.06
#   2020-05-27 18:42:06|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:42:09|     0/   52| bits: 0.03
#   2020-05-27 18:42:09|    10/   52| bits: 0.02
#   2020-05-27 18:42:10|    20/   52| bits: 0.01
#   2020-05-27 18:42:10|    30/   52| bits: 0.01
#   2020-05-27 18:42:10|    40/   52| bits: 0.01
#   2020-05-27 18:42:10|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:42:14|     0/   52| bits: 28.79
#   2020-05-27 18:42:14|    10/   52| bits: 14.22
#   2020-05-27 18:42:14|    20/   52| bits: 8.95
#   2020-05-27 18:42:14|    30/   52| bits: 5.85
#   2020-05-27 18:42:14|    40/   52| bits: 3.82
#   2020-05-27 18:42:14|    50/   52| bits: 2.47
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.06
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:42:19|     0/   52| bits: 2.23
#   2020-05-27 18:42:20|    10/   52| bits: 1.40
#   2020-05-27 18:42:20|    20/   52| bits: 0.87
#   2020-05-27 18:42:20|    30/   52| bits: 0.53
#   2020-05-27 18:42:20|    40/   52| bits: 0.33
#   2020-05-27 18:42:20|    50/   52| bits: 0.19
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.12
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:42:27|     0/   52| bits: 0.18
#   2020-05-27 18:42:27|    10/   52| bits: 0.11
#   2020-05-27 18:42:27|    20/   52| bits: 0.07
#   2020-05-27 18:42:27|    30/   52| bits: 0.05
#   2020-05-27 18:42:27|    40/   52| bits: 0.03
#   2020-05-27 18:42:27|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:42:31|     0/   52| bits: 25.75
#   2020-05-27 18:42:31|    10/   52| bits: 14.24
#   2020-05-27 18:42:31|    20/   52| bits: 8.22
#   2020-05-27 18:42:32|    30/   52| bits: 4.69
#   2020-05-27 18:42:32|    40/   52| bits: 2.56
#   2020-05-27 18:42:32|    50/   52| bits: 1.30
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.08
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:42:36|     0/   52| bits: 1.12
#   2020-05-27 18:42:36|    10/   52| bits: 0.52
#   2020-05-27 18:42:36|    20/   52| bits: 0.23
#   2020-05-27 18:42:36|    30/   52| bits: 0.11
#   2020-05-27 18:42:36|    40/   52| bits: 0.05
#   2020-05-27 18:42:36|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:42:44|     0/   52| bits: 0.02
#   2020-05-27 18:42:44|    10/   52| bits: 0.02
#   2020-05-27 18:42:44|    20/   52| bits: 0.01
#   2020-05-27 18:42:44|    30/   52| bits: 0.01
#   2020-05-27 18:42:44|    40/   52| bits: 0.01
#   2020-05-27 18:42:44|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:42:49|     0/   52| bits: 17.85
#   2020-05-27 18:42:49|    10/   52| bits: 10.93
#   2020-05-27 18:42:49|    20/   52| bits: 6.81
#   2020-05-27 18:42:49|    30/   52| bits: 4.11
#   2020-05-27 18:42:49|    40/   52| bits: 2.36
#   2020-05-27 18:42:49|    50/   52| bits: 1.28
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.12
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:42:53|     0/   52| bits: 1.13
#   2020-05-27 18:42:54|    10/   52| bits: 0.58
#   2020-05-27 18:42:54|    20/   52| bits: 0.29
#   2020-05-27 18:42:54|    30/   52| bits: 0.15
#   2020-05-27 18:42:54|    40/   52| bits: 0.07
#   2020-05-27 18:42:54|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:43:01|     0/   52| bits: 0.03
#   2020-05-27 18:43:02|    10/   52| bits: 0.02
#   2020-05-27 18:43:02|    20/   52| bits: 0.02
#   2020-05-27 18:43:02|    30/   52| bits: 0.01
#   2020-05-27 18:43:02|    40/   52| bits: 0.01
#   2020-05-27 18:43:02|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:43:06|     0/   52| bits: 19.07
#   2020-05-27 18:43:07|    10/   52| bits: 12.12
#   2020-05-27 18:43:07|    20/   52| bits: 7.58
#   2020-05-27 18:43:07|    30/   52| bits: 4.52
#   2020-05-27 18:43:07|    40/   52| bits: 2.55
#   2020-05-27 18:43:07|    50/   52| bits: 1.36
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.09
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:43:10|     0/   52| bits: 1.23
#   2020-05-27 18:43:11|    10/   52| bits: 0.62
#   2020-05-27 18:43:11|    20/   52| bits: 0.30
#   2020-05-27 18:43:11|    30/   52| bits: 0.15
#   2020-05-27 18:43:11|    40/   52| bits: 0.08
#   2020-05-27 18:43:11|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:43:18|     0/   52| bits: 0.04
#   2020-05-27 18:43:18|    10/   52| bits: 0.02
#   2020-05-27 18:43:18|    20/   52| bits: 0.02
#   2020-05-27 18:43:18|    30/   52| bits: 0.01
#   2020-05-27 18:43:18|    40/   52| bits: 0.01
#   2020-05-27 18:43:18|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:43:25|     0/   52| bits: 22.59
#   2020-05-27 18:43:25|    10/   52| bits: 12.74
#   2020-05-27 18:43:25|    20/   52| bits: 7.25
#   2020-05-27 18:43:25|    30/   52| bits: 4.03
#   2020-05-27 18:43:25|    40/   52| bits: 2.14
#   2020-05-27 18:43:26|    50/   52| bits: 1.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.92
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:43:29|     0/   52| bits: 0.92
#   2020-05-27 18:43:29|    10/   52| bits: 0.44
#   2020-05-27 18:43:29|    20/   52| bits: 0.20
#   2020-05-27 18:43:29|    30/   52| bits: 0.09
#   2020-05-27 18:43:29|    40/   52| bits: 0.04
#   2020-05-27 18:43:30|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:43:37|     0/   52| bits: 0.02
#   2020-05-27 18:43:37|    10/   52| bits: 0.01
#   2020-05-27 18:43:37|    20/   52| bits: 0.01
#   2020-05-27 18:43:37|    30/   52| bits: 0.01
#   2020-05-27 18:43:37|    40/   52| bits: 0.01
#   2020-05-27 18:43:37|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:43:44|     0/   52| bits: 27.96
#   2020-05-27 18:43:44|    10/   52| bits: 16.17
#   2020-05-27 18:43:44|    20/   52| bits: 10.17
#   2020-05-27 18:43:44|    30/   52| bits: 6.60
#   2020-05-27 18:43:44|    40/   52| bits: 4.32
#   2020-05-27 18:43:44|    50/   52| bits: 2.79
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.29
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:43:48|     0/   52| bits: 2.54
#   2020-05-27 18:43:48|    10/   52| bits: 1.62
#   2020-05-27 18:43:48|    20/   52| bits: 1.00
#   2020-05-27 18:43:48|    30/   52| bits: 0.60
#   2020-05-27 18:43:48|    40/   52| bits: 0.39
#   2020-05-27 18:43:48|    50/   52| bits: 0.26
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.18
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:43:55|     0/   52| bits: 0.24
#   2020-05-27 18:43:55|    10/   52| bits: 0.14
#   2020-05-27 18:43:55|    20/   52| bits: 0.11
#   2020-05-27 18:43:55|    30/   52| bits: 0.08
#   2020-05-27 18:43:55|    40/   52| bits: 0.05
#   2020-05-27 18:43:55|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:44:02|     0/   52| bits: 20.59
#   2020-05-27 18:44:02|    10/   52| bits: 12.63
#   2020-05-27 18:44:02|    20/   52| bits: 7.94
#   2020-05-27 18:44:02|    30/   52| bits: 4.91
#   2020-05-27 18:44:02|    40/   52| bits: 2.84
#   2020-05-27 18:44:02|    50/   52| bits: 1.58
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.25
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:44:06|     0/   52| bits: 1.45
#   2020-05-27 18:44:06|    10/   52| bits: 0.74
#   2020-05-27 18:44:06|    20/   52| bits: 0.39
#   2020-05-27 18:44:06|    30/   52| bits: 0.17
#   2020-05-27 18:44:06|    40/   52| bits: 0.09
#   2020-05-27 18:44:06|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:44:11|     0/   52| bits: 0.04
#   2020-05-27 18:44:11|    10/   52| bits: 0.03
#   2020-05-27 18:44:11|    20/   52| bits: 0.02
#   2020-05-27 18:44:11|    30/   52| bits: 0.02
#   2020-05-27 18:44:11|    40/   52| bits: 0.01
#   2020-05-27 18:44:11|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:44:20|     0/   52| bits: 23.18
#   2020-05-27 18:44:20|    10/   52| bits: 12.76
#   2020-05-27 18:44:20|    20/   52| bits: 7.44
#   2020-05-27 18:44:20|    30/   52| bits: 4.34
#   2020-05-27 18:44:20|    40/   52| bits: 2.48
#   2020-05-27 18:44:20|    50/   52| bits: 1.39
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.14
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:44:24|     0/   52| bits: 1.21
#   2020-05-27 18:44:24|    10/   52| bits: 0.66
#   2020-05-27 18:44:24|    20/   52| bits: 0.35
#   2020-05-27 18:44:24|    30/   52| bits: 0.19
#   2020-05-27 18:44:25|    40/   52| bits: 0.10
#   2020-05-27 18:44:25|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:44:28|     0/   52| bits: 0.05
#   2020-05-27 18:44:28|    10/   52| bits: 0.03
#   2020-05-27 18:44:28|    20/   52| bits: 0.02
#   2020-05-27 18:44:28|    30/   52| bits: 0.02
#   2020-05-27 18:44:28|    40/   52| bits: 0.02
#   2020-05-27 18:44:29|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:44:35|     0/   52| bits: 24.55
#   2020-05-27 18:44:35|    10/   52| bits: 14.39
#   2020-05-27 18:44:36|    20/   52| bits: 8.90
#   2020-05-27 18:44:36|    30/   52| bits: 5.55
#   2020-05-27 18:44:36|    40/   52| bits: 3.27
#   2020-05-27 18:44:36|    50/   52| bits: 1.77
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.46
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:44:42|     0/   52| bits: 1.58
#   2020-05-27 18:44:42|    10/   52| bits: 0.78
#   2020-05-27 18:44:42|    20/   52| bits: 0.39
#   2020-05-27 18:44:43|    30/   52| bits: 0.18
#   2020-05-27 18:44:43|    40/   52| bits: 0.09
#   2020-05-27 18:44:43|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:44:46|     0/   52| bits: 0.04
#   2020-05-27 18:44:46|    10/   52| bits: 0.02
#   2020-05-27 18:44:46|    20/   52| bits: 0.02
#   2020-05-27 18:44:46|    30/   52| bits: 0.01
#   2020-05-27 18:44:47|    40/   52| bits: 0.01
#   2020-05-27 18:44:47|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  5
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:44:53|     0/   52| bits: 21.79
#   2020-05-27 18:44:53|    10/   52| bits: 13.58
#   2020-05-27 18:44:53|    20/   52| bits: 8.69
#   2020-05-27 18:44:54|    30/   52| bits: 5.54
#   2020-05-27 18:44:54|    40/   52| bits: 3.54
#   2020-05-27 18:44:54|    50/   52| bits: 2.18
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.93
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:45:00|     0/   52| bits: 1.99
#   2020-05-27 18:45:00|    10/   52| bits: 1.19
#   2020-05-27 18:45:00|    20/   52| bits: 0.69
#   2020-05-27 18:45:01|    30/   52| bits: 0.39
# ...
#   2020-05-27 18:58:13|    30/   52| bits: 0.31
#   2020-05-27 18:58:13|    40/   52| bits: 0.16
#   2020-05-27 18:58:13|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:58:20|     0/   52| bits: 0.07
#   2020-05-27 18:58:20|    10/   52| bits: 0.04
#   2020-05-27 18:58:20|    20/   52| bits: 0.03
#   2020-05-27 18:58:20|    30/   52| bits: 0.02
#   2020-05-27 18:58:20|    40/   52| bits: 0.02
#   2020-05-27 18:58:20|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:58:28|     0/   52| bits: 22.37
#   2020-05-27 18:58:28|    10/   52| bits: 12.96
#   2020-05-27 18:58:28|    20/   52| bits: 8.11
#   2020-05-27 18:58:28|    30/   52| bits: 5.06
#   2020-05-27 18:58:28|    40/   52| bits: 3.07
#   2020-05-27 18:58:28|    50/   52| bits: 1.75
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.50
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:58:32|     0/   52| bits: 1.54
#   2020-05-27 18:58:32|    10/   52| bits: 0.84
#   2020-05-27 18:58:32|    20/   52| bits: 0.43
#   2020-05-27 18:58:32|    30/   52| bits: 0.22
#   2020-05-27 18:58:32|    40/   52| bits: 0.11
#   2020-05-27 18:58:32|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:58:37|     0/   52| bits: 0.05
#   2020-05-27 18:58:37|    10/   52| bits: 0.03
#   2020-05-27 18:58:37|    20/   52| bits: 0.02
#   2020-05-27 18:58:37|    30/   52| bits: 0.02
#   2020-05-27 18:58:37|    40/   52| bits: 0.01
#   2020-05-27 18:58:37|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:58:45|     0/   52| bits: 21.28
#   2020-05-27 18:58:46|    10/   52| bits: 12.31
#   2020-05-27 18:58:46|    20/   52| bits: 7.37
#   2020-05-27 18:58:46|    30/   52| bits: 4.50
#   2020-05-27 18:58:46|    40/   52| bits: 2.66
#   2020-05-27 18:58:47|    50/   52| bits: 1.55
# Elapsed time: 0h 0m 4s
# Validation| bits: 1.31
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:58:50|     0/   52| bits: 1.38
#   2020-05-27 18:58:50|    10/   52| bits: 0.78
#   2020-05-27 18:58:50|    20/   52| bits: 0.42
#   2020-05-27 18:58:50|    30/   52| bits: 0.23
#   2020-05-27 18:58:50|    40/   52| bits: 0.12
#   2020-05-27 18:58:51|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:58:55|     0/   52| bits: 0.06
#   2020-05-27 18:58:55|    10/   52| bits: 0.04
#   2020-05-27 18:58:55|    20/   52| bits: 0.03
#   2020-05-27 18:58:55|    30/   52| bits: 0.02
#   2020-05-27 18:58:55|    40/   52| bits: 0.01
#   2020-05-27 18:58:55|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:59:02|     0/   52| bits: 23.33
#   2020-05-27 18:59:03|    10/   52| bits: 13.34
#   2020-05-27 18:59:03|    20/   52| bits: 7.57
#   2020-05-27 18:59:03|    30/   52| bits: 4.21
#   2020-05-27 18:59:03|    40/   52| bits: 2.23
#   2020-05-27 18:59:03|    50/   52| bits: 1.12
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.94
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:59:08|     0/   52| bits: 0.96
#   2020-05-27 18:59:08|    10/   52| bits: 0.48
#   2020-05-27 18:59:08|    20/   52| bits: 0.24
#   2020-05-27 18:59:08|    30/   52| bits: 0.12
#   2020-05-27 18:59:08|    40/   52| bits: 0.07
#   2020-05-27 18:59:08|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:59:12|     0/   52| bits: 0.03
#   2020-05-27 18:59:12|    10/   52| bits: 0.02
#   2020-05-27 18:59:12|    20/   52| bits: 0.02
#   2020-05-27 18:59:12|    30/   52| bits: 0.01
#   2020-05-27 18:59:12|    40/   52| bits: 0.01
#   2020-05-27 18:59:12|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  15
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:59:17|     0/   52| bits: 19.21
#   2020-05-27 18:59:17|    10/   52| bits: 12.26
#   2020-05-27 18:59:17|    20/   52| bits: 8.35
#   2020-05-27 18:59:17|    30/   52| bits: 5.54
#   2020-05-27 18:59:17|    40/   52| bits: 3.34
#   2020-05-27 18:59:17|    50/   52| bits: 1.82
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.46
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:59:25|     0/   52| bits: 1.59
#   2020-05-27 18:59:26|    10/   52| bits: 0.76
#   2020-05-27 18:59:26|    20/   52| bits: 0.36
#   2020-05-27 18:59:26|    30/   52| bits: 0.17
#   2020-05-27 18:59:26|    40/   52| bits: 0.09
#   2020-05-27 18:59:26|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:59:30|     0/   52| bits: 0.05
#   2020-05-27 18:59:31|    10/   52| bits: 0.03
#   2020-05-27 18:59:31|    20/   52| bits: 0.02
#   2020-05-27 18:59:31|    30/   52| bits: 0.02
#   2020-05-27 18:59:31|    40/   52| bits: 0.02
#   2020-05-27 18:59:31|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:59:35|     0/   52| bits: 23.57
#   2020-05-27 18:59:35|    10/   52| bits: 12.81
#   2020-05-27 18:59:35|    20/   52| bits: 8.50
#   2020-05-27 18:59:35|    30/   52| bits: 5.86
#   2020-05-27 18:59:35|    40/   52| bits: 3.89
#   2020-05-27 18:59:35|    50/   52| bits: 2.50
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.02
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 18:59:41|     0/   52| bits: 2.32
#   2020-05-27 18:59:41|    10/   52| bits: 1.38
#   2020-05-27 18:59:42|    20/   52| bits: 0.84
#   2020-05-27 18:59:42|    30/   52| bits: 0.45
#   2020-05-27 18:59:42|    40/   52| bits: 0.26
#   2020-05-27 18:59:42|    50/   52| bits: 0.14
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.08
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 18:59:49|     0/   52| bits: 0.12
#   2020-05-27 18:59:49|    10/   52| bits: 0.07
#   2020-05-27 18:59:49|    20/   52| bits: 0.05
#   2020-05-27 18:59:49|    30/   52| bits: 0.03
#   2020-05-27 18:59:49|    40/   52| bits: 0.02
#   2020-05-27 18:59:49|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 18:59:53|     0/   52| bits: 26.27
#   2020-05-27 18:59:53|    10/   52| bits: 14.60
#   2020-05-27 18:59:53|    20/   52| bits: 8.67
#   2020-05-27 18:59:53|    30/   52| bits: 5.09
#   2020-05-27 18:59:53|    40/   52| bits: 2.89
#   2020-05-27 18:59:54|    50/   52| bits: 1.59
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.29
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:00:00|     0/   52| bits: 1.42
#   2020-05-27 19:00:00|    10/   52| bits: 0.73
#   2020-05-27 19:00:00|    20/   52| bits: 0.36
#   2020-05-27 19:00:00|    30/   52| bits: 0.18
#   2020-05-27 19:00:00|    40/   52| bits: 0.09
#   2020-05-27 19:00:00|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:00:06|     0/   52| bits: 0.04
#   2020-05-27 19:00:07|    10/   52| bits: 0.03
#   2020-05-27 19:00:07|    20/   52| bits: 0.02
#   2020-05-27 19:00:07|    30/   52| bits: 0.02
#   2020-05-27 19:00:07|    40/   52| bits: 0.01
#   2020-05-27 19:00:07|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:00:11|     0/   52| bits: 24.94
#   2020-05-27 19:00:11|    10/   52| bits: 13.48
#   2020-05-27 19:00:11|    20/   52| bits: 7.69
#   2020-05-27 19:00:11|    30/   52| bits: 4.40
#   2020-05-27 19:00:11|    40/   52| bits: 2.35
#   2020-05-27 19:00:11|    50/   52| bits: 1.18
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.01
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:00:18|     0/   52| bits: 1.03
#   2020-05-27 19:00:18|    10/   52| bits: 0.50
#   2020-05-27 19:00:18|    20/   52| bits: 0.24
#   2020-05-27 19:00:18|    30/   52| bits: 0.11
#   2020-05-27 19:00:18|    40/   52| bits: 0.05
#   2020-05-27 19:00:18|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:00:25|     0/   52| bits: 0.03
#   2020-05-27 19:00:25|    10/   52| bits: 0.02
#   2020-05-27 19:00:25|    20/   52| bits: 0.01
#   2020-05-27 19:00:25|    30/   52| bits: 0.01
#   2020-05-27 19:00:25|    40/   52| bits: 0.01
#   2020-05-27 19:00:25|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:00:29|     0/   52| bits: 20.14
#   2020-05-27 19:00:29|    10/   52| bits: 11.78
#   2020-05-27 19:00:29|    20/   52| bits: 7.49
#   2020-05-27 19:00:30|    30/   52| bits: 4.81
#   2020-05-27 19:00:30|    40/   52| bits: 2.96
#   2020-05-27 19:00:30|    50/   52| bits: 1.82
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.52
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:00:34|     0/   52| bits: 1.64
#   2020-05-27 19:00:34|    10/   52| bits: 0.97
#   2020-05-27 19:00:34|    20/   52| bits: 0.55
#   2020-05-27 19:00:34|    30/   52| bits: 0.29
#   2020-05-27 19:00:34|    40/   52| bits: 0.16
#   2020-05-27 19:00:34|    50/   52| bits: 0.09
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.07
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:00:38|     0/   52| bits: 0.08
#   2020-05-27 19:00:38|    10/   52| bits: 0.05
#   2020-05-27 19:00:38|    20/   52| bits: 0.03
#   2020-05-27 19:00:38|    30/   52| bits: 0.03
#   2020-05-27 19:00:38|    40/   52| bits: 0.02
#   2020-05-27 19:00:38|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:00:42|     0/   52| bits: 31.47
#   2020-05-27 19:00:43|    10/   52| bits: 16.26
#   2020-05-27 19:00:43|    20/   52| bits: 8.52
#   2020-05-27 19:00:43|    30/   52| bits: 4.42
#   2020-05-27 19:00:43|    40/   52| bits: 2.27
#   2020-05-27 19:00:43|    50/   52| bits: 1.13
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.97
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:00:51|     0/   52| bits: 0.98
#   2020-05-27 19:00:51|    10/   52| bits: 0.49
#   2020-05-27 19:00:51|    20/   52| bits: 0.24
#   2020-05-27 19:00:51|    30/   52| bits: 0.12
#   2020-05-27 19:00:52|    40/   52| bits: 0.06
#   2020-05-27 19:00:52|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:00:56|     0/   52| bits: 0.03
#   2020-05-27 19:00:56|    10/   52| bits: 0.02
#   2020-05-27 19:00:56|    20/   52| bits: 0.02
#   2020-05-27 19:00:57|    30/   52| bits: 0.01
#   2020-05-27 19:00:57|    40/   52| bits: 0.01
#   2020-05-27 19:00:57|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:01:01|     0/   52| bits: 22.01
#   2020-05-27 19:01:01|    10/   52| bits: 13.34
#   2020-05-27 19:01:01|    20/   52| bits: 8.92
#   2020-05-27 19:01:01|    30/   52| bits: 6.00
#   2020-05-27 19:01:01|    40/   52| bits: 3.88
#   2020-05-27 19:01:01|    50/   52| bits: 2.45
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.05
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:01:06|     0/   52| bits: 2.22
#   2020-05-27 19:01:06|    10/   52| bits: 1.31
#   2020-05-27 19:01:06|    20/   52| bits: 0.76
#   2020-05-27 19:01:06|    30/   52| bits: 0.43
#   2020-05-27 19:01:06|    40/   52| bits: 0.24
#   2020-05-27 19:01:06|    50/   52| bits: 0.15
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.10
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:01:10|     0/   52| bits: 0.12
#   2020-05-27 19:01:10|    10/   52| bits: 0.08
#   2020-05-27 19:01:10|    20/   52| bits: 0.06
#   2020-05-27 19:01:10|    30/   52| bits: 0.04
#   2020-05-27 19:01:10|    40/   52| bits: 0.03
#   2020-05-27 19:01:10|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:01:14|     0/   52| bits: 21.43
#   2020-05-27 19:01:15|    10/   52| bits: 12.26
#   2020-05-27 19:01:15|    20/   52| bits: 7.80
#   2020-05-27 19:01:15|    30/   52| bits: 4.80
#   2020-05-27 19:01:15|    40/   52| bits: 2.92
#   2020-05-27 19:01:15|    50/   52| bits: 1.68
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.45
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:01:21|     0/   52| bits: 1.49
#   2020-05-27 19:01:21|    10/   52| bits: 0.83
#   2020-05-27 19:01:21|    20/   52| bits: 0.44
#   2020-05-27 19:01:21|    30/   52| bits: 0.24
#   2020-05-27 19:01:21|    40/   52| bits: 0.12
#   2020-05-27 19:01:21|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:01:28|     0/   52| bits: 0.06
#   2020-05-27 19:01:28|    10/   52| bits: 0.04
#   2020-05-27 19:01:28|    20/   52| bits: 0.02
#   2020-05-27 19:01:29|    30/   52| bits: 0.02
#   2020-05-27 19:01:29|    40/   52| bits: 0.01
#   2020-05-27 19:01:29|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:01:33|     0/   52| bits: 20.29
#   2020-05-27 19:01:33|    10/   52| bits: 12.94
#   2020-05-27 19:01:33|    20/   52| bits: 8.55
#   2020-05-27 19:01:33|    30/   52| bits: 5.54
#   2020-05-27 19:01:33|    40/   52| bits: 3.53
#   2020-05-27 19:01:33|    50/   52| bits: 2.19
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.77
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:01:39|     0/   52| bits: 2.07
#   2020-05-27 19:01:39|    10/   52| bits: 1.27
#   2020-05-27 19:01:39|    20/   52| bits: 0.74
#   2020-05-27 19:01:39|    30/   52| bits: 0.43
#   2020-05-27 19:01:40|    40/   52| bits: 0.27
#   2020-05-27 19:01:40|    50/   52| bits: 0.14
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.11
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:01:47|     0/   52| bits: 0.13
#   2020-05-27 19:01:47|    10/   52| bits: 0.08
#   2020-05-27 19:01:47|    20/   52| bits: 0.05
#   2020-05-27 19:01:47|    30/   52| bits: 0.04
#   2020-05-27 19:01:47|    40/   52| bits: 0.03
#   2020-05-27 19:01:47|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-27 19:01:51|     0/   52| bits: 17.01
#   2020-05-27 19:01:51|    10/   52| bits: 10.99
#   2020-05-27 19:01:51|    20/   52| bits: 7.39
#   2020-05-27 19:01:51|    30/   52| bits: 5.06
#   2020-05-27 19:01:51|    40/   52| bits: 3.29
#   2020-05-27 19:01:51|    50/   52| bits: 2.00
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.54
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-27 19:01:56|     0/   52| bits: 1.72
#   2020-05-27 19:01:56|    10/   52| bits: 0.98
#   2020-05-27 19:01:56|    20/   52| bits: 0.53
#   2020-05-27 19:01:56|    30/   52| bits: 0.27
#   2020-05-27 19:01:56|    40/   52| bits: 0.14
#   2020-05-27 19:01:56|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-27 19:02:04|     0/   52| bits: 0.06
#   2020-05-27 19:02:04|    10/   52| bits: 0.04
#   2020-05-27 19:02:04|    20/   52| bits: 0.03
#   2020-05-27 19:02:04|    30/   52| bits: 0.02
#   2020-05-27 19:02:04|    40/   52| bits: 0.02
#   2020-05-27 19:02:04|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01

# %%
plt.figure(figsize = (20,12))
plt.plot(depths, error.mean(1))
plt.plot(depths, error.mean(1) + error.std(1))
plt.plot(depths, error.mean(1) - error.std(1))

plt.ylabel('MSE')
plt.xlabel('Number of hidden layers (each 32 nodes)')
plt.show()
