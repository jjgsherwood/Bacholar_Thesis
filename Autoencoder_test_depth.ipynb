# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_array, check_is_fitted

import numpy as np
import matplotlib.pyplot as plt
import os
import copy
import inspect
import random
import shutil

from datetime import datetime
from dateutil.relativedelta import relativedelta

from scipy import optimize
from sklearn import decomposition, cluster, model_selection, metrics
import sklearn

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import utils.dataset_utils as dataset
import utils.train_utils as train

# %%
def unit_vector_norm(X):
    X -= X.min() #remove noise offset
    return (X.T / np.sqrt((X**2).sum(axis=1))).T

class View(nn.Module):
    def __init__(self, shape):
        super().__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)

# %%
X = np.load("../data/HSI/Liver_map_150z25_60s_1TCPOBOP.npy", 'r')
Y = np.load("../data/HSI/Liver_map_150z25_60s_2TCPOBOP.npy", 'r')
Z = np.load("../data/HSI/Liver_map_150z25_60s_3OBOB.npy", 'r')
wavelength = np.load("../data/HSI/wavelength.npy", 'r')

shape_X = X.shape 
shape_Y = Y.shape 
shape_Z = Z.shape 

X = copy.copy(X.reshape(-1, X.shape[-1]))
Y = copy.copy(Y.reshape(-1, Y.shape[-1]))
Z = copy.copy(Z.reshape(-1, Z.shape[-1]))

# %%
class AutoEncoderConv(nn.Module):
    def __init__(self, n_components=10, d=1):
        super().__init__()
        h = 30
        self.encode = nn.Sequential( 
            nn.Dropout3d(0.25),
            nn.Flatten(),
            nn.Linear(1000, h),
            nn.ReLU(True),
            nn.Dropout3d(0.5),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),
            nn.Linear(h, n_components)
        )
        
        self.decode = nn.Sequential(
            nn.Linear(n_components, h),
            nn.ReLU(True),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),            
            nn.Linear(h, 1000),
            View((-1,1,1,1,1000))
        )
        
    def forward(self, x):
        return self.decode(self.encode(x))

# %%
def MSE_loss(x, model):
    x_ = model(x)
    return ((x - x_)**2).mean(0).sum()

# %%
class ReferenceVectorClassifierAE(BaseEstimator):
    def __init__(self, **kwargs):
        self.kwargs = {}
        self.k_means_kwargs = {}
        self.ae_kwargs = {}        
        self.set_params(**kwargs)

        _use_cuda = torch.cuda.is_available() and kwargs['cuda']
        if _use_cuda:
            torch.backends.cudnn.enabled = True
            torch.backends.cudnn.benchmark = True
        self.device = torch.device('cuda' if _use_cuda else 'cpu')        
        
    def fit(self, x, **kwargs):
        self.set_params(**kwargs)
        X = unit_vector_norm(x)
        
        ###################### Autoencoder ################################
        self.model = AutoEncoderConv(**self.ae_kwargs).to(self.device)
        
        parameters = filter(lambda x: x.requires_grad, self.model.parameters())
        self.optimizer = optim.Adam(parameters)        
        train_loader, test_loader = dataset.load_liver(X, self.kwargs['batch_size'])
        
        for epoch in range(self.kwargs['epochs']):
            print('-'*50)
            print('Epoch {:3d}/{:3d}'.format(epoch+1, self.kwargs['epochs']))
            start_time = datetime.now()
            train.train(self.model, self.optimizer, train_loader, self.kwargs['loss_func'], self.kwargs['log_step'], self.device)
            end_time = datetime.now()
            time_diff = relativedelta(end_time, start_time)
            print('Elapsed time: {}h {}m {}s'.format(time_diff.hours, time_diff.minutes, time_diff.seconds))
            loss = train.test(self.model, test_loader, self.kwargs['loss_func'], self.device)
            print('Validation| bits: {:2.2f}'.format(loss), flush=True)    
          
        self.model.eval()
        with torch.no_grad():
            z = self.model.encode(dataset.load_liver_all(X).to(self.device)).cpu()
              
        ###################### clustering ################################
        self.clusters = cluster.KMeans(**self.k_means_kwargs).fit(z)
        self.clusters = self.clusters.labels_
        
        one_hot = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        one_hot[range(X.shape[0]), self.clusters] = 1

        ###################### reference spectra ################################
        self.reference_spectra_ = np.array([X[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])
        self.ref_org = np.array([x[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])

        # Return the classifier
        return self

    def predict(self, X):
        """
        predict transforms the data into the reference space. Min weight should be 0 or higher then 'min_weight'
        The error is the NMSE, where the MSE is normalised by the signal strength. 
        error.shape = X.shape[0], so for each data point the error is calculated.
        """
        # Check is fit had been called
        check_is_fitted(self)

        # Input validation
        X = check_array(X)
        X = unit_vector_norm(X)
        
        ###################### RCA ################################
        old_mask = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        mask = np.ones((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        while np.abs(old_mask ^ mask).sum():
            RCA_vector = np.array([optimize.nnls(self.reference_spectra_.T * mask[i], X[i,:])[0] for i in range(X.shape[0])])
            old_mask, mask = mask, (RCA_vector.T / RCA_vector.sum(axis=1)).T >= self.kwargs['min_weight']            
        
        return RCA_vector  
    
    def get_reference_vectors(self):
        return self.reference_spectra_

    def get_org_reference_vectors(self):
        return self.ref_org    
    
    def get_params(self, deep=False):
        return self.kwargs
    
    def set_params(self, **kwargs):
        self.kwargs.update(kwargs)
        self.k_means_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(cluster.KMeans).parameters.keys())})     
        self.ae_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(AutoEncoderConv).parameters.keys())})     
        return self

# %%
def error_map(estimator, X, y=None):
    RCA = estimator.predict(X)
    ref_vec = estimator.get_reference_vectors()
    return ((RCA @ ref_vec - X)**2).mean(1)

def score_func(estimator, X, y=None):
    X = unit_vector_norm(X)
    return error_map(estimator, X).mean()

def print_mean_std(X):
    return f"{X.mean():<12.4e}{X.std():<12.4e}"

def cross_val_X_Y_Z(rvc, X, Y, Z):
    rvc.fit(np.concatenate((X, Y), axis=0))
    return score_func(rvc, Z)

# %%
kwargs = {'n_clusters': 3,
          'n_components': 5, #enough for PCA
          'min_weight': 0,
          'batch_size': 64,
          'cuda': True,
          'log_step': 10,
          'loss_func': MSE_loss,
          'epochs': 3,
          'd':1
         }

header = f"{'mean':12}{'std':12}"

# %%
rvc = ReferenceVectorClassifierAE(**kwargs)

repeat = 3
depths = [0,1,2] + list(range(3,16,2))
error = []
for d in depths:
    print('calculating for d: ',d)
    kwargs['d'] = d
    tmp = 0
    for _ in range(repeat):
        rvc.fit(X)
        tmp += score_func(rvc, X)
    error.append(tmp/repeat)
# Out:
# calculating for d:  0
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:15:32|     0/   52| bits: 22.32
#   2020-05-26 15:15:32|    10/   52| bits: 13.20
#   2020-05-26 15:15:32|    20/   52| bits: 8.13
#   2020-05-26 15:15:32|    30/   52| bits: 5.15
#   2020-05-26 15:15:32|    40/   52| bits: 3.25
#   2020-05-26 15:15:32|    50/   52| bits: 1.94
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.69
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:15:36|     0/   52| bits: 1.76
#   2020-05-26 15:15:36|    10/   52| bits: 0.97
#   2020-05-26 15:15:36|    20/   52| bits: 0.52
#   2020-05-26 15:15:36|    30/   52| bits: 0.28
#   2020-05-26 15:15:36|    40/   52| bits: 0.15
#   2020-05-26 15:15:36|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.07
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:15:40|     0/   52| bits: 0.08
#   2020-05-26 15:15:40|    10/   52| bits: 0.05
#   2020-05-26 15:15:40|    20/   52| bits: 0.03
#   2020-05-26 15:15:40|    30/   52| bits: 0.02
#   2020-05-26 15:15:40|    40/   52| bits: 0.02
#   2020-05-26 15:15:40|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:15:44|     0/   52| bits: 29.50
#   2020-05-26 15:15:44|    10/   52| bits: 15.18
#   2020-05-26 15:15:44|    20/   52| bits: 8.57
#   2020-05-26 15:15:44|    30/   52| bits: 4.86
#   2020-05-26 15:15:44|    40/   52| bits: 2.69
#   2020-05-26 15:15:45|    50/   52| bits: 1.49
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.27
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:15:48|     0/   52| bits: 1.35
#   2020-05-26 15:15:48|    10/   52| bits: 0.73
#   2020-05-26 15:15:48|    20/   52| bits: 0.39
#   2020-05-26 15:15:48|    30/   52| bits: 0.21
#   2020-05-26 15:15:48|    40/   52| bits: 0.11
#   2020-05-26 15:15:48|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:15:52|     0/   52| bits: 0.06
#   2020-05-26 15:15:52|    10/   52| bits: 0.03
#   2020-05-26 15:15:52|    20/   52| bits: 0.02
#   2020-05-26 15:15:52|    30/   52| bits: 0.01
#   2020-05-26 15:15:52|    40/   52| bits: 0.01
#   2020-05-26 15:15:52|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:15:56|     0/   52| bits: 27.37
#   2020-05-26 15:15:56|    10/   52| bits: 15.55
#   2020-05-26 15:15:57|    20/   52| bits: 9.39
#   2020-05-26 15:15:57|    30/   52| bits: 5.62
#   2020-05-26 15:15:57|    40/   52| bits: 3.30
#   2020-05-26 15:15:57|    50/   52| bits: 1.92
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.70
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:16:00|     0/   52| bits: 1.72
#   2020-05-26 15:16:00|    10/   52| bits: 0.99
#   2020-05-26 15:16:00|    20/   52| bits: 0.57
#   2020-05-26 15:16:01|    30/   52| bits: 0.32
#   2020-05-26 15:16:01|    40/   52| bits: 0.19
#   2020-05-26 15:16:01|    50/   52| bits: 0.11
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.09
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:16:04|     0/   52| bits: 0.10
#   2020-05-26 15:16:04|    10/   52| bits: 0.06
#   2020-05-26 15:16:04|    20/   52| bits: 0.03
#   2020-05-26 15:16:05|    30/   52| bits: 0.02
#   2020-05-26 15:16:05|    40/   52| bits: 0.02
#   2020-05-26 15:16:05|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  1
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:16:09|     0/   52| bits: 22.84
#   2020-05-26 15:16:09|    10/   52| bits: 12.95
#   2020-05-26 15:16:09|    20/   52| bits: 8.42
#   2020-05-26 15:16:09|    30/   52| bits: 5.62
#   2020-05-26 15:16:09|    40/   52| bits: 3.73
#   2020-05-26 15:16:09|    50/   52| bits: 2.32
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.83
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:16:13|     0/   52| bits: 2.04
#   2020-05-26 15:16:13|    10/   52| bits: 1.19
#   2020-05-26 15:16:13|    20/   52| bits: 0.64
#   2020-05-26 15:16:13|    30/   52| bits: 0.33
#   2020-05-26 15:16:13|    40/   52| bits: 0.16
#   2020-05-26 15:16:13|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:16:17|     0/   52| bits: 0.07
#   2020-05-26 15:16:17|    10/   52| bits: 0.04
#   2020-05-26 15:16:17|    20/   52| bits: 0.02
#   2020-05-26 15:16:17|    30/   52| bits: 0.02
#   2020-05-26 15:16:17|    40/   52| bits: 0.01
#   2020-05-26 15:16:17|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:16:21|     0/   52| bits: 33.15
#   2020-05-26 15:16:21|    10/   52| bits: 16.92
#   2020-05-26 15:16:22|    20/   52| bits: 9.08
#   2020-05-26 15:16:22|    30/   52| bits: 4.96
#   2020-05-26 15:16:22|    40/   52| bits: 2.70
#   2020-05-26 15:16:22|    50/   52| bits: 1.42
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.17
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:16:25|     0/   52| bits: 1.22
#   2020-05-26 15:16:25|    10/   52| bits: 0.63
#   2020-05-26 15:16:25|    20/   52| bits: 0.32
#   2020-05-26 15:16:26|    30/   52| bits: 0.16
#   2020-05-26 15:16:26|    40/   52| bits: 0.09
#   2020-05-26 15:16:26|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:16:29|     0/   52| bits: 0.05
#   2020-05-26 15:16:29|    10/   52| bits: 0.03
#   2020-05-26 15:16:29|    20/   52| bits: 0.02
#   2020-05-26 15:16:29|    30/   52| bits: 0.02
#   2020-05-26 15:16:30|    40/   52| bits: 0.01
#   2020-05-26 15:16:30|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:16:34|     0/   52| bits: 19.23
#   2020-05-26 15:16:34|    10/   52| bits: 11.11
#   2020-05-26 15:16:34|    20/   52| bits: 6.46
#   2020-05-26 15:16:34|    30/   52| bits: 3.63
#   2020-05-26 15:16:34|    40/   52| bits: 1.98
#   2020-05-26 15:16:34|    50/   52| bits: 1.00
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.84
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:16:38|     0/   52| bits: 0.87
#   2020-05-26 15:16:38|    10/   52| bits: 0.41
#   2020-05-26 15:16:38|    20/   52| bits: 0.19
#   2020-05-26 15:16:38|    30/   52| bits: 0.10
#   2020-05-26 15:16:38|    40/   52| bits: 0.05
#   2020-05-26 15:16:38|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:16:42|     0/   52| bits: 0.02
#   2020-05-26 15:16:42|    10/   52| bits: 0.02
#   2020-05-26 15:16:42|    20/   52| bits: 0.01
#   2020-05-26 15:16:42|    30/   52| bits: 0.01
#   2020-05-26 15:16:42|    40/   52| bits: 0.01
#   2020-05-26 15:16:42|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  2
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:16:46|     0/   52| bits: 26.87
#   2020-05-26 15:16:46|    10/   52| bits: 14.08
#   2020-05-26 15:16:46|    20/   52| bits: 7.73
#   2020-05-26 15:16:46|    30/   52| bits: 4.14
#   2020-05-26 15:16:46|    40/   52| bits: 2.18
#   2020-05-26 15:16:46|    50/   52| bits: 1.10
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.93
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:16:50|     0/   52| bits: 0.95
#   2020-05-26 15:16:50|    10/   52| bits: 0.45
#   2020-05-26 15:16:50|    20/   52| bits: 0.21
#   2020-05-26 15:16:50|    30/   52| bits: 0.09
#   2020-05-26 15:16:50|    40/   52| bits: 0.05
#   2020-05-26 15:16:50|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:16:54|     0/   52| bits: 0.02
#   2020-05-26 15:16:54|    10/   52| bits: 0.02
#   2020-05-26 15:16:54|    20/   52| bits: 0.01
#   2020-05-26 15:16:54|    30/   52| bits: 0.01
#   2020-05-26 15:16:54|    40/   52| bits: 0.01
#   2020-05-26 15:16:54|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:16:58|     0/   52| bits: 20.17
#   2020-05-26 15:16:58|    10/   52| bits: 12.82
#   2020-05-26 15:16:58|    20/   52| bits: 8.23
#   2020-05-26 15:16:59|    30/   52| bits: 5.10
#   2020-05-26 15:16:59|    40/   52| bits: 3.01
#   2020-05-26 15:16:59|    50/   52| bits: 1.73
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.43
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:17:02|     0/   52| bits: 1.52
#   2020-05-26 15:17:02|    10/   52| bits: 0.83
#   2020-05-26 15:17:02|    20/   52| bits: 0.43
#   2020-05-26 15:17:02|    30/   52| bits: 0.23
#   2020-05-26 15:17:03|    40/   52| bits: 0.12
#   2020-05-26 15:17:03|    50/   52| bits: 0.07
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:17:06|     0/   52| bits: 0.06
#   2020-05-26 15:17:06|    10/   52| bits: 0.03
#   2020-05-26 15:17:06|    20/   52| bits: 0.02
#   2020-05-26 15:17:06|    30/   52| bits: 0.02
#   2020-05-26 15:17:06|    40/   52| bits: 0.01
#   2020-05-26 15:17:06|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:17:11|     0/   52| bits: 23.11
#   2020-05-26 15:17:11|    10/   52| bits: 13.33
#   2020-05-26 15:17:11|    20/   52| bits: 8.17
#   2020-05-26 15:17:11|    30/   52| bits: 4.90
#   2020-05-26 15:17:11|    40/   52| bits: 2.84
#   2020-05-26 15:17:11|    50/   52| bits: 1.56
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.31
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:17:14|     0/   52| bits: 1.38
#   2020-05-26 15:17:15|    10/   52| bits: 0.72
#   2020-05-26 15:17:15|    20/   52| bits: 0.37
#   2020-05-26 15:17:15|    30/   52| bits: 0.19
#   2020-05-26 15:17:15|    40/   52| bits: 0.09
#   2020-05-26 15:17:15|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:17:18|     0/   52| bits: 0.04
#   2020-05-26 15:17:18|    10/   52| bits: 0.03
#   2020-05-26 15:17:19|    20/   52| bits: 0.02
#   2020-05-26 15:17:19|    30/   52| bits: 0.02
#   2020-05-26 15:17:19|    40/   52| bits: 0.01
#   2020-05-26 15:17:19|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  3
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:17:23|     0/   52| bits: 25.77
#   2020-05-26 15:17:23|    10/   52| bits: 13.04
#   2020-05-26 15:17:23|    20/   52| bits: 6.83
#   2020-05-26 15:17:23|    30/   52| bits: 3.54
#   2020-05-26 15:17:23|    40/   52| bits: 1.79
#   2020-05-26 15:17:23|    50/   52| bits: 0.88
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.74
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:17:27|     0/   52| bits: 0.76
#   2020-05-26 15:17:27|    10/   52| bits: 0.36
#   2020-05-26 15:17:27|    20/   52| bits: 0.17
#   2020-05-26 15:17:27|    30/   52| bits: 0.09
#   2020-05-26 15:17:27|    40/   52| bits: 0.05
#   2020-05-26 15:17:27|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:17:31|     0/   52| bits: 0.02
#   2020-05-26 15:17:31|    10/   52| bits: 0.02
#   2020-05-26 15:17:31|    20/   52| bits: 0.01
#   2020-05-26 15:17:31|    30/   52| bits: 0.01
#   2020-05-26 15:17:31|    40/   52| bits: 0.01
#   2020-05-26 15:17:31|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:17:35|     0/   52| bits: 24.40
#   2020-05-26 15:17:35|    10/   52| bits: 12.90
#   2020-05-26 15:17:35|    20/   52| bits: 8.72
#   2020-05-26 15:17:35|    30/   52| bits: 5.60
#   2020-05-26 15:17:35|    40/   52| bits: 3.67
#   2020-05-26 15:17:35|    50/   52| bits: 2.28
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.68
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:17:39|     0/   52| bits: 2.06
#   2020-05-26 15:17:39|    10/   52| bits: 1.19
#   2020-05-26 15:17:39|    20/   52| bits: 0.65
#   2020-05-26 15:17:39|    30/   52| bits: 0.37
#   2020-05-26 15:17:39|    40/   52| bits: 0.20
#   2020-05-26 15:17:39|    50/   52| bits: 0.10
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:17:43|     0/   52| bits: 0.09
#   2020-05-26 15:17:43|    10/   52| bits: 0.05
#   2020-05-26 15:17:43|    20/   52| bits: 0.04
#   2020-05-26 15:17:43|    30/   52| bits: 0.03
#   2020-05-26 15:17:43|    40/   52| bits: 0.03
#   2020-05-26 15:17:43|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:17:47|     0/   52| bits: 24.56
#   2020-05-26 15:17:47|    10/   52| bits: 13.05
#   2020-05-26 15:17:47|    20/   52| bits: 7.79
#   2020-05-26 15:17:47|    30/   52| bits: 4.62
#   2020-05-26 15:17:47|    40/   52| bits: 2.69
#   2020-05-26 15:17:48|    50/   52| bits: 1.53
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.29
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:17:51|     0/   52| bits: 1.36
#   2020-05-26 15:17:51|    10/   52| bits: 0.72
#   2020-05-26 15:17:51|    20/   52| bits: 0.38
#   2020-05-26 15:17:51|    30/   52| bits: 0.19
#   2020-05-26 15:17:51|    40/   52| bits: 0.10
#   2020-05-26 15:17:51|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:17:55|     0/   52| bits: 0.05
#   2020-05-26 15:17:55|    10/   52| bits: 0.02
#   2020-05-26 15:17:55|    20/   52| bits: 0.02
#   2020-05-26 15:17:55|    30/   52| bits: 0.01
#   2020-05-26 15:17:55|    40/   52| bits: 0.01
#   2020-05-26 15:17:55|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  5
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:17:59|     0/   52| bits: 19.43
#   2020-05-26 15:18:00|    10/   52| bits: 11.93
#   2020-05-26 15:18:00|    20/   52| bits: 7.75
#   2020-05-26 15:18:00|    30/   52| bits: 4.99
#   2020-05-26 15:18:00|    40/   52| bits: 3.10
#   2020-05-26 15:18:00|    50/   52| bits: 1.90
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.62
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:18:03|     0/   52| bits: 1.69
#   2020-05-26 15:18:03|    10/   52| bits: 0.95
#   2020-05-26 15:18:03|    20/   52| bits: 0.51
#   2020-05-26 15:18:04|    30/   52| bits: 0.26
#   2020-05-26 15:18:04|    40/   52| bits: 0.14
#   2020-05-26 15:18:04|    50/   52| bits: 0.08
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.06
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:18:07|     0/   52| bits: 0.07
#   2020-05-26 15:18:07|    10/   52| bits: 0.04
#   2020-05-26 15:18:07|    20/   52| bits: 0.03
#   2020-05-26 15:18:08|    30/   52| bits: 0.02
#   2020-05-26 15:18:08|    40/   52| bits: 0.02
#   2020-05-26 15:18:08|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:18:12|     0/   52| bits: 20.89
#   2020-05-26 15:18:12|    10/   52| bits: 12.96
#   2020-05-26 15:18:12|    20/   52| bits: 8.29
#   2020-05-26 15:18:12|    30/   52| bits: 5.21
#   2020-05-26 15:18:12|    40/   52| bits: 3.25
#   2020-05-26 15:18:12|    50/   52| bits: 1.96
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.76
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:18:16|     0/   52| bits: 1.78
#   2020-05-26 15:18:16|    10/   52| bits: 1.09
#   2020-05-26 15:18:16|    20/   52| bits: 0.63
#   2020-05-26 15:18:16|    30/   52| bits: 0.36
#   2020-05-26 15:18:16|    40/   52| bits: 0.22
#   2020-05-26 15:18:16|    50/   52| bits: 0.13
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.11
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:18:20|     0/   52| bits: 0.11
#   2020-05-26 15:18:20|    10/   52| bits: 0.07
#   2020-05-26 15:18:20|    20/   52| bits: 0.04
#   2020-05-26 15:18:20|    30/   52| bits: 0.03
#   2020-05-26 15:18:20|    40/   52| bits: 0.02
#   2020-05-26 15:18:20|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:18:24|     0/   52| bits: 22.28
#   2020-05-26 15:18:24|    10/   52| bits: 12.44
#   2020-05-26 15:18:24|    20/   52| bits: 7.14
#   2020-05-26 15:18:24|    30/   52| bits: 4.14
#   2020-05-26 15:18:24|    40/   52| bits: 2.31
#   2020-05-26 15:18:25|    50/   52| bits: 1.21
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.00
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:18:30|     0/   52| bits: 1.04
#   2020-05-26 15:18:30|    10/   52| bits: 0.52
#   2020-05-26 15:18:30|    20/   52| bits: 0.25
#   2020-05-26 15:18:30|    30/   52| bits: 0.13
#   2020-05-26 15:18:30|    40/   52| bits: 0.07
#   2020-05-26 15:18:30|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:18:34|     0/   52| bits: 0.03
#   2020-05-26 15:18:34|    10/   52| bits: 0.02
#   2020-05-26 15:18:34|    20/   52| bits: 0.02
#   2020-05-26 15:18:34|    30/   52| bits: 0.01
#   2020-05-26 15:18:34|    40/   52| bits: 0.02
#   2020-05-26 15:18:34|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  7
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:18:38|     0/   52| bits: 23.53
#   2020-05-26 15:18:38|    10/   52| bits: 13.58
#   2020-05-26 15:18:38|    20/   52| bits: 8.26
#   2020-05-26 15:18:38|    30/   52| bits: 4.87
#   2020-05-26 15:18:38|    40/   52| bits: 2.69
#   2020-05-26 15:18:38|    50/   52| bits: 1.48
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.08
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:18:42|     0/   52| bits: 1.31
#   2020-05-26 15:18:42|    10/   52| bits: 0.65
#   2020-05-26 15:18:42|    20/   52| bits: 0.33
#   2020-05-26 15:18:42|    30/   52| bits: 0.17
#   2020-05-26 15:18:42|    40/   52| bits: 0.09
#   2020-05-26 15:18:42|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:18:46|     0/   52| bits: 0.05
#   2020-05-26 15:18:46|    10/   52| bits: 0.03
#   2020-05-26 15:18:46|    20/   52| bits: 0.03
#   2020-05-26 15:18:46|    30/   52| bits: 0.02
#   2020-05-26 15:18:46|    40/   52| bits: 0.02
#   2020-05-26 15:18:46|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:18:50|     0/   52| bits: 21.79
#   2020-05-26 15:18:50|    10/   52| bits: 13.62
#   2020-05-26 15:18:50|    20/   52| bits: 8.49
#   2020-05-26 15:18:50|    30/   52| bits: 5.20
#   2020-05-26 15:18:50|    40/   52| bits: 3.02
#   2020-05-26 15:18:50|    50/   52| bits: 1.61
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.36
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:18:54|     0/   52| bits: 1.42
#   2020-05-26 15:18:54|    10/   52| bits: 0.68
#   2020-05-26 15:18:54|    20/   52| bits: 0.32
#   2020-05-26 15:18:54|    30/   52| bits: 0.16
#   2020-05-26 15:18:54|    40/   52| bits: 0.08
#   2020-05-26 15:18:54|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:18:58|     0/   52| bits: 0.05
#   2020-05-26 15:18:58|    10/   52| bits: 0.03
#   2020-05-26 15:18:58|    20/   52| bits: 0.02
#   2020-05-26 15:18:58|    30/   52| bits: 0.02
#   2020-05-26 15:18:58|    40/   52| bits: 0.01
#   2020-05-26 15:18:58|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:19:02|     0/   52| bits: 27.36
#   2020-05-26 15:19:03|    10/   52| bits: 14.77
#   2020-05-26 15:19:03|    20/   52| bits: 8.12
#   2020-05-26 15:19:03|    30/   52| bits: 4.48
#   2020-05-26 15:19:03|    40/   52| bits: 2.42
#   2020-05-26 15:19:03|    50/   52| bits: 1.30
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.13
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:19:07|     0/   52| bits: 1.15
#   2020-05-26 15:19:07|    10/   52| bits: 0.61
#   2020-05-26 15:19:07|    20/   52| bits: 0.32
#   2020-05-26 15:19:07|    30/   52| bits: 0.17
#   2020-05-26 15:19:07|    40/   52| bits: 0.09
#   2020-05-26 15:19:07|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:19:10|     0/   52| bits: 0.04
#   2020-05-26 15:19:10|    10/   52| bits: 0.03
#   2020-05-26 15:19:11|    20/   52| bits: 0.02
#   2020-05-26 15:19:11|    30/   52| bits: 0.01
#   2020-05-26 15:19:11|    40/   52| bits: 0.01
#   2020-05-26 15:19:11|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  9
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:19:15|     0/   52| bits: 29.86
#   2020-05-26 15:19:15|    10/   52| bits: 15.37
#   2020-05-26 15:19:15|    20/   52| bits: 7.96
#   2020-05-26 15:19:15|    30/   52| bits: 4.24
#   2020-05-26 15:19:15|    40/   52| bits: 2.26
#   2020-05-26 15:19:15|    50/   52| bits: 1.15
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.91
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:19:19|     0/   52| bits: 0.99
#   2020-05-26 15:19:19|    10/   52| bits: 0.51
#   2020-05-26 15:19:19|    20/   52| bits: 0.26
#   2020-05-26 15:19:19|    30/   52| bits: 0.15
#   2020-05-26 15:19:19|    40/   52| bits: 0.08
#   2020-05-26 15:19:19|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:19:23|     0/   52| bits: 0.04
#   2020-05-26 15:19:23|    10/   52| bits: 0.03
#   2020-05-26 15:19:23|    20/   52| bits: 0.02
#   2020-05-26 15:19:23|    30/   52| bits: 0.02
#   2020-05-26 15:19:23|    40/   52| bits: 0.01
#   2020-05-26 15:19:23|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:19:27|     0/   52| bits: 23.98
#   2020-05-26 15:19:27|    10/   52| bits: 13.38
#   2020-05-26 15:19:27|    20/   52| bits: 7.56
#   2020-05-26 15:19:27|    30/   52| bits: 4.31
#   2020-05-26 15:19:27|    40/   52| bits: 2.41
#   2020-05-26 15:19:27|    50/   52| bits: 1.33
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.14
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:19:31|     0/   52| bits: 1.17
#   2020-05-26 15:19:31|    10/   52| bits: 0.62
#   2020-05-26 15:19:31|    20/   52| bits: 0.32
#   2020-05-26 15:19:31|    30/   52| bits: 0.17
#   2020-05-26 15:19:31|    40/   52| bits: 0.09
#   2020-05-26 15:19:31|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:19:35|     0/   52| bits: 0.04
#   2020-05-26 15:19:35|    10/   52| bits: 0.03
#   2020-05-26 15:19:35|    20/   52| bits: 0.02
#   2020-05-26 15:19:35|    30/   52| bits: 0.01
#   2020-05-26 15:19:35|    40/   52| bits: 0.02
#   2020-05-26 15:19:35|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:19:39|     0/   52| bits: 20.91
#   2020-05-26 15:19:39|    10/   52| bits: 13.00
#   2020-05-26 15:19:39|    20/   52| bits: 8.78
#   2020-05-26 15:19:39|    30/   52| bits: 5.48
#   2020-05-26 15:19:39|    40/   52| bits: 3.12
#   2020-05-26 15:19:39|    50/   52| bits: 1.89
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.30
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:19:43|     0/   52| bits: 1.60
#   2020-05-26 15:19:43|    10/   52| bits: 0.89
#   2020-05-26 15:19:43|    20/   52| bits: 0.45
#   2020-05-26 15:19:43|    30/   52| bits: 0.23
#   2020-05-26 15:19:43|    40/   52| bits: 0.11
#   2020-05-26 15:19:43|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:19:50|     0/   52| bits: 0.05
#   2020-05-26 15:19:50|    10/   52| bits: 0.03
#   2020-05-26 15:19:50|    20/   52| bits: 0.03
#   2020-05-26 15:19:50|    30/   52| bits: 0.02
#   2020-05-26 15:19:50|    40/   52| bits: 0.02
#   2020-05-26 15:19:50|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# calculating for d:  11
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:19:57|     0/   52| bits: 26.68
#   2020-05-26 15:19:57|    10/   52| bits: 13.85
#   2020-05-26 15:19:57|    20/   52| bits: 8.36
#   2020-05-26 15:19:58|    30/   52| bits: 4.80
#   2020-05-26 15:19:58|    40/   52| bits: 2.82
#   2020-05-26 15:19:58|    50/   52| bits: 1.56
# Elapsed time: 0h 0m 3s
# Validation| bits: 1.22
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:20:04|     0/   52| bits: 1.36
#   2020-05-26 15:20:05|    10/   52| bits: 0.69
#   2020-05-26 15:20:05|    20/   52| bits: 0.34
#   2020-05-26 15:20:05|    30/   52| bits: 0.16
#   2020-05-26 15:20:05|    40/   52| bits: 0.08
#   2020-05-26 15:20:05|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:20:12|     0/   52| bits: 0.04
#   2020-05-26 15:20:12|    10/   52| bits: 0.02
#   2020-05-26 15:20:12|    20/   52| bits: 0.02
#   2020-05-26 15:20:12|    30/   52| bits: 0.02
#   2020-05-26 15:20:12|    40/   52| bits: 0.01
#   2020-05-26 15:20:12|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:20:17|     0/   52| bits: 19.50
#   2020-05-26 15:20:17|    10/   52| bits: 12.16
#   2020-05-26 15:20:17|    20/   52| bits: 7.93
#   2020-05-26 15:20:17|    30/   52| bits: 5.21
#   2020-05-26 15:20:17|    40/   52| bits: 3.43
#   2020-05-26 15:20:17|    50/   52| bits: 2.19
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.87
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:20:22|     0/   52| bits: 1.97
#   2020-05-26 15:20:22|    10/   52| bits: 1.13
#   2020-05-26 15:20:22|    20/   52| bits: 0.58
#   2020-05-26 15:20:22|    30/   52| bits: 0.28
#   2020-05-26 15:20:22|    40/   52| bits: 0.13
#   2020-05-26 15:20:22|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:20:26|     0/   52| bits: 0.05
#   2020-05-26 15:20:26|    10/   52| bits: 0.03
#   2020-05-26 15:20:26|    20/   52| bits: 0.02
#   2020-05-26 15:20:26|    30/   52| bits: 0.01
#   2020-05-26 15:20:26|    40/   52| bits: 0.01
#   2020-05-26 15:20:26|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:20:30|     0/   52| bits: 20.49
#   2020-05-26 15:20:30|    10/   52| bits: 12.05
#   2020-05-26 15:20:30|    20/   52| bits: 7.49
#   2020-05-26 15:20:30|    30/   52| bits: 4.53
#   2020-05-26 15:20:30|    40/   52| bits: 2.55
#   2020-05-26 15:20:30|    50/   52| bits: 1.35
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.12
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:20:34|     0/   52| bits: 1.19
#   2020-05-26 15:20:34|    10/   52| bits: 0.57
#   2020-05-26 15:20:34|    20/   52| bits: 0.28
#   2020-05-26 15:20:34|    30/   52| bits: 0.13
#   2020-05-26 15:20:34|    40/   52| bits: 0.06
#   2020-05-26 15:20:34|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:20:38|     0/   52| bits: 0.03
#   2020-05-26 15:20:38|    10/   52| bits: 0.02
#   2020-05-26 15:20:38|    20/   52| bits: 0.02
#   2020-05-26 15:20:38|    30/   52| bits: 0.01
#   2020-05-26 15:20:38|    40/   52| bits: 0.01
#   2020-05-26 15:20:38|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  13
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:20:42|     0/   52| bits: 24.89
#   2020-05-26 15:20:42|    10/   52| bits: 13.74
#   2020-05-26 15:20:42|    20/   52| bits: 7.90
#   2020-05-26 15:20:43|    30/   52| bits: 4.41
#   2020-05-26 15:20:43|    40/   52| bits: 2.41
#   2020-05-26 15:20:43|    50/   52| bits: 1.28
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.06
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:20:46|     0/   52| bits: 1.11
#   2020-05-26 15:20:46|    10/   52| bits: 0.56
#   2020-05-26 15:20:46|    20/   52| bits: 0.28
#   2020-05-26 15:20:47|    30/   52| bits: 0.14
#   2020-05-26 15:20:47|    40/   52| bits: 0.07
#   2020-05-26 15:20:47|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:20:50|     0/   52| bits: 0.04
#   2020-05-26 15:20:50|    10/   52| bits: 0.03
#   2020-05-26 15:20:50|    20/   52| bits: 0.02
#   2020-05-26 15:20:50|    30/   52| bits: 0.02
#   2020-05-26 15:20:50|    40/   52| bits: 0.01
#   2020-05-26 15:20:51|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:20:55|     0/   52| bits: 26.90
#   2020-05-26 15:20:55|    10/   52| bits: 13.47
#   2020-05-26 15:20:55|    20/   52| bits: 8.54
#   2020-05-26 15:20:55|    30/   52| bits: 5.72
#   2020-05-26 15:20:55|    40/   52| bits: 3.79
#   2020-05-26 15:20:55|    50/   52| bits: 2.60
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.09
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:20:59|     0/   52| bits: 2.40
#   2020-05-26 15:20:59|    10/   52| bits: 1.61
#   2020-05-26 15:20:59|    20/   52| bits: 1.01
#   2020-05-26 15:20:59|    30/   52| bits: 0.60
#   2020-05-26 15:20:59|    40/   52| bits: 0.36
#   2020-05-26 15:20:59|    50/   52| bits: 0.20
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.15
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:21:03|     0/   52| bits: 0.19
#   2020-05-26 15:21:03|    10/   52| bits: 0.10
#   2020-05-26 15:21:03|    20/   52| bits: 0.06
#   2020-05-26 15:21:03|    30/   52| bits: 0.04
#   2020-05-26 15:21:03|    40/   52| bits: 0.03
#   2020-05-26 15:21:03|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:21:07|     0/   52| bits: 26.17
#   2020-05-26 15:21:07|    10/   52| bits: 12.87
#   2020-05-26 15:21:07|    20/   52| bits: 8.08
#   2020-05-26 15:21:07|    30/   52| bits: 4.95
#   2020-05-26 15:21:07|    40/   52| bits: 3.05
#   2020-05-26 15:21:07|    50/   52| bits: 1.87
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.37
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:21:11|     0/   52| bits: 1.70
#   2020-05-26 15:21:11|    10/   52| bits: 0.95
#   2020-05-26 15:21:11|    20/   52| bits: 0.55
#   2020-05-26 15:21:11|    30/   52| bits: 0.31
#   2020-05-26 15:21:11|    40/   52| bits: 0.19
#   2020-05-26 15:21:11|    50/   52| bits: 0.11
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.08
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:21:15|     0/   52| bits: 0.10
#   2020-05-26 15:21:15|    10/   52| bits: 0.07
#   2020-05-26 15:21:15|    20/   52| bits: 0.04
#   2020-05-26 15:21:15|    30/   52| bits: 0.03
#   2020-05-26 15:21:15|    40/   52| bits: 0.03
#   2020-05-26 15:21:15|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for d:  15
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:21:19|     0/   52| bits: 23.92
#   2020-05-26 15:21:19|    10/   52| bits: 13.69
#   2020-05-26 15:21:19|    20/   52| bits: 7.76
#   2020-05-26 15:21:19|    30/   52| bits: 4.27
#   2020-05-26 15:21:19|    40/   52| bits: 2.24
#   2020-05-26 15:21:19|    50/   52| bits: 1.09
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.93
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:21:23|     0/   52| bits: 0.94
#   2020-05-26 15:21:23|    10/   52| bits: 0.45
#   2020-05-26 15:21:23|    20/   52| bits: 0.22
#   2020-05-26 15:21:23|    30/   52| bits: 0.12
#   2020-05-26 15:21:23|    40/   52| bits: 0.07
#   2020-05-26 15:21:23|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:21:27|     0/   52| bits: 0.03
#   2020-05-26 15:21:27|    10/   52| bits: 0.02
#   2020-05-26 15:21:27|    20/   52| bits: 0.02
#   2020-05-26 15:21:27|    30/   52| bits: 0.01
#   2020-05-26 15:21:27|    40/   52| bits: 0.01
#   2020-05-26 15:21:27|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:21:31|     0/   52| bits: 22.52
#   2020-05-26 15:21:31|    10/   52| bits: 12.90
#   2020-05-26 15:21:32|    20/   52| bits: 8.14
#   2020-05-26 15:21:32|    30/   52| bits: 4.92
#   2020-05-26 15:21:32|    40/   52| bits: 2.88
#   2020-05-26 15:21:32|    50/   52| bits: 1.58
# Elapsed time: 0h 0m 2s
# Validation| bits: 1.30
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:21:35|     0/   52| bits: 1.42
#   2020-05-26 15:21:35|    10/   52| bits: 0.72
#   2020-05-26 15:21:35|    20/   52| bits: 0.36
#   2020-05-26 15:21:35|    30/   52| bits: 0.17
#   2020-05-26 15:21:36|    40/   52| bits: 0.09
#   2020-05-26 15:21:36|    50/   52| bits: 0.06
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:21:39|     0/   52| bits: 0.04
#   2020-05-26 15:21:39|    10/   52| bits: 0.03
#   2020-05-26 15:21:39|    20/   52| bits: 0.02
#   2020-05-26 15:21:39|    30/   52| bits: 0.02
#   2020-05-26 15:21:39|    40/   52| bits: 0.02
#   2020-05-26 15:21:40|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 15:21:44|     0/   52| bits: 19.76
#   2020-05-26 15:21:44|    10/   52| bits: 11.51
#   2020-05-26 15:21:44|    20/   52| bits: 7.92
#   2020-05-26 15:21:44|    30/   52| bits: 5.50
#   2020-05-26 15:21:44|    40/   52| bits: 3.68
#   2020-05-26 15:21:44|    50/   52| bits: 2.32
# Elapsed time: 0h 0m 2s
# Validation| bits: 2.01
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 15:21:48|     0/   52| bits: 2.09
#   2020-05-26 15:21:48|    10/   52| bits: 1.20
#   2020-05-26 15:21:48|    20/   52| bits: 0.67
#   2020-05-26 15:21:48|    30/   52| bits: 0.36
#   2020-05-26 15:21:48|    40/   52| bits: 0.20
#   2020-05-26 15:21:48|    50/   52| bits: 0.11
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.09
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 15:21:52|     0/   52| bits: 0.10
#   2020-05-26 15:21:52|    10/   52| bits: 0.06
#   2020-05-26 15:21:52|    20/   52| bits: 0.04
#   2020-05-26 15:21:52|    30/   52| bits: 0.02
#   2020-05-26 15:21:53|    40/   52| bits: 0.02
#   2020-05-26 15:21:53|    50/   52| bits: 0.02
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01

# %%
plt.figure(figsize = (20,12))
plt.plot(depths, error)
plt.ylabel('MSE')
plt.xlabel('Number of hidden layers (each 32 nodes)')
plt.show()
