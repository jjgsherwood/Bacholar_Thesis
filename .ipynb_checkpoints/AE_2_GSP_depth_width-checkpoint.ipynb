# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_array, check_is_fitted

import numpy as np
import matplotlib.pyplot as plt
import os
import copy
import inspect
import random
import shutil

from datetime import datetime
from dateutil.relativedelta import relativedelta

from scipy import optimize, ndimage
from sklearn import decomposition, cluster, model_selection, metrics
import sklearn

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import utils.dataset_utils as dataset
import utils.train_utils as train

import numpy.polynomial.polynomial as poly

# %%
def unit_vector_norm(X):
    return (X.T / np.sqrt((X**2).sum(axis=1))).T

def split_Raman_af(X):
    """
    Removing spikes from the data to extract the autofluorescence.
    This is done by applying smoothing filter to the data and then taking the min of the smoothing filter and original data.
    """
    a = X
    c = 50

    # remove the top of the spikes from data, by using a Gaussian smoothing filter
    for _ in range(5):      
        a[:,c] = X[:,c]
        a[:,-c] = X[:,-c]      
        a1 = ndimage.gaussian_filter(a, (0, 30), mode='nearest')
        a = np.min([a, a1], axis=0)

    # remove the spikes from data, by using a polynominal fit
    for _ in range(5):
        a[:,c] = X[:,c]
        a[:,-c] = X[:,-c]        
        z = poly.polyfit(wavelength[::5], a[:,::5].T, 5)
        a1 = poly.polyval(wavelength, z)
        a = np.min([a, a1], axis=0)
        
    # smooth the curve the data, (to remove remnants of noise in the photoluminescence signal)
    for _ in range(10):           
        a[:,1] = X[:,1]
        a[:,-1] = X[:,-1]         
        a = ndimage.gaussian_filter(a, (0, 10), mode='nearest')

    # make the Raman signal non-negative, (to remove remnants of noise in the Raman signal)
    return (X-a).clip(min=0), a 

def smoothing(X, smooth=5, transition=10, spike_width=7):
    """
    Only remove noise from low noise to signal area's to maintain the intensity of the spikes.
    Noise is removed with a gaussian filter in spectral dimension.
    """
    grad = ndimage.gaussian_filter(X, (0, 1), order=1)
    grad_abs = np.abs(grad)
    grad_abs_sm = ndimage.gaussian_filter(grad_abs, (0, 5))
    mean_grad = np.mean(grad_abs, 1) + 1 / np.std(grad_abs, 1) * 3
    
    spikes = ((grad_abs_sm.T > mean_grad ).astype(float)).T 
    spikes = np.round(ndimage.gaussian_filter(spikes, (0, spike_width)))
    spikes = ndimage.uniform_filter(spikes, (0, transition))
    
    return (1 - spikes) * ndimage.gaussian_filter(X, (0,smooth)) + spikes * X

class View(nn.Module):
    def __init__(self, shape):
        super().__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)

# %%
N_WAVE = 2126

wavelength = np.load("../data/Raman/wavelength.npy", 'r')

# Z = np.load("../data/Raman/Alina_Art_4_2.npy", 'r')

shape_Z = (70,90,2126)

# Z = copy.copy(Z.reshape(-1, Z.shape[-1]))

# Z_smooth = smoothing(Z)
# ram_Z, afl_Z = split_Raman_af(Z_smooth)

ram_Z = np.load("../data/Raman/Alina_4_ram.npy", 'r')
ram_Z = copy.copy(ram_Z)

# %%
class AutoEncoder(nn.Module):
    def __init__(self, n_components=10, depth=2, neurons=100, bias=True, **kwargs):
        super().__init__()
        self.encode = nn.Sequential( 
            nn.Dropout3d(0.25),
            nn.Flatten(),
            nn.Linear(N_WAVE, neurons, bias=bias),
            nn.ReLU(True),
            *((nn.Linear(neurons, neurons, bias=bias),
            nn.ReLU(True)) * (depth-1)),
            nn.Linear(neurons, n_components, bias=bias),
            nn.Softmax(1),
        )
        
        self.decode = nn.Sequential(
            nn.Linear(n_components, neurons, bias=bias),
            nn.ReLU(True),
            *((nn.Linear(neurons, neurons, bias=bias),
            nn.ReLU(True)) * (depth-1)),            
            nn.Linear(neurons, N_WAVE, bias=bias),
            View((-1,1,1,1,N_WAVE)),
        )
        
    def forward(self, x):
        return self.decode(self.encode(x))

# %%
def MSE_loss(x, model):
    W = model.encode(x)
    x_ = model.decode(W)

    rho = 0.8
    
    reference_spectra_ = W.T @ x.squeeze()
    max_ref_diff = 0
    for i in range(W.size(1)):
        for j in range(i + 1, W.size(1)):
            max_ref_diff += 1 / (torch.abs(reference_spectra_[i] - reference_spectra_[j]).sum())
        
    #MSE loss
    MSE = ((x_ - x)**2).sum(4).mean()  
    
    return rho * MSE + (1 - rho) * max_ref_diff

# %%
class ReferenceVectorClassifierAE(BaseEstimator):
    def __init__(self, **kwargs):
        self.kwargs = {}
        self.ae_kwargs = {}
        self.k_means_kwargs = {}                
        self.set_params(**kwargs)

        _use_cuda = torch.cuda.is_available() and kwargs['cuda']
        if _use_cuda:
            torch.backends.cudnn.enabled = True
            torch.backends.cudnn.benchmark = True
        self.device = torch.device('cuda' if _use_cuda else 'cpu')        
        
    def fit(self, x, **kwargs):
        self.set_params(**kwargs)
        X = unit_vector_norm(x)
        
        ###################### Autoencoder ################################
        self.model = AutoEncoder(**self.ae_kwargs).to(self.device)
        
        parameters = filter(lambda x: x.requires_grad, self.model.parameters())
        self.optimizer = optim.Adam(parameters)        
        train_loader, test_loader = dataset.load_liver(X, self.kwargs['batch_size'])
        
        for epoch in range(self.kwargs['epochs']):
            print('-'*50)
            print('Epoch {:3d}/{:3d}'.format(epoch+1, self.kwargs['epochs']))
            start_time = datetime.now()
            train.train(self.model, self.optimizer, train_loader, self.kwargs['loss_func'], self.kwargs['log_step'], self.device)
            end_time = datetime.now()
            time_diff = relativedelta(end_time, start_time)
            print('Elapsed time: {}h {}m {}s'.format(time_diff.hours, time_diff.minutes, time_diff.seconds))
            loss = train.test(self.model, test_loader, self.kwargs['loss_func'], self.device)
            print('Validation| bits: {:2.2f}'.format(loss), flush=True)    
          
        self.model.eval()
        with torch.no_grad():
            W = self.model.encode(dataset.load_liver_all(X).to(self.device))
        self.z = W
        W = W.cpu().detach().numpy()
        
        ###################### clustering ################################        
        self.clusters = cluster.KMeans(**self.k_means_kwargs).fit(W)
        self.clusters = self.clusters.labels_
        
        one_hot = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        one_hot[range(X.shape[0]), self.clusters] = 1
                          
        ###################### reference spectra ################################
        self.reference_spectra_ = unit_vector_norm(np.array([np.abs(x_) for i, x_ in enumerate(one_hot.T @ X)]))
        self.ref_org = np.array([x[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])
               
        # Return the classifier
        return self
    
    def predict(self, X):
        """
        predict transforms the data into the reference space. Min weight should be 0 or higher then 'min_weight'
        The error is the NMSE, where the MSE is normalised by the signal strength. 
        error.shape = X.shape[0], so for each data point the error is calculated.
        """
        # Check is fit had been called
        check_is_fitted(self)

        # Input validation
        X = check_array(X)
        X = unit_vector_norm(X)
        
        ###################### RCA ################################           
        RCA_vector = np.array([optimize.nnls(self.reference_spectra_.T, X[i,:])[0] for i in range(X.shape[0])])

        return RCA_vector
    
    def get_reference_vectors(self):
        return self.reference_spectra_

    def get_org_reference_vectors(self):
        return self.ref_org    
    
    def get_Y(self, X):
        return self.model(dataset.load_liver_all(unit_vector_norm(X)).to(self.device)).squeeze().cpu().detach().numpy()
    
    def get_params(self, deep=False):
        return self.kwargs
    
    def set_params(self, **kwargs):
        self.kwargs.update(kwargs)
        self.k_means_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(cluster.KMeans).parameters.keys())})     
        self.ae_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(AutoEncoder).parameters.keys())})     
        return self

# %%
def error_map(estimator, X, y=None):
    Y = estimator.get_Y(X)
    return ((Y - X)**2).sum(1)

def score_func(estimator, X, y=None):
    tmp = np.sqrt((X**2).sum(axis=1))
    X = unit_vector_norm(X)
    return (error_map(estimator, X) * tmp).mean()

def print_mean_std(X):
    return f"{X.mean():<12.4e}{X.std():<12.4e}"

def cross_val_X_Y_Z(rvc, X, Y, Z):
    rvc.fit(np.concatenate((X, Y), axis=0))
    return score_func(rvc, Z)

# %%
kwargs = {'n_components': 3,
          'n_clusters': 3,
          'batch_size': 32,
          'cuda': True,
          'log_step': 30,
          'loss_func': MSE_loss,
          'epochs': 20,
          'depth': 3,
          'neurons': 2126,
          'bias': True
         }

# %%
score = []
for i in range(10):
    print(i)
    rvc = ReferenceVectorClassifierAE(**kwargs)
    rvc.fit(ram_Z)
    score.append(score_func(rvc, ram_Z))
print(score)
print(np.mean(score), np.std(score))
del score[np.argmax(score)]
del score[np.argmin(score)]
print(score)
print(np.mean(score), np.std(score))
# Out:
# 0
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:29:40|     0/  178| bits: 3.60
#   2020-07-19 11:29:41|    30/  178| bits: 0.12
#   2020-07-19 11:29:42|    60/  178| bits: 0.04
#   2020-07-19 11:29:42|    90/  178| bits: 0.09
#   2020-07-19 11:29:43|   120/  178| bits: 0.10
#   2020-07-19 11:29:44|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:29:48|     0/  178| bits: 0.02
#   2020-07-19 11:29:49|    30/  178| bits: 0.02
#   2020-07-19 11:29:49|    60/  178| bits: 0.05
#   2020-07-19 11:29:50|    90/  178| bits: 0.07
#   2020-07-19 11:29:51|   120/  178| bits: 0.07
#   2020-07-19 11:29:51|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:29:55|     0/  178| bits: 0.04
#   2020-07-19 11:29:56|    30/  178| bits: 0.06
#   2020-07-19 11:29:57|    60/  178| bits: 0.01
#   2020-07-19 11:29:57|    90/  178| bits: 0.06
#   2020-07-19 11:29:58|   120/  178| bits: 0.05
#   2020-07-19 11:29:59|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:30:03|     0/  178| bits: 0.03
#   2020-07-19 11:30:04|    30/  178| bits: 0.04
#   2020-07-19 11:30:04|    60/  178| bits: 0.02
#   2020-07-19 11:30:05|    90/  178| bits: 0.04
#   2020-07-19 11:30:05|   120/  178| bits: 0.02
#   2020-07-19 11:30:06|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:30:11|     0/  178| bits: 0.03
#   2020-07-19 11:30:11|    30/  178| bits: 0.04
#   2020-07-19 11:30:12|    60/  178| bits: 0.02
#   2020-07-19 11:30:13|    90/  178| bits: 0.05
#   2020-07-19 11:30:13|   120/  178| bits: 0.03
#   2020-07-19 11:30:14|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:30:18|     0/  178| bits: 0.02
#   2020-07-19 11:30:19|    30/  178| bits: 0.03
#   2020-07-19 11:30:19|    60/  178| bits: 0.08
#   2020-07-19 11:30:20|    90/  178| bits: 0.04
#   2020-07-19 11:30:21|   120/  178| bits: 0.03
#   2020-07-19 11:30:21|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:30:26|     0/  178| bits: 0.05
#   2020-07-19 11:30:26|    30/  178| bits: 0.05
#   2020-07-19 11:30:27|    60/  178| bits: 0.04
#   2020-07-19 11:30:28|    90/  178| bits: 0.02
#   2020-07-19 11:30:28|   120/  178| bits: 0.02
#   2020-07-19 11:30:29|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:30:33|     0/  178| bits: 0.03
#   2020-07-19 11:30:34|    30/  178| bits: 0.04
#   2020-07-19 11:30:34|    60/  178| bits: 0.04
#   2020-07-19 11:30:35|    90/  178| bits: 0.05
#   2020-07-19 11:30:36|   120/  178| bits: 0.02
#   2020-07-19 11:30:36|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:30:41|     0/  178| bits: 0.07
#   2020-07-19 11:30:41|    30/  178| bits: 0.02
#   2020-07-19 11:30:42|    60/  178| bits: 0.04
#   2020-07-19 11:30:43|    90/  178| bits: 0.01
#   2020-07-19 11:30:43|   120/  178| bits: 0.01
#   2020-07-19 11:30:44|   150/  178| bits: 0.10
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:30:48|     0/  178| bits: 0.01
#   2020-07-19 11:30:49|    30/  178| bits: 0.03
#   2020-07-19 11:30:49|    60/  178| bits: 0.04
#   2020-07-19 11:30:50|    90/  178| bits: 0.02
#   2020-07-19 11:30:51|   120/  178| bits: 0.04
#   2020-07-19 11:30:51|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:30:56|     0/  178| bits: 0.01
#   2020-07-19 11:30:56|    30/  178| bits: 0.03
#   2020-07-19 11:30:57|    60/  178| bits: 0.06
#   2020-07-19 11:30:58|    90/  178| bits: 0.06
#   2020-07-19 11:30:58|   120/  178| bits: 0.04
#   2020-07-19 11:30:59|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:31:03|     0/  178| bits: 0.03
#   2020-07-19 11:31:04|    30/  178| bits: 0.05
#   2020-07-19 11:31:04|    60/  178| bits: 0.02
#   2020-07-19 11:31:05|    90/  178| bits: 0.04
#   2020-07-19 11:31:06|   120/  178| bits: 0.01
#   2020-07-19 11:31:06|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:31:11|     0/  178| bits: 0.01
#   2020-07-19 11:31:11|    30/  178| bits: 0.04
#   2020-07-19 11:31:12|    60/  178| bits: 0.02
#   2020-07-19 11:31:13|    90/  178| bits: 0.01
#   2020-07-19 11:31:13|   120/  178| bits: 0.04
#   2020-07-19 11:31:14|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:31:18|     0/  178| bits: 0.02
#   2020-07-19 11:31:19|    30/  178| bits: 0.01
#   2020-07-19 11:31:19|    60/  178| bits: 0.01
#   2020-07-19 11:31:20|    90/  178| bits: 0.03
#   2020-07-19 11:31:21|   120/  178| bits: 0.02
#   2020-07-19 11:31:21|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:31:26|     0/  178| bits: 0.03
#   2020-07-19 11:31:26|    30/  178| bits: 0.04
#   2020-07-19 11:31:27|    60/  178| bits: 0.02
#   2020-07-19 11:31:28|    90/  178| bits: 0.01
#   2020-07-19 11:31:28|   120/  178| bits: 0.02
#   2020-07-19 11:31:29|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:31:33|     0/  178| bits: 0.01
#   2020-07-19 11:31:34|    30/  178| bits: 0.02
#   2020-07-19 11:31:35|    60/  178| bits: 0.03
#   2020-07-19 11:31:35|    90/  178| bits: 0.04
#   2020-07-19 11:31:36|   120/  178| bits: 0.03
#   2020-07-19 11:31:37|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:31:41|     0/  178| bits: 0.01
#   2020-07-19 11:31:42|    30/  178| bits: 0.04
#   2020-07-19 11:31:43|    60/  178| bits: 0.02
#   2020-07-19 11:31:43|    90/  178| bits: 0.04
#   2020-07-19 11:31:44|   120/  178| bits: 0.03
#   2020-07-19 11:31:45|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:31:49|     0/  178| bits: 0.06
#   2020-07-19 11:31:50|    30/  178| bits: 0.04
#   2020-07-19 11:31:50|    60/  178| bits: 0.02
#   2020-07-19 11:31:51|    90/  178| bits: 0.06
#   2020-07-19 11:31:52|   120/  178| bits: 0.04
#   2020-07-19 11:31:52|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:31:56|     0/  178| bits: 0.02
#   2020-07-19 11:31:57|    30/  178| bits: 0.02
#   2020-07-19 11:31:58|    60/  178| bits: 0.05
#   2020-07-19 11:31:58|    90/  178| bits: 0.01
#   2020-07-19 11:31:59|   120/  178| bits: 0.06
#   2020-07-19 11:32:00|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:32:04|     0/  178| bits: 0.05
#   2020-07-19 11:32:05|    30/  178| bits: 0.03
#   2020-07-19 11:32:05|    60/  178| bits: 0.04
#   2020-07-19 11:32:06|    90/  178| bits: 0.02
#   2020-07-19 11:32:07|   120/  178| bits: 0.01
#   2020-07-19 11:32:07|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# 1
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:32:13|     0/  178| bits: 3.74
#   2020-07-19 11:32:13|    30/  178| bits: 0.09
#   2020-07-19 11:32:14|    60/  178| bits: 0.11
#   2020-07-19 11:32:15|    90/  178| bits: 0.09
#   2020-07-19 11:32:15|   120/  178| bits: 0.05
#   2020-07-19 11:32:16|   150/  178| bits: 0.09
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:32:20|     0/  178| bits: 0.04
#   2020-07-19 11:32:21|    30/  178| bits: 0.07
#   2020-07-19 11:32:22|    60/  178| bits: 0.05
#   2020-07-19 11:32:22|    90/  178| bits: 0.02
#   2020-07-19 11:32:23|   120/  178| bits: 0.04
#   2020-07-19 11:32:24|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:32:28|     0/  178| bits: 0.03
#   2020-07-19 11:32:29|    30/  178| bits: 0.06
#   2020-07-19 11:32:30|    60/  178| bits: 0.02
#   2020-07-19 11:32:30|    90/  178| bits: 0.06
#   2020-07-19 11:32:31|   120/  178| bits: 0.03
#   2020-07-19 11:32:32|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:32:36|     0/  178| bits: 0.09
#   2020-07-19 11:32:36|    30/  178| bits: 0.03
#   2020-07-19 11:32:37|    60/  178| bits: 0.05
#   2020-07-19 11:32:38|    90/  178| bits: 0.02
#   2020-07-19 11:32:38|   120/  178| bits: 0.05
#   2020-07-19 11:32:39|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:32:43|     0/  178| bits: 0.06
#   2020-07-19 11:32:44|    30/  178| bits: 0.04
#   2020-07-19 11:32:45|    60/  178| bits: 0.01
#   2020-07-19 11:32:45|    90/  178| bits: 0.09
#   2020-07-19 11:32:46|   120/  178| bits: 0.04
#   2020-07-19 11:32:46|   150/  178| bits: 0.11
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:32:51|     0/  178| bits: 0.03
#   2020-07-19 11:32:51|    30/  178| bits: 0.05
#   2020-07-19 11:32:52|    60/  178| bits: 0.09
#   2020-07-19 11:32:53|    90/  178| bits: 0.03
#   2020-07-19 11:32:53|   120/  178| bits: 0.04
#   2020-07-19 11:32:54|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:32:58|     0/  178| bits: 0.01
#   2020-07-19 11:32:59|    30/  178| bits: 0.02
#   2020-07-19 11:33:00|    60/  178| bits: 0.06
#   2020-07-19 11:33:00|    90/  178| bits: 0.07
#   2020-07-19 11:33:01|   120/  178| bits: 0.05
#   2020-07-19 11:33:01|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:33:06|     0/  178| bits: 0.07
#   2020-07-19 11:33:06|    30/  178| bits: 0.04
#   2020-07-19 11:33:07|    60/  178| bits: 0.05
#   2020-07-19 11:33:08|    90/  178| bits: 0.10
#   2020-07-19 11:33:08|   120/  178| bits: 0.07
#   2020-07-19 11:33:09|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:33:13|     0/  178| bits: 0.04
#   2020-07-19 11:33:14|    30/  178| bits: 0.04
#   2020-07-19 11:33:15|    60/  178| bits: 0.04
#   2020-07-19 11:33:15|    90/  178| bits: 0.04
#   2020-07-19 11:33:16|   120/  178| bits: 0.02
#   2020-07-19 11:33:17|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:33:21|     0/  178| bits: 0.06
#   2020-07-19 11:33:21|    30/  178| bits: 0.02
#   2020-07-19 11:33:22|    60/  178| bits: 0.05
#   2020-07-19 11:33:23|    90/  178| bits: 0.05
#   2020-07-19 11:33:23|   120/  178| bits: 0.04
#   2020-07-19 11:33:24|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:33:28|     0/  178| bits: 0.05
#   2020-07-19 11:33:29|    30/  178| bits: 0.02
#   2020-07-19 11:33:30|    60/  178| bits: 0.02
#   2020-07-19 11:33:30|    90/  178| bits: 0.05
#   2020-07-19 11:33:31|   120/  178| bits: 0.02
#   2020-07-19 11:33:32|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:33:36|     0/  178| bits: 0.04
#   2020-07-19 11:33:37|    30/  178| bits: 0.04
#   2020-07-19 11:33:37|    60/  178| bits: 0.03
#   2020-07-19 11:33:38|    90/  178| bits: 0.02
#   2020-07-19 11:33:38|   120/  178| bits: 0.03
#   2020-07-19 11:33:39|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:33:43|     0/  178| bits: 0.05
#   2020-07-19 11:33:44|    30/  178| bits: 0.06
#   2020-07-19 11:33:45|    60/  178| bits: 0.05
#   2020-07-19 11:33:45|    90/  178| bits: 0.07
#   2020-07-19 11:33:46|   120/  178| bits: 0.04
#   2020-07-19 11:33:47|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:33:51|     0/  178| bits: 0.02
#   2020-07-19 11:33:52|    30/  178| bits: 0.02
#   2020-07-19 11:33:52|    60/  178| bits: 0.04
#   2020-07-19 11:33:53|    90/  178| bits: 0.04
#   2020-07-19 11:33:54|   120/  178| bits: 0.03
#   2020-07-19 11:33:54|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:33:58|     0/  178| bits: 0.02
#   2020-07-19 11:33:59|    30/  178| bits: 0.05
#   2020-07-19 11:34:00|    60/  178| bits: 0.03
#   2020-07-19 11:34:00|    90/  178| bits: 0.03
#   2020-07-19 11:34:01|   120/  178| bits: 0.03
#   2020-07-19 11:34:02|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:34:06|     0/  178| bits: 0.02
#   2020-07-19 11:34:07|    30/  178| bits: 0.03
#   2020-07-19 11:34:07|    60/  178| bits: 0.02
#   2020-07-19 11:34:08|    90/  178| bits: 0.02
#   2020-07-19 11:34:08|   120/  178| bits: 0.07
#   2020-07-19 11:34:09|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:34:13|     0/  178| bits: 0.06
#   2020-07-19 11:34:14|    30/  178| bits: 0.03
#   2020-07-19 11:34:15|    60/  178| bits: 0.01
#   2020-07-19 11:34:15|    90/  178| bits: 0.05
#   2020-07-19 11:34:16|   120/  178| bits: 0.03
#   2020-07-19 11:34:17|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:34:21|     0/  178| bits: 0.02
#   2020-07-19 11:34:21|    30/  178| bits: 0.04
#   2020-07-19 11:34:22|    60/  178| bits: 0.02
#   2020-07-19 11:34:23|    90/  178| bits: 0.04
#   2020-07-19 11:34:23|   120/  178| bits: 0.06
#   2020-07-19 11:34:24|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:34:28|     0/  178| bits: 0.04
#   2020-07-19 11:34:29|    30/  178| bits: 0.02
#   2020-07-19 11:34:30|    60/  178| bits: 0.08
#   2020-07-19 11:34:30|    90/  178| bits: 0.05
#   2020-07-19 11:34:31|   120/  178| bits: 0.04
#   2020-07-19 11:34:31|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:34:36|     0/  178| bits: 0.05
#   2020-07-19 11:34:36|    30/  178| bits: 0.04
#   2020-07-19 11:34:37|    60/  178| bits: 0.03
#   2020-07-19 11:34:38|    90/  178| bits: 0.04
#   2020-07-19 11:34:38|   120/  178| bits: 0.02
#   2020-07-19 11:34:39|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# 2
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:34:44|     0/  178| bits: 2.67
#   2020-07-19 11:34:45|    30/  178| bits: 0.09
#   2020-07-19 11:34:46|    60/  178| bits: 0.05
#   2020-07-19 11:34:46|    90/  178| bits: 0.07
#   2020-07-19 11:34:47|   120/  178| bits: 0.07
#   2020-07-19 11:34:48|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:34:52|     0/  178| bits: 0.02
#   2020-07-19 11:34:52|    30/  178| bits: 0.13
#   2020-07-19 11:34:53|    60/  178| bits: 0.06
#   2020-07-19 11:34:54|    90/  178| bits: 0.02
#   2020-07-19 11:34:54|   120/  178| bits: 0.05
#   2020-07-19 11:34:55|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:34:59|     0/  178| bits: 0.06
#   2020-07-19 11:35:00|    30/  178| bits: 0.02
#   2020-07-19 11:35:01|    60/  178| bits: 0.02
#   2020-07-19 11:35:01|    90/  178| bits: 0.06
#   2020-07-19 11:35:02|   120/  178| bits: 0.03
#   2020-07-19 11:35:02|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:35:07|     0/  178| bits: 0.02
#   2020-07-19 11:35:07|    30/  178| bits: 0.06
#   2020-07-19 11:35:08|    60/  178| bits: 0.06
#   2020-07-19 11:35:09|    90/  178| bits: 0.02
#   2020-07-19 11:35:09|   120/  178| bits: 0.03
#   2020-07-19 11:35:10|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:35:14|     0/  178| bits: 0.02
#   2020-07-19 11:35:15|    30/  178| bits: 0.02
#   2020-07-19 11:35:15|    60/  178| bits: 0.02
#   2020-07-19 11:35:16|    90/  178| bits: 0.05
#   2020-07-19 11:35:17|   120/  178| bits: 0.03
#   2020-07-19 11:35:17|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:35:22|     0/  178| bits: 0.08
#   2020-07-19 11:35:22|    30/  178| bits: 0.02
#   2020-07-19 11:35:23|    60/  178| bits: 0.05
#   2020-07-19 11:35:24|    90/  178| bits: 0.04
#   2020-07-19 11:35:24|   120/  178| bits: 0.06
#   2020-07-19 11:35:25|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:35:29|     0/  178| bits: 0.02
#   2020-07-19 11:35:30|    30/  178| bits: 0.02
#   2020-07-19 11:35:30|    60/  178| bits: 0.04
#   2020-07-19 11:35:31|    90/  178| bits: 0.03
#   2020-07-19 11:35:32|   120/  178| bits: 0.03
#   2020-07-19 11:35:32|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:35:36|     0/  178| bits: 0.03
#   2020-07-19 11:35:37|    30/  178| bits: 0.03
#   2020-07-19 11:35:38|    60/  178| bits: 0.02
#   2020-07-19 11:35:38|    90/  178| bits: 0.06
#   2020-07-19 11:35:39|   120/  178| bits: 0.01
#   2020-07-19 11:35:40|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:35:44|     0/  178| bits: 0.02
#   2020-07-19 11:35:45|    30/  178| bits: 0.07
#   2020-07-19 11:35:45|    60/  178| bits: 0.07
#   2020-07-19 11:35:46|    90/  178| bits: 0.02
#   2020-07-19 11:35:46|   120/  178| bits: 0.02
#   2020-07-19 11:35:47|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:35:51|     0/  178| bits: 0.03
#   2020-07-19 11:35:52|    30/  178| bits: 0.06
#   2020-07-19 11:35:53|    60/  178| bits: 0.11
#   2020-07-19 11:35:53|    90/  178| bits: 0.06
#   2020-07-19 11:35:54|   120/  178| bits: 0.01
#   2020-07-19 11:35:55|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:35:59|     0/  178| bits: 0.08
#   2020-07-19 11:36:00|    30/  178| bits: 0.03
#   2020-07-19 11:36:00|    60/  178| bits: 0.02
#   2020-07-19 11:36:01|    90/  178| bits: 0.06
#   2020-07-19 11:36:01|   120/  178| bits: 0.03
#   2020-07-19 11:36:02|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:36:06|     0/  178| bits: 0.05
#   2020-07-19 11:36:07|    30/  178| bits: 0.06
#   2020-07-19 11:36:08|    60/  178| bits: 0.02
#   2020-07-19 11:36:08|    90/  178| bits: 0.02
#   2020-07-19 11:36:09|   120/  178| bits: 0.03
#   2020-07-19 11:36:10|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:36:14|     0/  178| bits: 0.02
#   2020-07-19 11:36:14|    30/  178| bits: 0.03
#   2020-07-19 11:36:15|    60/  178| bits: 0.02
#   2020-07-19 11:36:16|    90/  178| bits: 0.03
#   2020-07-19 11:36:16|   120/  178| bits: 0.01
#   2020-07-19 11:36:17|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:36:21|     0/  178| bits: 0.07
#   2020-07-19 11:36:22|    30/  178| bits: 0.06
#   2020-07-19 11:36:23|    60/  178| bits: 0.02
#   2020-07-19 11:36:23|    90/  178| bits: 0.05
#   2020-07-19 11:36:24|   120/  178| bits: 0.06
#   2020-07-19 11:36:25|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:36:29|     0/  178| bits: 0.05
#   2020-07-19 11:36:29|    30/  178| bits: 0.04
#   2020-07-19 11:36:30|    60/  178| bits: 0.08
#   2020-07-19 11:36:31|    90/  178| bits: 0.02
#   2020-07-19 11:36:31|   120/  178| bits: 0.07
#   2020-07-19 11:36:32|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:36:36|     0/  178| bits: 0.09
#   2020-07-19 11:36:37|    30/  178| bits: 0.02
#   2020-07-19 11:36:38|    60/  178| bits: 0.04
#   2020-07-19 11:36:38|    90/  178| bits: 0.07
#   2020-07-19 11:36:39|   120/  178| bits: 0.05
#   2020-07-19 11:36:40|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:36:44|     0/  178| bits: 0.03
#   2020-07-19 11:36:44|    30/  178| bits: 0.03
#   2020-07-19 11:36:45|    60/  178| bits: 0.03
#   2020-07-19 11:36:46|    90/  178| bits: 0.02
#   2020-07-19 11:36:46|   120/  178| bits: 0.03
#   2020-07-19 11:36:47|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:36:51|     0/  178| bits: 0.02
#   2020-07-19 11:36:52|    30/  178| bits: 0.04
#   2020-07-19 11:36:52|    60/  178| bits: 0.07
#   2020-07-19 11:36:53|    90/  178| bits: 0.02
#   2020-07-19 11:36:54|   120/  178| bits: 0.06
#   2020-07-19 11:36:54|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:36:59|     0/  178| bits: 0.04
#   2020-07-19 11:36:59|    30/  178| bits: 0.02
#   2020-07-19 11:37:00|    60/  178| bits: 0.04
#   2020-07-19 11:37:01|    90/  178| bits: 0.02
#   2020-07-19 11:37:01|   120/  178| bits: 0.06
#   2020-07-19 11:37:02|   150/  178| bits: 0.09
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:37:06|     0/  178| bits: 0.06
#   2020-07-19 11:37:07|    30/  178| bits: 0.02
#   2020-07-19 11:37:08|    60/  178| bits: 0.08
#   2020-07-19 11:37:08|    90/  178| bits: 0.05
#   2020-07-19 11:37:09|   120/  178| bits: 0.03
#   2020-07-19 11:37:10|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# 3
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:37:15|     0/  178| bits: 2.69
#   2020-07-19 11:37:16|    30/  178| bits: 0.10
#   2020-07-19 11:37:16|    60/  178| bits: 0.07
#   2020-07-19 11:37:17|    90/  178| bits: 0.06
#   2020-07-19 11:37:18|   120/  178| bits: 0.03
#   2020-07-19 11:37:18|   150/  178| bits: 0.09
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:37:23|     0/  178| bits: 0.04
#   2020-07-19 11:37:23|    30/  178| bits: 0.03
#   2020-07-19 11:37:24|    60/  178| bits: 0.04
#   2020-07-19 11:37:25|    90/  178| bits: 0.02
#   2020-07-19 11:37:25|   120/  178| bits: 0.07
#   2020-07-19 11:37:26|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:37:30|     0/  178| bits: 0.08
#   2020-07-19 11:37:31|    30/  178| bits: 0.03
#   2020-07-19 11:37:32|    60/  178| bits: 0.05
#   2020-07-19 11:37:32|    90/  178| bits: 0.03
#   2020-07-19 11:37:33|   120/  178| bits: 0.03
#   2020-07-19 11:37:34|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:37:38|     0/  178| bits: 0.02
#   2020-07-19 11:37:39|    30/  178| bits: 0.05
#   2020-07-19 11:37:40|    60/  178| bits: 0.06
#   2020-07-19 11:37:40|    90/  178| bits: 0.07
#   2020-07-19 11:37:41|   120/  178| bits: 0.05
#   2020-07-19 11:37:42|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:37:46|     0/  178| bits: 0.04
#   2020-07-19 11:37:46|    30/  178| bits: 0.06
#   2020-07-19 11:37:47|    60/  178| bits: 0.03
#   2020-07-19 11:37:48|    90/  178| bits: 0.04
#   2020-07-19 11:37:48|   120/  178| bits: 0.06
#   2020-07-19 11:37:49|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:37:53|     0/  178| bits: 0.02
#   2020-07-19 11:37:54|    30/  178| bits: 0.04
#   2020-07-19 11:37:55|    60/  178| bits: 0.02
#   2020-07-19 11:37:55|    90/  178| bits: 0.03
#   2020-07-19 11:37:56|   120/  178| bits: 0.01
#   2020-07-19 11:37:57|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:38:01|     0/  178| bits: 0.03
#   2020-07-19 11:38:02|    30/  178| bits: 0.04
#   2020-07-19 11:38:02|    60/  178| bits: 0.04
#   2020-07-19 11:38:03|    90/  178| bits: 0.04
#   2020-07-19 11:38:04|   120/  178| bits: 0.07
#   2020-07-19 11:38:04|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:38:09|     0/  178| bits: 0.03
#   2020-07-19 11:38:10|    30/  178| bits: 0.03
#   2020-07-19 11:38:10|    60/  178| bits: 0.04
#   2020-07-19 11:38:11|    90/  178| bits: 0.02
#   2020-07-19 11:38:12|   120/  178| bits: 0.01
#   2020-07-19 11:38:12|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 6s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:38:17|     0/  178| bits: 0.03
#   2020-07-19 11:38:17|    30/  178| bits: 0.05
#   2020-07-19 11:38:18|    60/  178| bits: 0.03
#   2020-07-19 11:38:18|    90/  178| bits: 0.01
#   2020-07-19 11:38:19|   120/  178| bits: 0.02
#   2020-07-19 11:38:20|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:38:24|     0/  178| bits: 0.02
#   2020-07-19 11:38:25|    30/  178| bits: 0.04
#   2020-07-19 11:38:26|    60/  178| bits: 0.06
#   2020-07-19 11:38:26|    90/  178| bits: 0.05
#   2020-07-19 11:38:27|   120/  178| bits: 0.04
#   2020-07-19 11:38:28|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:38:32|     0/  178| bits: 0.05
#   2020-07-19 11:38:33|    30/  178| bits: 0.01
#   2020-07-19 11:38:33|    60/  178| bits: 0.07
#   2020-07-19 11:38:34|    90/  178| bits: 0.03
#   2020-07-19 11:38:35|   120/  178| bits: 0.02
#   2020-07-19 11:38:35|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:38:40|     0/  178| bits: 0.01
#   2020-07-19 11:38:40|    30/  178| bits: 0.03
#   2020-07-19 11:38:41|    60/  178| bits: 0.03
#   2020-07-19 11:38:42|    90/  178| bits: 0.04
#   2020-07-19 11:38:42|   120/  178| bits: 0.04
#   2020-07-19 11:38:43|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:38:47|     0/  178| bits: 0.02
#   2020-07-19 11:38:48|    30/  178| bits: 0.05
#   2020-07-19 11:38:48|    60/  178| bits: 0.03
#   2020-07-19 11:38:49|    90/  178| bits: 0.02
#   2020-07-19 11:38:50|   120/  178| bits: 0.06
#   2020-07-19 11:38:50|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:38:54|     0/  178| bits: 0.01
#   2020-07-19 11:38:55|    30/  178| bits: 0.06
#   2020-07-19 11:38:56|    60/  178| bits: 0.08
#   2020-07-19 11:38:56|    90/  178| bits: 0.04
#   2020-07-19 11:38:57|   120/  178| bits: 0.03
#   2020-07-19 11:38:58|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:39:02|     0/  178| bits: 0.01
#   2020-07-19 11:39:02|    30/  178| bits: 0.04
#   2020-07-19 11:39:03|    60/  178| bits: 0.02
#   2020-07-19 11:39:04|    90/  178| bits: 0.04
#   2020-07-19 11:39:04|   120/  178| bits: 0.06
#   2020-07-19 11:39:05|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:39:10|     0/  178| bits: 0.06
#   2020-07-19 11:39:10|    30/  178| bits: 0.03
#   2020-07-19 11:39:11|    60/  178| bits: 0.02
#   2020-07-19 11:39:12|    90/  178| bits: 0.01
#   2020-07-19 11:39:12|   120/  178| bits: 0.01
#   2020-07-19 11:39:13|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:39:17|     0/  178| bits: 0.02
#   2020-07-19 11:39:18|    30/  178| bits: 0.03
#   2020-07-19 11:39:18|    60/  178| bits: 0.01
#   2020-07-19 11:39:19|    90/  178| bits: 0.02
#   2020-07-19 11:39:20|   120/  178| bits: 0.04
#   2020-07-19 11:39:20|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:39:24|     0/  178| bits: 0.01
#   2020-07-19 11:39:25|    30/  178| bits: 0.01
#   2020-07-19 11:39:26|    60/  178| bits: 0.01
#   2020-07-19 11:39:26|    90/  178| bits: 0.03
#   2020-07-19 11:39:27|   120/  178| bits: 0.01
#   2020-07-19 11:39:28|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:39:32|     0/  178| bits: 0.04
#   2020-07-19 11:39:32|    30/  178| bits: 0.07
#   2020-07-19 11:39:33|    60/  178| bits: 0.01
#   2020-07-19 11:39:34|    90/  178| bits: 0.01
#   2020-07-19 11:39:34|   120/  178| bits: 0.01
#   2020-07-19 11:39:35|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:39:39|     0/  178| bits: 0.02
#   2020-07-19 11:39:40|    30/  178| bits: 0.01
#   2020-07-19 11:39:40|    60/  178| bits: 0.03
#   2020-07-19 11:39:41|    90/  178| bits: 0.03
#   2020-07-19 11:39:42|   120/  178| bits: 0.04
#   2020-07-19 11:39:42|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.01
# 4
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:39:47|     0/  178| bits: 4.19
#   2020-07-19 11:39:48|    30/  178| bits: 0.13
#   2020-07-19 11:39:49|    60/  178| bits: 0.07
#   2020-07-19 11:39:49|    90/  178| bits: 0.02
#   2020-07-19 11:39:50|   120/  178| bits: 0.07
#   2020-07-19 11:39:51|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:39:55|     0/  178| bits: 0.09
#   2020-07-19 11:39:56|    30/  178| bits: 0.07
#   2020-07-19 11:39:56|    60/  178| bits: 0.04
#   2020-07-19 11:39:57|    90/  178| bits: 0.04
#   2020-07-19 11:39:57|   120/  178| bits: 0.06
#   2020-07-19 11:39:58|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:40:02|     0/  178| bits: 0.06
#   2020-07-19 11:40:03|    30/  178| bits: 0.02
#   2020-07-19 11:40:04|    60/  178| bits: 0.03
#   2020-07-19 11:40:04|    90/  178| bits: 0.05
#   2020-07-19 11:40:05|   120/  178| bits: 0.01
#   2020-07-19 11:40:06|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:40:10|     0/  178| bits: 0.09
#   2020-07-19 11:40:10|    30/  178| bits: 0.03
#   2020-07-19 11:40:11|    60/  178| bits: 0.04
#   2020-07-19 11:40:12|    90/  178| bits: 0.03
#   2020-07-19 11:40:12|   120/  178| bits: 0.02
#   2020-07-19 11:40:13|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:40:17|     0/  178| bits: 0.01
#   2020-07-19 11:40:18|    30/  178| bits: 0.05
#   2020-07-19 11:40:18|    60/  178| bits: 0.02
#   2020-07-19 11:40:19|    90/  178| bits: 0.02
#   2020-07-19 11:40:20|   120/  178| bits: 0.05
#   2020-07-19 11:40:20|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:40:25|     0/  178| bits: 0.03
#   2020-07-19 11:40:25|    30/  178| bits: 0.04
#   2020-07-19 11:40:26|    60/  178| bits: 0.02
#   2020-07-19 11:40:27|    90/  178| bits: 0.07
#   2020-07-19 11:40:27|   120/  178| bits: 0.04
#   2020-07-19 11:40:28|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:40:32|     0/  178| bits: 0.05
#   2020-07-19 11:40:33|    30/  178| bits: 0.04
#   2020-07-19 11:40:33|    60/  178| bits: 0.02
#   2020-07-19 11:40:34|    90/  178| bits: 0.04
#   2020-07-19 11:40:35|   120/  178| bits: 0.07
#   2020-07-19 11:40:35|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:40:40|     0/  178| bits: 0.03
#   2020-07-19 11:40:40|    30/  178| bits: 0.02
#   2020-07-19 11:40:41|    60/  178| bits: 0.03
#   2020-07-19 11:40:42|    90/  178| bits: 0.03
#   2020-07-19 11:40:42|   120/  178| bits: 0.03
#   2020-07-19 11:40:43|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:40:47|     0/  178| bits: 0.05
#   2020-07-19 11:40:48|    30/  178| bits: 0.07
#   2020-07-19 11:40:48|    60/  178| bits: 0.04
#   2020-07-19 11:40:49|    90/  178| bits: 0.05
#   2020-07-19 11:40:50|   120/  178| bits: 0.02
#   2020-07-19 11:40:50|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.05
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:40:55|     0/  178| bits: 0.09
#   2020-07-19 11:40:55|    30/  178| bits: 0.08
#   2020-07-19 11:40:56|    60/  178| bits: 0.06
#   2020-07-19 11:40:56|    90/  178| bits: 0.03
#   2020-07-19 11:40:57|   120/  178| bits: 0.08
#   2020-07-19 11:40:58|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:41:02|     0/  178| bits: 0.02
#   2020-07-19 11:41:03|    30/  178| bits: 0.07
#   2020-07-19 11:41:03|    60/  178| bits: 0.01
#   2020-07-19 11:41:04|    90/  178| bits: 0.02
#   2020-07-19 11:41:05|   120/  178| bits: 0.07
#   2020-07-19 11:41:05|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:41:09|     0/  178| bits: 0.02
#   2020-07-19 11:41:10|    30/  178| bits: 0.03
#   2020-07-19 11:41:11|    60/  178| bits: 0.02
#   2020-07-19 11:41:11|    90/  178| bits: 0.02
#   2020-07-19 11:41:12|   120/  178| bits: 0.04
#   2020-07-19 11:41:13|   150/  178| bits: 0.10
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:41:17|     0/  178| bits: 0.05
#   2020-07-19 11:41:17|    30/  178| bits: 0.02
#   2020-07-19 11:41:18|    60/  178| bits: 0.03
#   2020-07-19 11:41:19|    90/  178| bits: 0.05
#   2020-07-19 11:41:19|   120/  178| bits: 0.02
#   2020-07-19 11:41:20|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:41:24|     0/  178| bits: 0.04
#   2020-07-19 11:41:25|    30/  178| bits: 0.06
#   2020-07-19 11:41:26|    60/  178| bits: 0.03
#   2020-07-19 11:41:26|    90/  178| bits: 0.07
#   2020-07-19 11:41:27|   120/  178| bits: 0.04
#   2020-07-19 11:41:28|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:41:32|     0/  178| bits: 0.05
#   2020-07-19 11:41:32|    30/  178| bits: 0.06
#   2020-07-19 11:41:33|    60/  178| bits: 0.03
#   2020-07-19 11:41:34|    90/  178| bits: 0.10
#   2020-07-19 11:41:34|   120/  178| bits: 0.04
#   2020-07-19 11:41:35|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:41:39|     0/  178| bits: 0.02
#   2020-07-19 11:41:40|    30/  178| bits: 0.01
#   2020-07-19 11:41:41|    60/  178| bits: 0.03
#   2020-07-19 11:41:41|    90/  178| bits: 0.04
#   2020-07-19 11:41:42|   120/  178| bits: 0.01
#   2020-07-19 11:41:43|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:41:47|     0/  178| bits: 0.07
#   2020-07-19 11:41:47|    30/  178| bits: 0.05
#   2020-07-19 11:41:48|    60/  178| bits: 0.02
#   2020-07-19 11:41:49|    90/  178| bits: 0.04
#   2020-07-19 11:41:49|   120/  178| bits: 0.02
#   2020-07-19 11:41:50|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:41:54|     0/  178| bits: 0.01
#   2020-07-19 11:41:55|    30/  178| bits: 0.08
#   2020-07-19 11:41:55|    60/  178| bits: 0.01
#   2020-07-19 11:41:56|    90/  178| bits: 0.01
#   2020-07-19 11:41:57|   120/  178| bits: 0.07
#   2020-07-19 11:41:57|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:42:02|     0/  178| bits: 0.02
#   2020-07-19 11:42:02|    30/  178| bits: 0.03
#   2020-07-19 11:42:03|    60/  178| bits: 0.06
#   2020-07-19 11:42:03|    90/  178| bits: 0.02
#   2020-07-19 11:42:04|   120/  178| bits: 0.02
#   2020-07-19 11:42:05|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:42:09|     0/  178| bits: 0.06
#   2020-07-19 11:42:10|    30/  178| bits: 0.03
#   2020-07-19 11:42:10|    60/  178| bits: 0.02
#   2020-07-19 11:42:11|    90/  178| bits: 0.02
#   2020-07-19 11:42:12|   120/  178| bits: 0.08
#   2020-07-19 11:42:12|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# 5
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:42:17|     0/  178| bits: 2.49
#   2020-07-19 11:42:18|    30/  178| bits: 0.05
#   2020-07-19 11:42:19|    60/  178| bits: 0.04
#   2020-07-19 11:42:19|    90/  178| bits: 0.09
#   2020-07-19 11:42:20|   120/  178| bits: 0.09
#   2020-07-19 11:42:21|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:42:25|     0/  178| bits: 0.10
#   2020-07-19 11:42:26|    30/  178| bits: 0.04
#   2020-07-19 11:42:26|    60/  178| bits: 0.03
#   2020-07-19 11:42:27|    90/  178| bits: 0.08
#   2020-07-19 11:42:28|   120/  178| bits: 0.03
#   2020-07-19 11:42:28|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:42:33|     0/  178| bits: 0.02
#   2020-07-19 11:42:33|    30/  178| bits: 0.07
#   2020-07-19 11:42:34|    60/  178| bits: 0.02
#   2020-07-19 11:42:35|    90/  178| bits: 0.03
#   2020-07-19 11:42:35|   120/  178| bits: 0.05
#   2020-07-19 11:42:36|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:42:40|     0/  178| bits: 0.04
#   2020-07-19 11:42:41|    30/  178| bits: 0.02
#   2020-07-19 11:42:41|    60/  178| bits: 0.05
#   2020-07-19 11:42:42|    90/  178| bits: 0.02
#   2020-07-19 11:42:42|   120/  178| bits: 0.04
#   2020-07-19 11:42:43|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:42:47|     0/  178| bits: 0.05
#   2020-07-19 11:42:48|    30/  178| bits: 0.08
#   2020-07-19 11:42:49|    60/  178| bits: 0.05
#   2020-07-19 11:42:49|    90/  178| bits: 0.05
#   2020-07-19 11:42:50|   120/  178| bits: 0.02
#   2020-07-19 11:42:51|   150/  178| bits: 0.01
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:42:55|     0/  178| bits: 0.03
#   2020-07-19 11:42:55|    30/  178| bits: 0.03
#   2020-07-19 11:42:56|    60/  178| bits: 0.05
#   2020-07-19 11:42:57|    90/  178| bits: 0.02
#   2020-07-19 11:42:57|   120/  178| bits: 0.04
#   2020-07-19 11:42:58|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:43:02|     0/  178| bits: 0.04
#   2020-07-19 11:43:03|    30/  178| bits: 0.04
#   2020-07-19 11:43:03|    60/  178| bits: 0.09
#   2020-07-19 11:43:04|    90/  178| bits: 0.04
#   2020-07-19 11:43:05|   120/  178| bits: 0.04
#   2020-07-19 11:43:05|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:43:10|     0/  178| bits: 0.07
#   2020-07-19 11:43:10|    30/  178| bits: 0.06
#   2020-07-19 11:43:11|    60/  178| bits: 0.08
#   2020-07-19 11:43:11|    90/  178| bits: 0.05
#   2020-07-19 11:43:12|   120/  178| bits: 0.04
#   2020-07-19 11:43:13|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:43:17|     0/  178| bits: 0.02
#   2020-07-19 11:43:18|    30/  178| bits: 0.02
#   2020-07-19 11:43:18|    60/  178| bits: 0.09
#   2020-07-19 11:43:19|    90/  178| bits: 0.03
#   2020-07-19 11:43:20|   120/  178| bits: 0.05
#   2020-07-19 11:43:20|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:43:24|     0/  178| bits: 0.05
#   2020-07-19 11:43:25|    30/  178| bits: 0.07
#   2020-07-19 11:43:26|    60/  178| bits: 0.04
#   2020-07-19 11:43:26|    90/  178| bits: 0.01
#   2020-07-19 11:43:27|   120/  178| bits: 0.04
#   2020-07-19 11:43:28|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:43:32|     0/  178| bits: 0.05
#   2020-07-19 11:43:33|    30/  178| bits: 0.08
#   2020-07-19 11:43:33|    60/  178| bits: 0.04
#   2020-07-19 11:43:34|    90/  178| bits: 0.07
#   2020-07-19 11:43:34|   120/  178| bits: 0.07
#   2020-07-19 11:43:35|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:43:39|     0/  178| bits: 0.04
#   2020-07-19 11:43:40|    30/  178| bits: 0.03
#   2020-07-19 11:43:41|    60/  178| bits: 0.05
#   2020-07-19 11:43:41|    90/  178| bits: 0.04
#   2020-07-19 11:43:42|   120/  178| bits: 0.02
#   2020-07-19 11:43:43|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:43:47|     0/  178| bits: 0.04
#   2020-07-19 11:43:47|    30/  178| bits: 0.07
#   2020-07-19 11:43:48|    60/  178| bits: 0.01
#   2020-07-19 11:43:49|    90/  178| bits: 0.05
#   2020-07-19 11:43:49|   120/  178| bits: 0.04
#   2020-07-19 11:43:50|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:43:54|     0/  178| bits: 0.02
#   2020-07-19 11:43:55|    30/  178| bits: 0.02
#   2020-07-19 11:43:56|    60/  178| bits: 0.04
#   2020-07-19 11:43:56|    90/  178| bits: 0.03
#   2020-07-19 11:43:57|   120/  178| bits: 0.05
#   2020-07-19 11:43:58|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:44:02|     0/  178| bits: 0.06
#   2020-07-19 11:44:02|    30/  178| bits: 0.04
#   2020-07-19 11:44:03|    60/  178| bits: 0.02
#   2020-07-19 11:44:04|    90/  178| bits: 0.03
#   2020-07-19 11:44:04|   120/  178| bits: 0.03
#   2020-07-19 11:44:05|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:44:09|     0/  178| bits: 0.06
#   2020-07-19 11:44:10|    30/  178| bits: 0.06
#   2020-07-19 11:44:11|    60/  178| bits: 0.07
#   2020-07-19 11:44:11|    90/  178| bits: 0.05
#   2020-07-19 11:44:12|   120/  178| bits: 0.04
#   2020-07-19 11:44:12|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:44:17|     0/  178| bits: 0.03
#   2020-07-19 11:44:17|    30/  178| bits: 0.03
#   2020-07-19 11:44:18|    60/  178| bits: 0.02
#   2020-07-19 11:44:19|    90/  178| bits: 0.04
#   2020-07-19 11:44:19|   120/  178| bits: 0.03
#   2020-07-19 11:44:20|   150/  178| bits: 0.10
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:44:24|     0/  178| bits: 0.03
#   2020-07-19 11:44:25|    30/  178| bits: 0.03
#   2020-07-19 11:44:25|    60/  178| bits: 0.07
#   2020-07-19 11:44:26|    90/  178| bits: 0.02
#   2020-07-19 11:44:27|   120/  178| bits: 0.06
#   2020-07-19 11:44:27|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:44:32|     0/  178| bits: 0.05
#   2020-07-19 11:44:32|    30/  178| bits: 0.06
#   2020-07-19 11:44:33|    60/  178| bits: 0.02
#   2020-07-19 11:44:34|    90/  178| bits: 0.02
#   2020-07-19 11:44:34|   120/  178| bits: 0.02
#   2020-07-19 11:44:35|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:44:39|     0/  178| bits: 0.09
#   2020-07-19 11:44:40|    30/  178| bits: 0.02
#   2020-07-19 11:44:40|    60/  178| bits: 0.02
#   2020-07-19 11:44:41|    90/  178| bits: 0.01
#   2020-07-19 11:44:42|   120/  178| bits: 0.04
#   2020-07-19 11:44:42|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# 6
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:44:48|     0/  178| bits: 3.48
#   2020-07-19 11:44:48|    30/  178| bits: 0.11
#   2020-07-19 11:44:49|    60/  178| bits: 0.05
#   2020-07-19 11:44:50|    90/  178| bits: 0.07
#   2020-07-19 11:44:50|   120/  178| bits: 0.05
#   2020-07-19 11:44:51|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:44:55|     0/  178| bits: 0.06
#   2020-07-19 11:44:56|    30/  178| bits: 0.02
#   2020-07-19 11:44:56|    60/  178| bits: 0.03
#   2020-07-19 11:44:57|    90/  178| bits: 0.08
#   2020-07-19 11:44:58|   120/  178| bits: 0.02
#   2020-07-19 11:44:58|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# ...
#   2020-07-19 11:49:49|    60/  178| bits: 0.04
#   2020-07-19 11:49:50|    90/  178| bits: 0.05
#   2020-07-19 11:49:51|   120/  178| bits: 0.04
#   2020-07-19 11:49:51|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:49:55|     0/  178| bits: 0.08
#   2020-07-19 11:49:56|    30/  178| bits: 0.04
#   2020-07-19 11:49:57|    60/  178| bits: 0.05
#   2020-07-19 11:49:57|    90/  178| bits: 0.03
#   2020-07-19 11:49:58|   120/  178| bits: 0.03
#   2020-07-19 11:49:59|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:50:03|     0/  178| bits: 0.03
#   2020-07-19 11:50:04|    30/  178| bits: 0.02
#   2020-07-19 11:50:04|    60/  178| bits: 0.04
#   2020-07-19 11:50:05|    90/  178| bits: 0.06
#   2020-07-19 11:50:06|   120/  178| bits: 0.10
#   2020-07-19 11:50:06|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:50:10|     0/  178| bits: 0.02
#   2020-07-19 11:50:11|    30/  178| bits: 0.07
#   2020-07-19 11:50:12|    60/  178| bits: 0.10
#   2020-07-19 11:50:12|    90/  178| bits: 0.06
#   2020-07-19 11:50:13|   120/  178| bits: 0.02
#   2020-07-19 11:50:14|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:50:18|     0/  178| bits: 0.04
#   2020-07-19 11:50:18|    30/  178| bits: 0.04
#   2020-07-19 11:50:19|    60/  178| bits: 0.04
#   2020-07-19 11:50:20|    90/  178| bits: 0.07
#   2020-07-19 11:50:20|   120/  178| bits: 0.03
#   2020-07-19 11:50:21|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:50:25|     0/  178| bits: 0.03
#   2020-07-19 11:50:26|    30/  178| bits: 0.03
#   2020-07-19 11:50:26|    60/  178| bits: 0.02
#   2020-07-19 11:50:27|    90/  178| bits: 0.10
#   2020-07-19 11:50:28|   120/  178| bits: 0.01
#   2020-07-19 11:50:28|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:50:32|     0/  178| bits: 0.06
#   2020-07-19 11:50:33|    30/  178| bits: 0.05
#   2020-07-19 11:50:34|    60/  178| bits: 0.03
#   2020-07-19 11:50:34|    90/  178| bits: 0.03
#   2020-07-19 11:50:35|   120/  178| bits: 0.04
#   2020-07-19 11:50:36|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:50:40|     0/  178| bits: 0.01
#   2020-07-19 11:50:40|    30/  178| bits: 0.02
#   2020-07-19 11:50:41|    60/  178| bits: 0.05
#   2020-07-19 11:50:42|    90/  178| bits: 0.04
#   2020-07-19 11:50:42|   120/  178| bits: 0.03
#   2020-07-19 11:50:43|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:50:47|     0/  178| bits: 0.10
#   2020-07-19 11:50:48|    30/  178| bits: 0.07
#   2020-07-19 11:50:49|    60/  178| bits: 0.01
#   2020-07-19 11:50:49|    90/  178| bits: 0.02
#   2020-07-19 11:50:50|   120/  178| bits: 0.05
#   2020-07-19 11:50:50|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:50:55|     0/  178| bits: 0.05
#   2020-07-19 11:50:55|    30/  178| bits: 0.03
#   2020-07-19 11:50:56|    60/  178| bits: 0.02
#   2020-07-19 11:50:57|    90/  178| bits: 0.05
#   2020-07-19 11:50:57|   120/  178| bits: 0.06
#   2020-07-19 11:50:58|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:51:02|     0/  178| bits: 0.02
#   2020-07-19 11:51:03|    30/  178| bits: 0.04
#   2020-07-19 11:51:03|    60/  178| bits: 0.05
#   2020-07-19 11:51:04|    90/  178| bits: 0.07
#   2020-07-19 11:51:05|   120/  178| bits: 0.05
#   2020-07-19 11:51:05|   150/  178| bits: 0.03
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:51:10|     0/  178| bits: 0.03
#   2020-07-19 11:51:10|    30/  178| bits: 0.06
#   2020-07-19 11:51:11|    60/  178| bits: 0.05
#   2020-07-19 11:51:12|    90/  178| bits: 0.01
#   2020-07-19 11:51:12|   120/  178| bits: 0.02
#   2020-07-19 11:51:13|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:51:17|     0/  178| bits: 0.04
#   2020-07-19 11:51:18|    30/  178| bits: 0.03
#   2020-07-19 11:51:18|    60/  178| bits: 0.06
#   2020-07-19 11:51:19|    90/  178| bits: 0.04
#   2020-07-19 11:51:20|   120/  178| bits: 0.03
#   2020-07-19 11:51:20|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:51:24|     0/  178| bits: 0.02
#   2020-07-19 11:51:25|    30/  178| bits: 0.07
#   2020-07-19 11:51:26|    60/  178| bits: 0.02
#   2020-07-19 11:51:26|    90/  178| bits: 0.05
#   2020-07-19 11:51:27|   120/  178| bits: 0.04
#   2020-07-19 11:51:28|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:51:32|     0/  178| bits: 0.02
#   2020-07-19 11:51:32|    30/  178| bits: 0.05
#   2020-07-19 11:51:33|    60/  178| bits: 0.02
#   2020-07-19 11:51:34|    90/  178| bits: 0.02
#   2020-07-19 11:51:34|   120/  178| bits: 0.06
#   2020-07-19 11:51:35|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:51:39|     0/  178| bits: 0.05
#   2020-07-19 11:51:40|    30/  178| bits: 0.04
#   2020-07-19 11:51:41|    60/  178| bits: 0.11
#   2020-07-19 11:51:41|    90/  178| bits: 0.05
#   2020-07-19 11:51:42|   120/  178| bits: 0.11
#   2020-07-19 11:51:43|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:51:47|     0/  178| bits: 0.04
#   2020-07-19 11:51:47|    30/  178| bits: 0.06
#   2020-07-19 11:51:48|    60/  178| bits: 0.05
#   2020-07-19 11:51:49|    90/  178| bits: 0.04
#   2020-07-19 11:51:49|   120/  178| bits: 0.02
#   2020-07-19 11:51:50|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:51:54|     0/  178| bits: 0.04
#   2020-07-19 11:51:55|    30/  178| bits: 0.03
#   2020-07-19 11:51:56|    60/  178| bits: 0.07
#   2020-07-19 11:51:56|    90/  178| bits: 0.02
#   2020-07-19 11:51:57|   120/  178| bits: 0.05
#   2020-07-19 11:51:57|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:52:02|     0/  178| bits: 0.09
#   2020-07-19 11:52:02|    30/  178| bits: 0.06
#   2020-07-19 11:52:03|    60/  178| bits: 0.02
#   2020-07-19 11:52:04|    90/  178| bits: 0.05
#   2020-07-19 11:52:04|   120/  178| bits: 0.06
#   2020-07-19 11:52:05|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:52:09|     0/  178| bits: 0.05
#   2020-07-19 11:52:10|    30/  178| bits: 0.04
#   2020-07-19 11:52:10|    60/  178| bits: 0.04
#   2020-07-19 11:52:11|    90/  178| bits: 0.02
#   2020-07-19 11:52:12|   120/  178| bits: 0.04
#   2020-07-19 11:52:12|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# 9
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 11:52:18|     0/  178| bits: 3.19
#   2020-07-19 11:52:18|    30/  178| bits: 0.07
#   2020-07-19 11:52:19|    60/  178| bits: 0.06
#   2020-07-19 11:52:20|    90/  178| bits: 0.06
#   2020-07-19 11:52:20|   120/  178| bits: 0.04
#   2020-07-19 11:52:21|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 11:52:25|     0/  178| bits: 0.07
#   2020-07-19 11:52:26|    30/  178| bits: 0.07
#   2020-07-19 11:52:26|    60/  178| bits: 0.04
#   2020-07-19 11:52:27|    90/  178| bits: 0.03
#   2020-07-19 11:52:28|   120/  178| bits: 0.09
#   2020-07-19 11:52:28|   150/  178| bits: 0.09
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 11:52:33|     0/  178| bits: 0.04
#   2020-07-19 11:52:33|    30/  178| bits: 0.04
#   2020-07-19 11:52:34|    60/  178| bits: 0.07
#   2020-07-19 11:52:35|    90/  178| bits: 0.04
#   2020-07-19 11:52:35|   120/  178| bits: 0.02
#   2020-07-19 11:52:36|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 11:52:40|     0/  178| bits: 0.09
#   2020-07-19 11:52:41|    30/  178| bits: 0.07
#   2020-07-19 11:52:41|    60/  178| bits: 0.03
#   2020-07-19 11:52:42|    90/  178| bits: 0.07
#   2020-07-19 11:52:43|   120/  178| bits: 0.05
#   2020-07-19 11:52:43|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 11:52:48|     0/  178| bits: 0.02
#   2020-07-19 11:52:48|    30/  178| bits: 0.13
#   2020-07-19 11:52:49|    60/  178| bits: 0.09
#   2020-07-19 11:52:50|    90/  178| bits: 0.05
#   2020-07-19 11:52:50|   120/  178| bits: 0.03
#   2020-07-19 11:52:51|   150/  178| bits: 0.07
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 11:52:55|     0/  178| bits: 0.01
#   2020-07-19 11:52:56|    30/  178| bits: 0.04
#   2020-07-19 11:52:57|    60/  178| bits: 0.04
#   2020-07-19 11:52:57|    90/  178| bits: 0.02
#   2020-07-19 11:52:58|   120/  178| bits: 0.05
#   2020-07-19 11:52:59|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 11:53:03|     0/  178| bits: 0.04
#   2020-07-19 11:53:03|    30/  178| bits: 0.06
#   2020-07-19 11:53:04|    60/  178| bits: 0.03
#   2020-07-19 11:53:05|    90/  178| bits: 0.04
#   2020-07-19 11:53:05|   120/  178| bits: 0.06
#   2020-07-19 11:53:06|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 11:53:10|     0/  178| bits: 0.04
#   2020-07-19 11:53:11|    30/  178| bits: 0.06
#   2020-07-19 11:53:11|    60/  178| bits: 0.06
#   2020-07-19 11:53:12|    90/  178| bits: 0.02
#   2020-07-19 11:53:13|   120/  178| bits: 0.08
#   2020-07-19 11:53:13|   150/  178| bits: 0.08
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 11:53:18|     0/  178| bits: 0.04
#   2020-07-19 11:53:18|    30/  178| bits: 0.05
#   2020-07-19 11:53:19|    60/  178| bits: 0.02
#   2020-07-19 11:53:19|    90/  178| bits: 0.04
#   2020-07-19 11:53:20|   120/  178| bits: 0.04
#   2020-07-19 11:53:21|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 11:53:25|     0/  178| bits: 0.04
#   2020-07-19 11:53:26|    30/  178| bits: 0.04
#   2020-07-19 11:53:26|    60/  178| bits: 0.02
#   2020-07-19 11:53:27|    90/  178| bits: 0.03
#   2020-07-19 11:53:28|   120/  178| bits: 0.03
#   2020-07-19 11:53:28|   150/  178| bits: 0.11
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 11:53:32|     0/  178| bits: 0.04
#   2020-07-19 11:53:33|    30/  178| bits: 0.07
#   2020-07-19 11:53:34|    60/  178| bits: 0.04
#   2020-07-19 11:53:34|    90/  178| bits: 0.04
#   2020-07-19 11:53:35|   120/  178| bits: 0.03
#   2020-07-19 11:53:36|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 11:53:40|     0/  178| bits: 0.07
#   2020-07-19 11:53:40|    30/  178| bits: 0.02
#   2020-07-19 11:53:41|    60/  178| bits: 0.07
#   2020-07-19 11:53:42|    90/  178| bits: 0.02
#   2020-07-19 11:53:42|   120/  178| bits: 0.01
#   2020-07-19 11:53:43|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 11:53:47|     0/  178| bits: 0.03
#   2020-07-19 11:53:48|    30/  178| bits: 0.05
#   2020-07-19 11:53:48|    60/  178| bits: 0.02
#   2020-07-19 11:53:49|    90/  178| bits: 0.02
#   2020-07-19 11:53:50|   120/  178| bits: 0.01
#   2020-07-19 11:53:50|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 11:53:55|     0/  178| bits: 0.05
#   2020-07-19 11:53:55|    30/  178| bits: 0.06
#   2020-07-19 11:53:56|    60/  178| bits: 0.05
#   2020-07-19 11:53:57|    90/  178| bits: 0.01
#   2020-07-19 11:53:57|   120/  178| bits: 0.03
#   2020-07-19 11:53:58|   150/  178| bits: 0.05
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 11:54:02|     0/  178| bits: 0.07
#   2020-07-19 11:54:03|    30/  178| bits: 0.04
#   2020-07-19 11:54:03|    60/  178| bits: 0.05
#   2020-07-19 11:54:04|    90/  178| bits: 0.04
#   2020-07-19 11:54:05|   120/  178| bits: 0.06
#   2020-07-19 11:54:05|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 11:54:09|     0/  178| bits: 0.09
#   2020-07-19 11:54:10|    30/  178| bits: 0.03
#   2020-07-19 11:54:11|    60/  178| bits: 0.08
#   2020-07-19 11:54:11|    90/  178| bits: 0.03
#   2020-07-19 11:54:12|   120/  178| bits: 0.05
#   2020-07-19 11:54:13|   150/  178| bits: 0.04
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 11:54:17|     0/  178| bits: 0.06
#   2020-07-19 11:54:17|    30/  178| bits: 0.04
#   2020-07-19 11:54:18|    60/  178| bits: 0.02
#   2020-07-19 11:54:19|    90/  178| bits: 0.03
#   2020-07-19 11:54:19|   120/  178| bits: 0.08
#   2020-07-19 11:54:20|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 11:54:24|     0/  178| bits: 0.05
#   2020-07-19 11:54:25|    30/  178| bits: 0.02
#   2020-07-19 11:54:26|    60/  178| bits: 0.05
#   2020-07-19 11:54:26|    90/  178| bits: 0.06
#   2020-07-19 11:54:27|   120/  178| bits: 0.02
#   2020-07-19 11:54:27|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 11:54:32|     0/  178| bits: 0.02
#   2020-07-19 11:54:32|    30/  178| bits: 0.03
#   2020-07-19 11:54:33|    60/  178| bits: 0.04
#   2020-07-19 11:54:34|    90/  178| bits: 0.04
#   2020-07-19 11:54:34|   120/  178| bits: 0.02
#   2020-07-19 11:54:35|   150/  178| bits: 0.02
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 11:54:39|     0/  178| bits: 0.13
#   2020-07-19 11:54:40|    30/  178| bits: 0.03
#   2020-07-19 11:54:40|    60/  178| bits: 0.03
#   2020-07-19 11:54:41|    90/  178| bits: 0.04
#   2020-07-19 11:54:42|   120/  178| bits: 0.02
#   2020-07-19 11:54:42|   150/  178| bits: 0.06
# Elapsed time: 0h 0m 5s
# Validation| bits: 0.02
# [44.625335843469465, 47.467935169820315, 76.07436541870945, 38.4034275655275, 55.46763141151052, 63.707106865732804, 61.84107647609862, 64.15932319289568, 68.10728335906391, 46.673082817051714]
# 56.652656811988 11.421437521596209
# [44.625335843469465, 47.467935169820315, 55.46763141151052, 63.707106865732804, 61.84107647609862, 64.15932319289568, 68.10728335906391, 46.673082817051714]
# 56.50609689195538 8.617448714829338
