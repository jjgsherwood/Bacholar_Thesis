# %%
import torch
import torchvision
from torchvision import transforms, datasets
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
import cv2
import numpy as np
from tqdm import tqdm
from collections import OrderedDict
from torch.optim.lr_scheduler import StepLR

# %%
train = datasets.MNIST("../data/", train=True, download=True, transform=transforms.ToTensor())
test = datasets.MNIST("../data/", train=False, download=True, transform=transforms.ToTensor())

# %%
IM_SIZE = 28 * 28
IM_SHAPE = (28, 28)
CPU_training = False
BATCH = 100

use_cuda =  torch.cuda.is_available() and not CPU_training
device = torch.device("cuda" if use_cuda else "cpu")

trainset = torch.utils.data.DataLoader(train, batch_size=BATCH, shuffle=True, num_workers=10, pin_memory=use_cuda)
testset = torch.utils.data.DataLoader(test, batch_size=BATCH, shuffle=False, num_workers=10, pin_memory=use_cuda)

# %%
class PCA(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
        self.encoder = nn.Sequential(
            nn.Linear(IM_SIZE, dim)
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(dim, IM_SIZE),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.decoder(self.encoder(x))

# %%
class AutoEncoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim
        self.encoder = nn.Sequential(
            nn.Linear(IM_SIZE, 64),
            nn.ReLU(True),
            nn.Linear(64, dim),
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(dim, 64),
            nn.ReLU(True),
            nn.Linear(64, IM_SIZE),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.decoder(self.encoder(x))

# %%
def train(network, dim):
    net = network(dim).to(device).train()

    optimizer = optim.Adadelta(net.parameters(), lr=1.0, rho=0.9, eps=1e-06, weight_decay=0)
    scheduler = StepLR(optimizer, step_size=1, gamma=0.7)

    for epoch in range(EPOCHS):
        for X, _ in tqdm(trainset):
            X = X.view(-1, IM_SIZE).to(device)
            net.zero_grad()
            output = net(X)
            loss = F.binary_cross_entropy(output, X)
            loss.backward()
            optimizer.step()
        scheduler.step()
        print(epoch, loss)
    
    return net

# %%
def test(net):
    net.eval()

    comp_data = np.empty((10000, DIM))
    comp_label = np.empty((10000,))
    loss = 0
    with torch.no_grad():
        for i, (X, y) in tqdm(enumerate(testset)):
            X = X.view(-1, IM_SIZE).to(device)
            latent = net.encoder(X)
            output = net.decoder(latent)
            comp_data[BATCH * i: BATCH * (i + 1)] = latent.cpu()
            comp_label[BATCH * i: BATCH * (i + 1)] = y

            loss += F.mse_loss(output, X, reduction='sum')

    print(loss)
    if use_cuda:
        X = X.cpu()
        output = output.cpu()
    plt.imshow(X[0].view(IM_SHAPE))
    plt.show()
    plt.imshow(output[0].view(IM_SHAPE))
    plt.show()

    plt.scatter(comp_data[0:-1:5,0], comp_data[0:-1:5,1], c=comp_label[0:-1:5], cmap=plt.cm.rainbow)
    plt.show()

# %%
net = train(PCA)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:07<00:00, 83.07it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 0 tensor(0.6016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.56it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 1 tensor(0.4838, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.93it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 2 tensor(0.3203, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:06<00:00, 99.88it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 3 tensor(0.2667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:05<00:00, 106.31it/s]
# 4 tensor(0.2737, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100it [00:04, 21.82it/s]
# tensor(527479.6250, device='cuda:0')

# %%
test(net)
# Out:
# 100it [00:03, 27.25it/s]
# tensor(527479.6250, device='cuda:0')

# %%
net2 = train(AutoEncoder)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:08<00:00, 69.09it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 0 tensor(0.2498, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.80it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 1 tensor(0.2359, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.99it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 2 tensor(0.2447, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.68it/s]
#   0%|                                                                                          | 0/600 [00:00<?, ?it/s]
# 3 tensor(0.2299, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.44it/s]
# 4 tensor(0.2294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward>)

# %%
test(net2)
# Out:
# 100it [00:03, 25.00it/s]
# tensor(451945.3438, device='cuda:0')

# %%
# Softmax - sigmoid at the last layer
# Use ReLU for all layers but the middle one
# Try to find dim 4 6 10 16 and compare to PCA
# Try to use UMAP

# %%
for d in [4,6,10,16]:
    DIM = d
