# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_array, check_is_fitted

import numpy as np
import matplotlib.pyplot as plt
import os
import copy
import inspect
import random
import shutil

from datetime import datetime
from dateutil.relativedelta import relativedelta

from scipy import optimize
from sklearn import decomposition, cluster, model_selection, metrics
import sklearn

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import utils.dataset_utils as dataset
import utils.train_utils as train

# %%
def unit_vector_norm(X):
    X -= X.min() #remove noise offset
    return (X.T / np.sqrt((X**2).sum(axis=1))).T

class View(nn.Module):
    def __init__(self, shape):
        super().__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)

# %%
X = np.load("../data/HSI/Liver_map_150z25_60s_1TCPOBOP.npy", 'r')
Y = np.load("../data/HSI/Liver_map_150z25_60s_2TCPOBOP.npy", 'r')
Z = np.load("../data/HSI/Liver_map_150z25_60s_3OBOB.npy", 'r')
wavelength = np.load("../data/HSI/wavelength.npy", 'r')

shape_X = X.shape 
shape_Y = Y.shape 
shape_Z = Z.shape 

X = copy.copy(X.reshape(-1, X.shape[-1]))
Y = copy.copy(Y.reshape(-1, Y.shape[-1]))
Z = copy.copy(Z.reshape(-1, Z.shape[-1]))

# %%
class AutoEncoderConv(nn.Module):
    def __init__(self, n_components=10, d=1):
        super().__init__()
        h = 32
        self.encode = nn.Sequential( 
            nn.Dropout3d(0.25),
            nn.Flatten(),
            nn.Linear(1000, h),
            nn.ReLU(True),
            nn.Dropout3d(0.5),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),
            nn.Linear(h, n_components)
        )
        
        self.decode = nn.Sequential(
            nn.Linear(n_components, h),
            nn.ReLU(True),
            *((nn.Linear(h, h),
            nn.ReLU(True)) * (d-1)),            
            nn.Linear(h, 1000),
            View((-1,1,1,1,1000))
        )
        
    def forward(self, x):
        return self.decode(self.encode(x))

# %%
def MSE_loss(x, model):
    x_ = model(x)
    return ((x - x_)**2).mean(0).sum()

# %%
class ReferenceVectorClassifierAE(BaseEstimator):
    def __init__(self, **kwargs):
        self.kwargs = {}
        self.k_means_kwargs = {}
        self.ae_kwargs = {}        
        self.set_params(**kwargs)

        _use_cuda = torch.cuda.is_available() and kwargs['cuda']
        if _use_cuda:
            torch.backends.cudnn.enabled = True
            torch.backends.cudnn.benchmark = True
        self.device = torch.device('cuda' if _use_cuda else 'cpu')        
        
    def fit(self, x, **kwargs):
        self.set_params(**kwargs)
        X = unit_vector_norm(x)
        
        ###################### Autoencoder ################################
        self.model = AutoEncoderConv(**self.ae_kwargs).to(self.device)
        
        parameters = filter(lambda x: x.requires_grad, self.model.parameters())
        self.optimizer = optim.Adam(parameters)        
        train_loader, test_loader = dataset.load_liver(X, self.kwargs['batch_size'])
        
        for epoch in range(self.kwargs['epochs']):
            print('-'*50)
            print('Epoch {:3d}/{:3d}'.format(epoch+1, self.kwargs['epochs']))
            start_time = datetime.now()
            train.train(self.model, self.optimizer, train_loader, self.kwargs['loss_func'], self.kwargs['log_step'], self.device)
            end_time = datetime.now()
            time_diff = relativedelta(end_time, start_time)
            print('Elapsed time: {}h {}m {}s'.format(time_diff.hours, time_diff.minutes, time_diff.seconds))
            loss = train.test(self.model, test_loader, self.kwargs['loss_func'], self.device)
            print('Validation| bits: {:2.2f}'.format(loss), flush=True)    
          
        self.model.eval()
        with torch.no_grad():
            z = self.model.encode(dataset.load_liver_all(X).to(self.device)).cpu()
              
        ###################### clustering ################################
        self.clusters = cluster.KMeans(**self.k_means_kwargs).fit(z)
        self.clusters = self.clusters.labels_
        
        one_hot = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        one_hot[range(X.shape[0]), self.clusters] = 1

        ###################### reference spectra ################################
        self.reference_spectra_ = np.array([X[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])
        self.ref_org = np.array([x[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])

        # Return the classifier
        return self

    def predict(self, X):
        """
        predict transforms the data into the reference space. Min weight should be 0 or higher then 'min_weight'
        The error is the NMSE, where the MSE is normalised by the signal strength. 
        error.shape = X.shape[0], so for each data point the error is calculated.
        """
        # Check is fit had been called
        check_is_fitted(self)

        # Input validation
        X = check_array(X)
        X = unit_vector_norm(X)
        
        ###################### RCA ################################
        old_mask = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        mask = np.ones((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        while np.abs(old_mask ^ mask).sum():
            RCA_vector = np.array([optimize.nnls(self.reference_spectra_.T * mask[i], X[i,:])[0] for i in range(X.shape[0])])
            old_mask, mask = mask, (RCA_vector.T / RCA_vector.sum(axis=1)).T >= self.kwargs['min_weight']            
        
        return RCA_vector  
    
    def get_reference_vectors(self):
        return self.reference_spectra_

    def get_org_reference_vectors(self):
        return self.ref_org    
    
    def get_params(self, deep=False):
        return self.kwargs
    
    def set_params(self, **kwargs):
        self.kwargs.update(kwargs)
        self.k_means_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(cluster.KMeans).parameters.keys())})     
        self.ae_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(AutoEncoderConv).parameters.keys())})     
        return self

# %%
def error_map(estimator, X, y=None):
    RCA = estimator.predict(X)
    ref_vec = estimator.get_reference_vectors()
    return ((RCA @ ref_vec - X)**2).mean(1)

def score_func(estimator, X, y=None):
    X = unit_vector_norm(X)
    return error_map(estimator, X).mean()

def print_mean_std(X):
    return f"{X.mean():<12.4e}{X.std():<12.4e}"

def cross_val_X_Y_Z(rvc, X, Y, Z):
    rvc.fit(np.concatenate((X, Y), axis=0))
    return score_func(rvc, Z)

# %%
kwargs = {'n_clusters': 3,
          'n_components': 5, #enough for PCA
          'min_weight': 0,
          'batch_size': 64,
          'cuda': True,
          'log_step': 10,
          'loss_func': MSE_loss,
          'epochs': 3,
          'd':1
         }

header = f"{'mean':12}{'std':12}"

# %%
rvc = ReferenceVectorClassifierAE(**kwargs)

repeat = 10
hs = [1000, 800, 500, 300, 100, 80, 50, 30, 10, 8, 5, 3]
error = []
for h in hs:
    print('calculating for h: ',h)
    kwargs['h'] = h
    tmp = 0
    for _ in range(repeat):
        rvc.fit(X)
        tmp += score_func(rvc, X)
    error.append(tmp/repeat)
# Out:
# calculating for h:  1000
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:30:20|     0/   52| bits: 15.96
#   2020-05-26 14:30:20|    10/   52| bits: 2.38
#   2020-05-26 14:30:20|    20/   52| bits: 0.57
#   2020-05-26 14:30:20|    30/   52| bits: 0.23
#   2020-05-26 14:30:20|    40/   52| bits: 0.10
#   2020-05-26 14:30:20|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:30:27|     0/   52| bits: 0.03
#   2020-05-26 14:30:27|    10/   52| bits: 0.02
#   2020-05-26 14:30:27|    20/   52| bits: 0.02
#   2020-05-26 14:30:27|    30/   52| bits: 0.01
#   2020-05-26 14:30:28|    40/   52| bits: 0.01
#   2020-05-26 14:30:28|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:30:32|     0/   52| bits: 0.01
#   2020-05-26 14:30:32|    10/   52| bits: 0.01
#   2020-05-26 14:30:32|    20/   52| bits: 0.01
#   2020-05-26 14:30:32|    30/   52| bits: 0.01
#   2020-05-26 14:30:32|    40/   52| bits: 0.01
#   2020-05-26 14:30:32|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:30:37|     0/   52| bits: 15.76
#   2020-05-26 14:30:37|    10/   52| bits: 2.44
#   2020-05-26 14:30:37|    20/   52| bits: 0.56
#   2020-05-26 14:30:37|    30/   52| bits: 0.23
#   2020-05-26 14:30:37|    40/   52| bits: 0.09
#   2020-05-26 14:30:37|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:30:44|     0/   52| bits: 0.03
#   2020-05-26 14:30:45|    10/   52| bits: 0.02
#   2020-05-26 14:30:45|    20/   52| bits: 0.01
#   2020-05-26 14:30:45|    30/   52| bits: 0.01
#   2020-05-26 14:30:45|    40/   52| bits: 0.01
#   2020-05-26 14:30:45|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:30:50|     0/   52| bits: 0.01
#   2020-05-26 14:30:50|    10/   52| bits: 0.01
#   2020-05-26 14:30:50|    20/   52| bits: 0.01
#   2020-05-26 14:30:50|    30/   52| bits: 0.01
#   2020-05-26 14:30:50|    40/   52| bits: 0.01
#   2020-05-26 14:30:50|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:30:55|     0/   52| bits: 18.85
#   2020-05-26 14:30:55|    10/   52| bits: 2.91
#   2020-05-26 14:30:55|    20/   52| bits: 0.67
#   2020-05-26 14:30:55|    30/   52| bits: 0.26
#   2020-05-26 14:30:55|    40/   52| bits: 0.11
#   2020-05-26 14:30:55|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:31:00|     0/   52| bits: 0.04
#   2020-05-26 14:31:00|    10/   52| bits: 0.02
#   2020-05-26 14:31:00|    20/   52| bits: 0.01
#   2020-05-26 14:31:00|    30/   52| bits: 0.01
#   2020-05-26 14:31:01|    40/   52| bits: 0.01
#   2020-05-26 14:31:01|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:31:07|     0/   52| bits: 0.01
#   2020-05-26 14:31:07|    10/   52| bits: 0.01
#   2020-05-26 14:31:08|    20/   52| bits: 0.01
#   2020-05-26 14:31:08|    30/   52| bits: 0.01
#   2020-05-26 14:31:08|    40/   52| bits: 0.01
#   2020-05-26 14:31:08|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:31:12|     0/   52| bits: 17.78
#   2020-05-26 14:31:12|    10/   52| bits: 2.67
#   2020-05-26 14:31:12|    20/   52| bits: 0.54
#   2020-05-26 14:31:12|    30/   52| bits: 0.24
#   2020-05-26 14:31:12|    40/   52| bits: 0.10
#   2020-05-26 14:31:12|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:31:18|     0/   52| bits: 0.03
#   2020-05-26 14:31:18|    10/   52| bits: 0.02
#   2020-05-26 14:31:18|    20/   52| bits: 0.01
#   2020-05-26 14:31:18|    30/   52| bits: 0.01
#   2020-05-26 14:31:18|    40/   52| bits: 0.01
#   2020-05-26 14:31:18|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:31:24|     0/   52| bits: 0.01
#   2020-05-26 14:31:24|    10/   52| bits: 0.01
#   2020-05-26 14:31:24|    20/   52| bits: 0.01
#   2020-05-26 14:31:25|    30/   52| bits: 0.01
#   2020-05-26 14:31:25|    40/   52| bits: 0.01
#   2020-05-26 14:31:25|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:31:29|     0/   52| bits: 16.70
#   2020-05-26 14:31:29|    10/   52| bits: 2.60
#   2020-05-26 14:31:29|    20/   52| bits: 0.63
#   2020-05-26 14:31:29|    30/   52| bits: 0.27
#   2020-05-26 14:31:29|    40/   52| bits: 0.10
#   2020-05-26 14:31:29|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:31:33|     0/   52| bits: 0.04
#   2020-05-26 14:31:33|    10/   52| bits: 0.02
#   2020-05-26 14:31:34|    20/   52| bits: 0.01
#   2020-05-26 14:31:34|    30/   52| bits: 0.01
#   2020-05-26 14:31:34|    40/   52| bits: 0.01
#   2020-05-26 14:31:34|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:31:41|     0/   52| bits: 0.01
#   2020-05-26 14:31:41|    10/   52| bits: 0.01
#   2020-05-26 14:31:41|    20/   52| bits: 0.01
#   2020-05-26 14:31:41|    30/   52| bits: 0.01
#   2020-05-26 14:31:41|    40/   52| bits: 0.01
#   2020-05-26 14:31:41|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:31:46|     0/   52| bits: 18.12
#   2020-05-26 14:31:46|    10/   52| bits: 2.63
#   2020-05-26 14:31:46|    20/   52| bits: 0.58
#   2020-05-26 14:31:47|    30/   52| bits: 0.25
#   2020-05-26 14:31:47|    40/   52| bits: 0.11
#   2020-05-26 14:31:47|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:31:50|     0/   52| bits: 0.04
#   2020-05-26 14:31:50|    10/   52| bits: 0.02
#   2020-05-26 14:31:50|    20/   52| bits: 0.01
#   2020-05-26 14:31:50|    30/   52| bits: 0.01
#   2020-05-26 14:31:50|    40/   52| bits: 0.01
#   2020-05-26 14:31:51|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:31:56|     0/   52| bits: 0.01
#   2020-05-26 14:31:56|    10/   52| bits: 0.01
#   2020-05-26 14:31:56|    20/   52| bits: 0.01
#   2020-05-26 14:31:56|    30/   52| bits: 0.01
#   2020-05-26 14:31:56|    40/   52| bits: 0.01
#   2020-05-26 14:31:56|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:32:04|     0/   52| bits: 17.23
#   2020-05-26 14:32:04|    10/   52| bits: 2.96
#   2020-05-26 14:32:04|    20/   52| bits: 0.77
#   2020-05-26 14:32:04|    30/   52| bits: 0.28
#   2020-05-26 14:32:04|    40/   52| bits: 0.12
#   2020-05-26 14:32:04|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:32:08|     0/   52| bits: 0.05
#   2020-05-26 14:32:08|    10/   52| bits: 0.03
#   2020-05-26 14:32:08|    20/   52| bits: 0.02
#   2020-05-26 14:32:08|    30/   52| bits: 0.01
#   2020-05-26 14:32:08|    40/   52| bits: 0.01
#   2020-05-26 14:32:08|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:32:12|     0/   52| bits: 0.01
#   2020-05-26 14:32:12|    10/   52| bits: 0.01
#   2020-05-26 14:32:12|    20/   52| bits: 0.01
#   2020-05-26 14:32:12|    30/   52| bits: 0.01
#   2020-05-26 14:32:12|    40/   52| bits: 0.01
#   2020-05-26 14:32:12|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:32:20|     0/   52| bits: 16.33
#   2020-05-26 14:32:20|    10/   52| bits: 2.48
#   2020-05-26 14:32:20|    20/   52| bits: 0.60
#   2020-05-26 14:32:20|    30/   52| bits: 0.24
#   2020-05-26 14:32:20|    40/   52| bits: 0.10
#   2020-05-26 14:32:20|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:32:25|     0/   52| bits: 0.04
#   2020-05-26 14:32:25|    10/   52| bits: 0.02
#   2020-05-26 14:32:25|    20/   52| bits: 0.02
#   2020-05-26 14:32:25|    30/   52| bits: 0.01
#   2020-05-26 14:32:25|    40/   52| bits: 0.01
#   2020-05-26 14:32:25|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:32:28|     0/   52| bits: 0.01
#   2020-05-26 14:32:29|    10/   52| bits: 0.01
#   2020-05-26 14:32:29|    20/   52| bits: 0.01
#   2020-05-26 14:32:29|    30/   52| bits: 0.01
#   2020-05-26 14:32:29|    40/   52| bits: 0.01
#   2020-05-26 14:32:29|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:32:35|     0/   52| bits: 16.42
#   2020-05-26 14:32:35|    10/   52| bits: 2.95
#   2020-05-26 14:32:35|    20/   52| bits: 0.69
#   2020-05-26 14:32:35|    30/   52| bits: 0.24
#   2020-05-26 14:32:35|    40/   52| bits: 0.10
#   2020-05-26 14:32:35|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:32:42|     0/   52| bits: 0.04
#   2020-05-26 14:32:42|    10/   52| bits: 0.02
#   2020-05-26 14:32:42|    20/   52| bits: 0.02
#   2020-05-26 14:32:42|    30/   52| bits: 0.01
#   2020-05-26 14:32:42|    40/   52| bits: 0.01
#   2020-05-26 14:32:42|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:32:46|     0/   52| bits: 0.01
#   2020-05-26 14:32:46|    10/   52| bits: 0.01
#   2020-05-26 14:32:46|    20/   52| bits: 0.01
#   2020-05-26 14:32:46|    30/   52| bits: 0.01
#   2020-05-26 14:32:46|    40/   52| bits: 0.01
#   2020-05-26 14:32:46|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:32:51|     0/   52| bits: 13.98
#   2020-05-26 14:32:51|    10/   52| bits: 2.30
#   2020-05-26 14:32:51|    20/   52| bits: 0.48
#   2020-05-26 14:32:52|    30/   52| bits: 0.20
#   2020-05-26 14:32:52|    40/   52| bits: 0.08
#   2020-05-26 14:32:52|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:32:58|     0/   52| bits: 0.03
#   2020-05-26 14:32:58|    10/   52| bits: 0.02
#   2020-05-26 14:32:59|    20/   52| bits: 0.01
#   2020-05-26 14:32:59|    30/   52| bits: 0.01
#   2020-05-26 14:32:59|    40/   52| bits: 0.01
#   2020-05-26 14:32:59|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:33:04|     0/   52| bits: 0.01
#   2020-05-26 14:33:04|    10/   52| bits: 0.01
#   2020-05-26 14:33:04|    20/   52| bits: 0.01
#   2020-05-26 14:33:04|    30/   52| bits: 0.01
#   2020-05-26 14:33:04|    40/   52| bits: 0.01
#   2020-05-26 14:33:04|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for h:  800
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:33:08|     0/   52| bits: 15.38
#   2020-05-26 14:33:08|    10/   52| bits: 2.21
#   2020-05-26 14:33:08|    20/   52| bits: 0.57
#   2020-05-26 14:33:08|    30/   52| bits: 0.23
#   2020-05-26 14:33:08|    40/   52| bits: 0.09
#   2020-05-26 14:33:08|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:33:15|     0/   52| bits: 0.04
#   2020-05-26 14:33:15|    10/   52| bits: 0.02
#   2020-05-26 14:33:15|    20/   52| bits: 0.01
#   2020-05-26 14:33:15|    30/   52| bits: 0.01
#   2020-05-26 14:33:15|    40/   52| bits: 0.01
#   2020-05-26 14:33:15|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:33:22|     0/   52| bits: 0.01
#   2020-05-26 14:33:22|    10/   52| bits: 0.01
#   2020-05-26 14:33:22|    20/   52| bits: 0.01
#   2020-05-26 14:33:22|    30/   52| bits: 0.01
#   2020-05-26 14:33:22|    40/   52| bits: 0.01
#   2020-05-26 14:33:22|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:33:26|     0/   52| bits: 12.89
#   2020-05-26 14:33:27|    10/   52| bits: 2.33
#   2020-05-26 14:33:27|    20/   52| bits: 0.56
#   2020-05-26 14:33:27|    30/   52| bits: 0.19
#   2020-05-26 14:33:27|    40/   52| bits: 0.07
#   2020-05-26 14:33:27|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:33:31|     0/   52| bits: 0.03
#   2020-05-26 14:33:32|    10/   52| bits: 0.02
#   2020-05-26 14:33:32|    20/   52| bits: 0.01
#   2020-05-26 14:33:32|    30/   52| bits: 0.01
#   2020-05-26 14:33:32|    40/   52| bits: 0.01
#   2020-05-26 14:33:32|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:33:39|     0/   52| bits: 0.01
#   2020-05-26 14:33:39|    10/   52| bits: 0.01
#   2020-05-26 14:33:39|    20/   52| bits: 0.01
#   2020-05-26 14:33:39|    30/   52| bits: 0.01
#   2020-05-26 14:33:39|    40/   52| bits: 0.01
#   2020-05-26 14:33:39|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:33:44|     0/   52| bits: 17.78
#   2020-05-26 14:33:44|    10/   52| bits: 2.49
#   2020-05-26 14:33:44|    20/   52| bits: 0.56
#   2020-05-26 14:33:44|    30/   52| bits: 0.27
#   2020-05-26 14:33:45|    40/   52| bits: 0.10
#   2020-05-26 14:33:45|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:33:49|     0/   52| bits: 0.03
#   2020-05-26 14:33:49|    10/   52| bits: 0.02
#   2020-05-26 14:33:49|    20/   52| bits: 0.01
#   2020-05-26 14:33:50|    30/   52| bits: 0.01
#   2020-05-26 14:33:50|    40/   52| bits: 0.01
#   2020-05-26 14:33:50|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:33:57|     0/   52| bits: 0.01
#   2020-05-26 14:33:57|    10/   52| bits: 0.01
#   2020-05-26 14:33:57|    20/   52| bits: 0.01
#   2020-05-26 14:33:57|    30/   52| bits: 0.01
#   2020-05-26 14:33:57|    40/   52| bits: 0.01
#   2020-05-26 14:33:57|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:34:02|     0/   52| bits: 18.77
#   2020-05-26 14:34:02|    10/   52| bits: 3.33
#   2020-05-26 14:34:02|    20/   52| bits: 0.81
#   2020-05-26 14:34:02|    30/   52| bits: 0.31
#   2020-05-26 14:34:02|    40/   52| bits: 0.13
#   2020-05-26 14:34:02|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:34:07|     0/   52| bits: 0.04
#   2020-05-26 14:34:07|    10/   52| bits: 0.02
#   2020-05-26 14:34:07|    20/   52| bits: 0.02
#   2020-05-26 14:34:07|    30/   52| bits: 0.01
#   2020-05-26 14:34:07|    40/   52| bits: 0.01
#   2020-05-26 14:34:07|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:34:13|     0/   52| bits: 0.01
#   2020-05-26 14:34:14|    10/   52| bits: 0.01
#   2020-05-26 14:34:14|    20/   52| bits: 0.01
#   2020-05-26 14:34:14|    30/   52| bits: 0.01
#   2020-05-26 14:34:14|    40/   52| bits: 0.01
#   2020-05-26 14:34:14|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:34:20|     0/   52| bits: 16.12
#   2020-05-26 14:34:20|    10/   52| bits: 2.81
#   2020-05-26 14:34:20|    20/   52| bits: 0.58
#   2020-05-26 14:34:20|    30/   52| bits: 0.23
#   2020-05-26 14:34:20|    40/   52| bits: 0.09
#   2020-05-26 14:34:20|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:34:24|     0/   52| bits: 0.04
#   2020-05-26 14:34:24|    10/   52| bits: 0.02
#   2020-05-26 14:34:24|    20/   52| bits: 0.01
#   2020-05-26 14:34:24|    30/   52| bits: 0.01
#   2020-05-26 14:34:24|    40/   52| bits: 0.01
#   2020-05-26 14:34:24|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:34:28|     0/   52| bits: 0.01
#   2020-05-26 14:34:28|    10/   52| bits: 0.01
#   2020-05-26 14:34:28|    20/   52| bits: 0.01
#   2020-05-26 14:34:28|    30/   52| bits: 0.01
#   2020-05-26 14:34:28|    40/   52| bits: 0.01
#   2020-05-26 14:34:28|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:34:32|     0/   52| bits: 14.45
#   2020-05-26 14:34:32|    10/   52| bits: 2.96
#   2020-05-26 14:34:33|    20/   52| bits: 0.69
#   2020-05-26 14:34:33|    30/   52| bits: 0.25
#   2020-05-26 14:34:33|    40/   52| bits: 0.10
#   2020-05-26 14:34:33|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:34:36|     0/   52| bits: 0.04
#   2020-05-26 14:34:36|    10/   52| bits: 0.02
#   2020-05-26 14:34:36|    20/   52| bits: 0.02
#   2020-05-26 14:34:37|    30/   52| bits: 0.01
#   2020-05-26 14:34:37|    40/   52| bits: 0.01
#   2020-05-26 14:34:37|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:34:41|     0/   52| bits: 0.01
#   2020-05-26 14:34:41|    10/   52| bits: 0.01
#   2020-05-26 14:34:41|    20/   52| bits: 0.01
#   2020-05-26 14:34:41|    30/   52| bits: 0.01
#   2020-05-26 14:34:41|    40/   52| bits: 0.01
#   2020-05-26 14:34:41|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:34:46|     0/   52| bits: 17.25
#   2020-05-26 14:34:46|    10/   52| bits: 2.46
#   2020-05-26 14:34:46|    20/   52| bits: 0.57
#   2020-05-26 14:34:47|    30/   52| bits: 0.25
#   2020-05-26 14:34:47|    40/   52| bits: 0.10
#   2020-05-26 14:34:47|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:34:51|     0/   52| bits: 0.04
#   2020-05-26 14:34:51|    10/   52| bits: 0.02
#   2020-05-26 14:34:51|    20/   52| bits: 0.01
#   2020-05-26 14:34:51|    30/   52| bits: 0.01
#   2020-05-26 14:34:51|    40/   52| bits: 0.01
#   2020-05-26 14:34:51|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:34:55|     0/   52| bits: 0.01
#   2020-05-26 14:34:55|    10/   52| bits: 0.01
#   2020-05-26 14:34:55|    20/   52| bits: 0.01
#   2020-05-26 14:34:55|    30/   52| bits: 0.01
#   2020-05-26 14:34:55|    40/   52| bits: 0.01
#   2020-05-26 14:34:55|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:35:01|     0/   52| bits: 11.04
#   2020-05-26 14:35:01|    10/   52| bits: 2.39
#   2020-05-26 14:35:01|    20/   52| bits: 0.57
#   2020-05-26 14:35:01|    30/   52| bits: 0.18
#   2020-05-26 14:35:01|    40/   52| bits: 0.07
#   2020-05-26 14:35:01|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.02
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:35:08|     0/   52| bits: 0.03
#   2020-05-26 14:35:08|    10/   52| bits: 0.02
#   2020-05-26 14:35:08|    20/   52| bits: 0.01
#   2020-05-26 14:35:08|    30/   52| bits: 0.01
#   2020-05-26 14:35:08|    40/   52| bits: 0.01
#   2020-05-26 14:35:08|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:35:12|     0/   52| bits: 0.01
#   2020-05-26 14:35:12|    10/   52| bits: 0.01
#   2020-05-26 14:35:12|    20/   52| bits: 0.01
#   2020-05-26 14:35:12|    30/   52| bits: 0.01
#   2020-05-26 14:35:12|    40/   52| bits: 0.01
#   2020-05-26 14:35:12|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:35:17|     0/   52| bits: 15.26
#   2020-05-26 14:35:18|    10/   52| bits: 3.13
#   2020-05-26 14:35:18|    20/   52| bits: 0.80
#   2020-05-26 14:35:18|    30/   52| bits: 0.26
#   2020-05-26 14:35:18|    40/   52| bits: 0.11
#   2020-05-26 14:35:18|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:35:25|     0/   52| bits: 0.04
#   2020-05-26 14:35:26|    10/   52| bits: 0.02
#   2020-05-26 14:35:26|    20/   52| bits: 0.02
#   2020-05-26 14:35:26|    30/   52| bits: 0.01
#   2020-05-26 14:35:26|    40/   52| bits: 0.01
#   2020-05-26 14:35:26|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:35:31|     0/   52| bits: 0.01
#   2020-05-26 14:35:31|    10/   52| bits: 0.01
#   2020-05-26 14:35:31|    20/   52| bits: 0.01
#   2020-05-26 14:35:31|    30/   52| bits: 0.01
#   2020-05-26 14:35:31|    40/   52| bits: 0.01
#   2020-05-26 14:35:31|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:35:35|     0/   52| bits: 17.00
#   2020-05-26 14:35:36|    10/   52| bits: 2.50
#   2020-05-26 14:35:36|    20/   52| bits: 0.56
#   2020-05-26 14:35:36|    30/   52| bits: 0.25
#   2020-05-26 14:35:36|    40/   52| bits: 0.09
#   2020-05-26 14:35:36|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:35:42|     0/   52| bits: 0.04
#   2020-05-26 14:35:43|    10/   52| bits: 0.02
#   2020-05-26 14:35:43|    20/   52| bits: 0.01
#   2020-05-26 14:35:43|    30/   52| bits: 0.01
#   2020-05-26 14:35:43|    40/   52| bits: 0.01
#   2020-05-26 14:35:43|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:35:48|     0/   52| bits: 0.01
#   2020-05-26 14:35:48|    10/   52| bits: 0.01
#   2020-05-26 14:35:48|    20/   52| bits: 0.01
#   2020-05-26 14:35:48|    30/   52| bits: 0.01
#   2020-05-26 14:35:48|    40/   52| bits: 0.01
#   2020-05-26 14:35:48|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# calculating for h:  500
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:35:52|     0/   52| bits: 15.62
#   2020-05-26 14:35:52|    10/   52| bits: 2.68
#   2020-05-26 14:35:52|    20/   52| bits: 0.61
#   2020-05-26 14:35:52|    30/   52| bits: 0.24
#   2020-05-26 14:35:52|    40/   52| bits: 0.09
#   2020-05-26 14:35:52|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:35:58|     0/   52| bits: 0.04
#   2020-05-26 14:35:58|    10/   52| bits: 0.02
#   2020-05-26 14:35:58|    20/   52| bits: 0.02
#   2020-05-26 14:35:58|    30/   52| bits: 0.01
#   2020-05-26 14:35:58|    40/   52| bits: 0.01
#   2020-05-26 14:35:58|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:36:04|     0/   52| bits: 0.01
#   2020-05-26 14:36:05|    10/   52| bits: 0.01
#   2020-05-26 14:36:05|    20/   52| bits: 0.01
#   2020-05-26 14:36:05|    30/   52| bits: 0.01
#   2020-05-26 14:36:05|    40/   52| bits: 0.01
#   2020-05-26 14:36:05|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:36:09|     0/   52| bits: 14.53
#   2020-05-26 14:36:09|    10/   52| bits: 2.97
#   2020-05-26 14:36:09|    20/   52| bits: 0.67
#   2020-05-26 14:36:09|    30/   52| bits: 0.22
#   2020-05-26 14:36:09|    40/   52| bits: 0.09
#   2020-05-26 14:36:09|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:36:13|     0/   52| bits: 0.03
#   2020-05-26 14:36:14|    10/   52| bits: 0.02
#   2020-05-26 14:36:14|    20/   52| bits: 0.01
#   2020-05-26 14:36:14|    30/   52| bits: 0.01
#   2020-05-26 14:36:14|    40/   52| bits: 0.01
#   2020-05-26 14:36:14|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:36:21|     0/   52| bits: 0.01
#   2020-05-26 14:36:22|    10/   52| bits: 0.01
#   2020-05-26 14:36:22|    20/   52| bits: 0.01
#   2020-05-26 14:36:22|    30/   52| bits: 0.01
#   2020-05-26 14:36:22|    40/   52| bits: 0.01
#   2020-05-26 14:36:22|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:36:27|     0/   52| bits: 15.63
#   2020-05-26 14:36:27|    10/   52| bits: 2.71
#   2020-05-26 14:36:27|    20/   52| bits: 0.64
#   2020-05-26 14:36:27|    30/   52| bits: 0.23
#   2020-05-26 14:36:27|    40/   52| bits: 0.10
#   2020-05-26 14:36:27|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:36:31|     0/   52| bits: 0.04
#   2020-05-26 14:36:31|    10/   52| bits: 0.02
#   2020-05-26 14:36:31|    20/   52| bits: 0.02
#   2020-05-26 14:36:31|    30/   52| bits: 0.02
#   2020-05-26 14:36:32|    40/   52| bits: 0.01
#   2020-05-26 14:36:32|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:36:37|     0/   52| bits: 0.01
#   2020-05-26 14:36:38|    10/   52| bits: 0.01
#   2020-05-26 14:36:38|    20/   52| bits: 0.01
#   2020-05-26 14:36:38|    30/   52| bits: 0.01
#   2020-05-26 14:36:38|    40/   52| bits: 0.01
#   2020-05-26 14:36:38|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:36:45|     0/   52| bits: 15.58
#   2020-05-26 14:36:45|    10/   52| bits: 2.41
#   2020-05-26 14:36:45|    20/   52| bits: 0.55
#   2020-05-26 14:36:45|    30/   52| bits: 0.22
#   2020-05-26 14:36:45|    40/   52| bits: 0.10
#   2020-05-26 14:36:45|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:36:49|     0/   52| bits: 0.04
#   2020-05-26 14:36:49|    10/   52| bits: 0.02
#   2020-05-26 14:36:49|    20/   52| bits: 0.01
#   2020-05-26 14:36:49|    30/   52| bits: 0.01
#   2020-05-26 14:36:49|    40/   52| bits: 0.01
#   2020-05-26 14:36:49|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:36:54|     0/   52| bits: 0.01
#   2020-05-26 14:36:54|    10/   52| bits: 0.01
#   2020-05-26 14:36:54|    20/   52| bits: 0.01
#   2020-05-26 14:36:54|    30/   52| bits: 0.01
#   2020-05-26 14:36:54|    40/   52| bits: 0.01
#   2020-05-26 14:36:54|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:37:02|     0/   52| bits: 16.09
#   2020-05-26 14:37:02|    10/   52| bits: 2.69
#   2020-05-26 14:37:02|    20/   52| bits: 0.65
#   2020-05-26 14:37:02|    30/   52| bits: 0.25
#   2020-05-26 14:37:02|    40/   52| bits: 0.09
#   2020-05-26 14:37:02|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:37:07|     0/   52| bits: 0.04
#   2020-05-26 14:37:07|    10/   52| bits: 0.02
#   2020-05-26 14:37:07|    20/   52| bits: 0.01
#   2020-05-26 14:37:07|    30/   52| bits: 0.01
#   2020-05-26 14:37:07|    40/   52| bits: 0.01
#   2020-05-26 14:37:07|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:37:10|     0/   52| bits: 0.01
#   2020-05-26 14:37:10|    10/   52| bits: 0.01
#   2020-05-26 14:37:11|    20/   52| bits: 0.01
#   2020-05-26 14:37:11|    30/   52| bits: 0.01
#   2020-05-26 14:37:11|    40/   52| bits: 0.01
#   2020-05-26 14:37:11|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:37:17|     0/   52| bits: 17.77
#   2020-05-26 14:37:17|    10/   52| bits: 2.97
#   2020-05-26 14:37:17|    20/   52| bits: 0.74
#   2020-05-26 14:37:17|    30/   52| bits: 0.26
#   2020-05-26 14:37:17|    40/   52| bits: 0.11
#   2020-05-26 14:37:17|    50/   52| bits: 0.05
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.04
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:37:24|     0/   52| bits: 0.04
#   2020-05-26 14:37:24|    10/   52| bits: 0.02
#   2020-05-26 14:37:24|    20/   52| bits: 0.02
#   2020-05-26 14:37:24|    30/   52| bits: 0.01
#   2020-05-26 14:37:24|    40/   52| bits: 0.01
#   2020-05-26 14:37:24|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:37:28|     0/   52| bits: 0.01
#   2020-05-26 14:37:28|    10/   52| bits: 0.01
#   2020-05-26 14:37:28|    20/   52| bits: 0.01
#   2020-05-26 14:37:28|    30/   52| bits: 0.01
#   2020-05-26 14:37:28|    40/   52| bits: 0.01
#   2020-05-26 14:37:28|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:37:34|     0/   52| bits: 13.55
#   2020-05-26 14:37:35|    10/   52| bits: 2.52
#   2020-05-26 14:37:35|    20/   52| bits: 0.59
#   2020-05-26 14:37:35|    30/   52| bits: 0.22
#   2020-05-26 14:37:35|    40/   52| bits: 0.09
#   2020-05-26 14:37:35|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:37:42|     0/   52| bits: 0.04
#   2020-05-26 14:37:42|    10/   52| bits: 0.02
#   2020-05-26 14:37:42|    20/   52| bits: 0.01
#   2020-05-26 14:37:42|    30/   52| bits: 0.01
#   2020-05-26 14:37:42|    40/   52| bits: 0.01
#   2020-05-26 14:37:42|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:37:46|     0/   52| bits: 0.01
#   2020-05-26 14:37:46|    10/   52| bits: 0.01
#   2020-05-26 14:37:46|    20/   52| bits: 0.01
#   2020-05-26 14:37:46|    30/   52| bits: 0.01
#   2020-05-26 14:37:46|    40/   52| bits: 0.01
#   2020-05-26 14:37:46|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:37:50|     0/   52| bits: 13.72
#   2020-05-26 14:37:50|    10/   52| bits: 2.22
#   2020-05-26 14:37:50|    20/   52| bits: 0.45
#   2020-05-26 14:37:51|    30/   52| bits: 0.18
#   2020-05-26 14:37:51|    40/   52| bits: 0.07
#   2020-05-26 14:37:51|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:37:58|     0/   52| bits: 0.03
#   2020-05-26 14:37:58|    10/   52| bits: 0.01
#   2020-05-26 14:37:58|    20/   52| bits: 0.01
#   2020-05-26 14:37:58|    30/   52| bits: 0.01
#   2020-05-26 14:37:58|    40/   52| bits: 0.01
#   2020-05-26 14:37:59|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:38:03|     0/   52| bits: 0.01
#   2020-05-26 14:38:03|    10/   52| bits: 0.01
#   2020-05-26 14:38:03|    20/   52| bits: 0.01
#   2020-05-26 14:38:03|    30/   52| bits: 0.01
#   2020-05-26 14:38:04|    40/   52| bits: 0.01
#   2020-05-26 14:38:04|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:38:08|     0/   52| bits: 14.13
#   2020-05-26 14:38:08|    10/   52| bits: 2.70
#   2020-05-26 14:38:08|    20/   52| bits: 0.55
#   2020-05-26 14:38:08|    30/   52| bits: 0.20
#   2020-05-26 14:38:08|    40/   52| bits: 0.09
#   2020-05-26 14:38:08|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:38:13|     0/   52| bits: 0.04
#   2020-05-26 14:38:14|    10/   52| bits: 0.02
#   2020-05-26 14:38:14|    20/   52| bits: 0.01
#   2020-05-26 14:38:14|    30/   52| bits: 0.01
#   2020-05-26 14:38:14|    40/   52| bits: 0.01
#   2020-05-26 14:38:14|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:38:21|     0/   52| bits: 0.01
#   2020-05-26 14:38:21|    10/   52| bits: 0.01
#   2020-05-26 14:38:21|    20/   52| bits: 0.01
#   2020-05-26 14:38:21|    30/   52| bits: 0.01
#   2020-05-26 14:38:21|    40/   52| bits: 0.01
#   2020-05-26 14:38:21|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:38:25|     0/   52| bits: 15.32
#   2020-05-26 14:38:25|    10/   52| bits: 2.43
#   2020-05-26 14:38:25|    20/   52| bits: 0.62
#   2020-05-26 14:38:25|    30/   52| bits: 0.24
#   2020-05-26 14:38:25|    40/   52| bits: 0.10
#   2020-05-26 14:38:25|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:38:30|     0/   52| bits: 0.03
#   2020-05-26 14:38:30|    10/   52| bits: 0.02
#   2020-05-26 14:38:30|    20/   52| bits: 0.01
#   2020-05-26 14:38:30|    30/   52| bits: 0.01
#   2020-05-26 14:38:30|    40/   52| bits: 0.01
#   2020-05-26 14:38:30|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:38:38|     0/   52| bits: 0.01
#   2020-05-26 14:38:38|    10/   52| bits: 0.01
#   2020-05-26 14:38:38|    20/   52| bits: 0.01
#   2020-05-26 14:38:38|    30/   52| bits: 0.01
#   2020-05-26 14:38:38|    40/   52| bits: 0.01
#   2020-05-26 14:38:38|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.01
# calculating for h:  300
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:38:43|     0/   52| bits: 17.04
#   2020-05-26 14:38:44|    10/   52| bits: 2.53
#   2020-05-26 14:38:44|    20/   52| bits: 0.54
#   2020-05-26 14:38:44|    30/   52| bits: 0.22
#   2020-05-26 14:38:44|    40/   52| bits: 0.10
#   2020-05-26 14:38:44|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:38:47|     0/   52| bits: 0.04
#   2020-05-26 14:38:47|    10/   52| bits: 0.02
#   2020-05-26 14:38:47|    20/   52| bits: 0.01
#   2020-05-26 14:38:48|    30/   52| bits: 0.01
#   2020-05-26 14:38:48|    40/   52| bits: 0.01
#   2020-05-26 14:38:48|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:38:53|     0/   52| bits: 0.01
#   2020-05-26 14:38:54|    10/   52| bits: 0.01
#   2020-05-26 14:38:54|    20/   52| bits: 0.01
#   2020-05-26 14:38:54|    30/   52| bits: 0.01
#   2020-05-26 14:38:54|    40/   52| bits: 0.01
#   2020-05-26 14:38:54|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:39:01|     0/   52| bits: 12.63
#   2020-05-26 14:39:01|    10/   52| bits: 2.72
#   2020-05-26 14:39:01|    20/   52| bits: 0.66
#   2020-05-26 14:39:01|    30/   52| bits: 0.21
#   2020-05-26 14:39:01|    40/   52| bits: 0.07
#   2020-05-26 14:39:01|    50/   52| bits: 0.03
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:39:05|     0/   52| bits: 0.03
#   2020-05-26 14:39:05|    10/   52| bits: 0.02
#   2020-05-26 14:39:05|    20/   52| bits: 0.01
#   2020-05-26 14:39:05|    30/   52| bits: 0.01
#   2020-05-26 14:39:05|    40/   52| bits: 0.01
#   2020-05-26 14:39:05|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:39:09|     0/   52| bits: 0.01
#   2020-05-26 14:39:09|    10/   52| bits: 0.01
#   2020-05-26 14:39:09|    20/   52| bits: 0.01
#   2020-05-26 14:39:09|    30/   52| bits: 0.01
#   2020-05-26 14:39:09|    40/   52| bits: 0.01
#   2020-05-26 14:39:09|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:39:15|     0/   52| bits: 12.65
#   2020-05-26 14:39:15|    10/   52| bits: 2.74
#   2020-05-26 14:39:16|    20/   52| bits: 0.68
#   2020-05-26 14:39:16|    30/   52| bits: 0.22
#   2020-05-26 14:39:16|    40/   52| bits: 0.09
#   2020-05-26 14:39:16|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:39:22|     0/   52| bits: 0.03
#   2020-05-26 14:39:22|    10/   52| bits: 0.02
#   2020-05-26 14:39:22|    20/   52| bits: 0.02
#   2020-05-26 14:39:22|    30/   52| bits: 0.01
#   2020-05-26 14:39:23|    40/   52| bits: 0.01
#   2020-05-26 14:39:23|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   3/  3
#   2020-05-26 14:39:26|     0/   52| bits: 0.01
#   2020-05-26 14:39:26|    10/   52| bits: 0.01
#   2020-05-26 14:39:26|    20/   52| bits: 0.01
#   2020-05-26 14:39:26|    30/   52| bits: 0.01
#   2020-05-26 14:39:26|    40/   52| bits: 0.01
#   2020-05-26 14:39:26|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.01
# --------------------------------------------------
# Epoch   1/  3
#   2020-05-26 14:39:31|     0/   52| bits: 17.09
#   2020-05-26 14:39:31|    10/   52| bits: 2.90
#   2020-05-26 14:39:31|    20/   52| bits: 0.71
#   2020-05-26 14:39:31|    30/   52| bits: 0.26
#   2020-05-26 14:39:31|    40/   52| bits: 0.11
#   2020-05-26 14:39:31|    50/   52| bits: 0.04
# Elapsed time: 0h 0m 2s
# Validation| bits: 0.03
# --------------------------------------------------
# Epoch   2/  3
#   2020-05-26 14:39:38|     0/   52| bits: 0.04
#   2020-05-26 14:39:38|    10/   52| bits: 0.02
#   2020-05-26 14:39:38|    20/   52| bits: 0.01
#   2020-05-26 14:39:38|    30/   52| bits: 0.01
#   2020-05-26 14:39:38|    40/   52| bits: 0.01
#   2020-05-26 14:39:38|    50/   52| bits: 0.01
# Elapsed time: 0h 0m 3s

# %%
plt.figure(figsize = (20,12))
plt.plot(hs, error)
plt.show()
