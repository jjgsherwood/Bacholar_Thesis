# %%
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.utils.validation import check_array, check_is_fitted

import numpy as np
import matplotlib.pyplot as plt
import os
import copy
import inspect
import random
import shutil

from datetime import datetime
from dateutil.relativedelta import relativedelta

from scipy import optimize, ndimage
from sklearn import decomposition, cluster, model_selection, metrics
import sklearn

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import utils.dataset_utils as dataset
import utils.train_utils as train

import numpy.polynomial.polynomial as poly

# %%
def unit_vector_norm(X):
    return (X.T / np.sqrt((X**2).sum(axis=1))).T

def split_Raman_af(X):
    """
    Removing spikes from the data to extract the autofluorescence.
    This is done by applying smoothing filter to the data and then taking the min of the smoothing filter and original data.
    """
    a = X
    c = 50

    # remove the top of the spikes from data, by using a Gaussian smoothing filter
    for _ in range(5):      
        a[:,c] = X[:,c]
        a[:,-c] = X[:,-c]      
        a1 = ndimage.gaussian_filter(a, (0, 30), mode='nearest')
        a = np.min([a, a1], axis=0)

    # remove the spikes from data, by using a polynominal fit
    for _ in range(5):
        a[:,c] = X[:,c]
        a[:,-c] = X[:,-c]        
        z = poly.polyfit(wavelength[::5], a[:,::5].T, 5)
        a1 = poly.polyval(wavelength, z)
        a = np.min([a, a1], axis=0)
        
    # smooth the curve the data, (to remove remnants of noise in the photoluminescence signal)
    for _ in range(10):           
        a[:,1] = X[:,1]
        a[:,-1] = X[:,-1]         
        a = ndimage.gaussian_filter(a, (0, 10), mode='nearest')

    # make the Raman signal non-negative, (to remove remnants of noise in the Raman signal)
    return (X-a).clip(min=0), a 

def smoothing(X, smooth=5, transition=10, spike_width=7):
    """
    Only remove noise from low noise to signal area's to maintain the intensity of the spikes.
    Noise is removed with a gaussian filter in spectral dimension.
    """
    grad = ndimage.gaussian_filter(X, (0, 1), order=1)
    grad_abs = np.abs(grad)
    grad_abs_sm = ndimage.gaussian_filter(grad_abs, (0, 5))
    mean_grad = np.mean(grad_abs, 1) + 1 / np.std(grad_abs, 1) * 3
    
    spikes = ((grad_abs_sm.T > mean_grad ).astype(float)).T 
    spikes = np.round(ndimage.gaussian_filter(spikes, (0, spike_width)))
    spikes = ndimage.uniform_filter(spikes, (0, transition))
    
    return (1 - spikes) * ndimage.gaussian_filter(X, (0,smooth)) + spikes * X

class View(nn.Module):
    def __init__(self, shape):
        super().__init__()
        self.shape = shape

    def forward(self, x):
        return x.view(*self.shape)

# %%
N_WAVE = 2126

wavelength = np.load("../data/Raman/wavelength.npy", 'r')

# Z = np.load("../data/Raman/Alina_Art_4_2.npy", 'r')

shape_Z = (70,90,2126)

# Z = copy.copy(Z.reshape(-1, Z.shape[-1]))

# Z_smooth = smoothing(Z)
# ram_Z, afl_Z = split_Raman_af(Z_smooth)

ram_Z = np.load("../data/Raman/Alina_4_ram.npy", 'r')
ram_Z = copy.copy(ram_Z)

# %%
class AutoEncoder(nn.Module):
    def __init__(self, n_components=10, depth=2, neurons=100, bias=True, **kwargs):
        super().__init__()
        self.encode = nn.Sequential( 
            nn.Dropout3d(0.25),
            nn.Flatten(),
            nn.Linear(N_WAVE, neurons, bias=bias),
            nn.ReLU(True),
            *((nn.Linear(neurons, neurons, bias=bias),
            nn.ReLU(True)) * (depth-1)),
            nn.Linear(neurons, n_components, bias=bias),
            nn.Softmax(1),
        )
        
        self.decode = nn.Sequential(
            nn.Linear(n_components, neurons, bias=bias),
            nn.ReLU(True),
            *((nn.Linear(neurons, neurons, bias=bias),
            nn.ReLU(True)) * (depth-1)),            
            nn.Linear(neurons, N_WAVE, bias=bias),
            View((-1,1,1,1,N_WAVE)),
        )
        
    def forward(self, x):
        return self.decode(self.encode(x))

# %%
def MSE_loss(x, model):
    W = model.encode(x)
    x_ = model.decode(W)

    alpha = 0.8
    rho = 0.8
    
    max_ref_diff = alpha * torch.abs(W).sum(1).mean(0)        
    max_ref_diff += (1 - alpha) * ((W.sum(1))**2).mean(0)
        
    #MSE loss
    MSE = ((x_ - x)**2).sum(4).mean()  
    
    return rho * MSE + (1 - rho) * max_ref_diff

# %%
class ReferenceVectorClassifierAE(BaseEstimator):
    def __init__(self, **kwargs):
        self.kwargs = {}
        self.ae_kwargs = {}
        self.k_means_kwargs = {}                
        self.set_params(**kwargs)

        _use_cuda = torch.cuda.is_available() and kwargs['cuda']
        if _use_cuda:
            torch.backends.cudnn.enabled = True
            torch.backends.cudnn.benchmark = True
        self.device = torch.device('cuda' if _use_cuda else 'cpu')        
        
    def fit(self, x, **kwargs):
        self.set_params(**kwargs)
        X = unit_vector_norm(x)
        
        ###################### Autoencoder ################################
        self.model = AutoEncoder(**self.ae_kwargs).to(self.device)
        
        parameters = filter(lambda x: x.requires_grad, self.model.parameters())
        self.optimizer = optim.Adam(parameters)        
        train_loader, test_loader = dataset.load_liver(X, self.kwargs['batch_size'])
        
        for epoch in range(self.kwargs['epochs']):
            print('-'*50)
            print('Epoch {:3d}/{:3d}'.format(epoch+1, self.kwargs['epochs']))
            start_time = datetime.now()
            train.train(self.model, self.optimizer, train_loader, self.kwargs['loss_func'], self.kwargs['log_step'], self.device)
            end_time = datetime.now()
            time_diff = relativedelta(end_time, start_time)
            print('Elapsed time: {}h {}m {}s'.format(time_diff.hours, time_diff.minutes, time_diff.seconds))
            loss = train.test(self.model, test_loader, self.kwargs['loss_func'], self.device)
            print('Validation| bits: {:2.2f}'.format(loss), flush=True)    
          
        self.model.eval()
        with torch.no_grad():
            W = self.model.encode(dataset.load_liver_all(X).to(self.device))
        self.z = W
        W = W.cpu().detach().numpy()
        
        ###################### clustering ################################        
        self.clusters = cluster.KMeans(**self.k_means_kwargs).fit(W)
        self.clusters = self.clusters.labels_
        
        one_hot = np.zeros((X.shape[0], self.kwargs['n_clusters']), dtype=bool)
        one_hot[range(X.shape[0]), self.clusters] = 1
                          
        ###################### reference spectra ################################
        self.reference_spectra_ = unit_vector_norm(np.array([np.abs(x_) for i, x_ in enumerate(one_hot.T @ X)]))
        self.ref_org = np.array([x[one_hot[:,i],:].mean(axis=0) for i in range(self.kwargs['n_clusters'])])
               
        # Return the classifier
        return self
    
    def predict(self, X):
        """
        predict transforms the data into the reference space. Min weight should be 0 or higher then 'min_weight'
        The error is the NMSE, where the MSE is normalised by the signal strength. 
        error.shape = X.shape[0], so for each data point the error is calculated.
        """
        # Check is fit had been called
        check_is_fitted(self)

        # Input validation
        X = check_array(X)
        X = unit_vector_norm(X)
        
        ###################### RCA ################################           
        RCA_vector = np.array([optimize.nnls(self.reference_spectra_.T, X[i,:])[0] for i in range(X.shape[0])])

        return RCA_vector
    
    def get_reference_vectors(self):
        return self.reference_spectra_

    def get_org_reference_vectors(self):
        return self.ref_org    
    
    def get_Y(self, X):
        return self.model(dataset.load_liver_all(unit_vector_norm(X)).to(self.device)).squeeze().cpu().detach().numpy()
    
    def get_params(self, deep=False):
        return self.kwargs
    
    def set_params(self, **kwargs):
        self.kwargs.update(kwargs)
        self.k_means_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(cluster.KMeans).parameters.keys())})     
        self.ae_kwargs.update({k:v  for k,v in kwargs.items() if k in list(inspect.signature(AutoEncoder).parameters.keys())})     
        return self

# %%
def error_map(estimator, X, y=None):
    Y = estimator.get_Y(X)
    return ((Y - X)**2).sum(1)

def score_func(estimator, X, y=None):
    tmp = np.sqrt((X**2).sum(axis=1))
    X = unit_vector_norm(X)
    return (error_map(estimator, X) * tmp).mean()

def print_mean_std(X):
    return f"{X.mean():<12.4e}{X.std():<12.4e}"

def cross_val_X_Y_Z(rvc, X, Y, Z):
    rvc.fit(np.concatenate((X, Y), axis=0))
    return score_func(rvc, Z)

# %%
kwargs = {'n_components': 3,
          'n_clusters': 3,
          'batch_size': 32,
          'cuda': True,
          'log_step': 30,
          'loss_func': MSE_loss,
          'epochs': 20,
          'depth': 4,
          'neurons': 266,
          'bias': True
         }

# %%
score = []
for i in range(10):
    print(i)
    rvc = ReferenceVectorClassifierAE(**kwargs)
    rvc.fit(ram_Z)
    score.append(score_func(rvc, ram_Z))
print(score)
print(np.mean(score), np.std(score))
del score[np.argmax(score)]
del score[np.argmin(score)]
print(score)
print(np.mean(score), np.std(score))
# Out:
# 0
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:04:07|     0/  178| bits: 3.65
#   2020-07-19 00:04:08|    30/  178| bits: 0.34
#   2020-07-19 00:04:08|    60/  178| bits: 0.23
#   2020-07-19 00:04:08|    90/  178| bits: 0.27
#   2020-07-19 00:04:09|   120/  178| bits: 0.22
#   2020-07-19 00:04:09|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:04:13|     0/  178| bits: 0.26
#   2020-07-19 00:04:13|    30/  178| bits: 0.22
#   2020-07-19 00:04:13|    60/  178| bits: 0.21
#   2020-07-19 00:04:14|    90/  178| bits: 0.25
#   2020-07-19 00:04:14|   120/  178| bits: 0.25
#   2020-07-19 00:04:14|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:04:19|     0/  178| bits: 0.21
#   2020-07-19 00:04:19|    30/  178| bits: 0.25
#   2020-07-19 00:04:19|    60/  178| bits: 0.21
#   2020-07-19 00:04:20|    90/  178| bits: 0.27
#   2020-07-19 00:04:20|   120/  178| bits: 0.21
#   2020-07-19 00:04:20|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 4s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:04:24|     0/  178| bits: 0.26
#   2020-07-19 00:04:25|    30/  178| bits: 0.26
#   2020-07-19 00:04:25|    60/  178| bits: 0.22
#   2020-07-19 00:04:25|    90/  178| bits: 0.25
#   2020-07-19 00:04:25|   120/  178| bits: 0.23
#   2020-07-19 00:04:26|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:04:30|     0/  178| bits: 0.23
#   2020-07-19 00:04:30|    30/  178| bits: 0.26
#   2020-07-19 00:04:30|    60/  178| bits: 0.23
#   2020-07-19 00:04:31|    90/  178| bits: 0.25
#   2020-07-19 00:04:31|   120/  178| bits: 0.23
#   2020-07-19 00:04:31|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:04:35|     0/  178| bits: 0.24
#   2020-07-19 00:04:36|    30/  178| bits: 0.22
#   2020-07-19 00:04:36|    60/  178| bits: 0.25
#   2020-07-19 00:04:36|    90/  178| bits: 0.29
#   2020-07-19 00:04:37|   120/  178| bits: 0.23
#   2020-07-19 00:04:37|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:04:41|     0/  178| bits: 0.21
#   2020-07-19 00:04:41|    30/  178| bits: 0.24
#   2020-07-19 00:04:41|    60/  178| bits: 0.23
#   2020-07-19 00:04:42|    90/  178| bits: 0.24
#   2020-07-19 00:04:42|   120/  178| bits: 0.21
#   2020-07-19 00:04:42|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:04:46|     0/  178| bits: 0.22
#   2020-07-19 00:04:46|    30/  178| bits: 0.21
#   2020-07-19 00:04:47|    60/  178| bits: 0.21
#   2020-07-19 00:04:47|    90/  178| bits: 0.29
#   2020-07-19 00:04:47|   120/  178| bits: 0.23
#   2020-07-19 00:04:48|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:04:52|     0/  178| bits: 0.21
#   2020-07-19 00:04:52|    30/  178| bits: 0.22
#   2020-07-19 00:04:52|    60/  178| bits: 0.24
#   2020-07-19 00:04:53|    90/  178| bits: 0.29
#   2020-07-19 00:04:53|   120/  178| bits: 0.21
#   2020-07-19 00:04:53|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:04:57|     0/  178| bits: 0.21
#   2020-07-19 00:04:57|    30/  178| bits: 0.23
#   2020-07-19 00:04:58|    60/  178| bits: 0.21
#   2020-07-19 00:04:58|    90/  178| bits: 0.21
#   2020-07-19 00:04:58|   120/  178| bits: 0.21
#   2020-07-19 00:04:59|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:05:03|     0/  178| bits: 0.23
#   2020-07-19 00:05:03|    30/  178| bits: 0.22
#   2020-07-19 00:05:03|    60/  178| bits: 0.21
#   2020-07-19 00:05:04|    90/  178| bits: 0.21
#   2020-07-19 00:05:04|   120/  178| bits: 0.21
#   2020-07-19 00:05:04|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:05:08|     0/  178| bits: 0.22
#   2020-07-19 00:05:08|    30/  178| bits: 0.21
#   2020-07-19 00:05:09|    60/  178| bits: 0.25
#   2020-07-19 00:05:09|    90/  178| bits: 0.21
#   2020-07-19 00:05:09|   120/  178| bits: 0.24
#   2020-07-19 00:05:10|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:05:14|     0/  178| bits: 0.22
#   2020-07-19 00:05:14|    30/  178| bits: 0.21
#   2020-07-19 00:05:14|    60/  178| bits: 0.21
#   2020-07-19 00:05:15|    90/  178| bits: 0.22
#   2020-07-19 00:05:15|   120/  178| bits: 0.23
#   2020-07-19 00:05:15|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:05:19|     0/  178| bits: 0.20
#   2020-07-19 00:05:19|    30/  178| bits: 0.21
#   2020-07-19 00:05:20|    60/  178| bits: 0.22
#   2020-07-19 00:05:20|    90/  178| bits: 0.21
#   2020-07-19 00:05:20|   120/  178| bits: 0.22
#   2020-07-19 00:05:21|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:05:25|     0/  178| bits: 0.21
#   2020-07-19 00:05:25|    30/  178| bits: 0.23
#   2020-07-19 00:05:25|    60/  178| bits: 0.21
#   2020-07-19 00:05:26|    90/  178| bits: 0.22
#   2020-07-19 00:05:26|   120/  178| bits: 0.21
#   2020-07-19 00:05:26|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:05:30|     0/  178| bits: 0.22
#   2020-07-19 00:05:30|    30/  178| bits: 0.22
#   2020-07-19 00:05:31|    60/  178| bits: 0.22
#   2020-07-19 00:05:31|    90/  178| bits: 0.23
#   2020-07-19 00:05:31|   120/  178| bits: 0.21
#   2020-07-19 00:05:32|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:05:36|     0/  178| bits: 0.26
#   2020-07-19 00:05:36|    30/  178| bits: 0.23
#   2020-07-19 00:05:36|    60/  178| bits: 0.21
#   2020-07-19 00:05:37|    90/  178| bits: 0.24
#   2020-07-19 00:05:37|   120/  178| bits: 0.23
#   2020-07-19 00:05:37|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:05:41|     0/  178| bits: 0.22
#   2020-07-19 00:05:41|    30/  178| bits: 0.24
#   2020-07-19 00:05:42|    60/  178| bits: 0.21
#   2020-07-19 00:05:42|    90/  178| bits: 0.21
#   2020-07-19 00:05:42|   120/  178| bits: 0.23
#   2020-07-19 00:05:43|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:05:47|     0/  178| bits: 0.21
#   2020-07-19 00:05:47|    30/  178| bits: 0.24
#   2020-07-19 00:05:47|    60/  178| bits: 0.25
#   2020-07-19 00:05:47|    90/  178| bits: 0.21
#   2020-07-19 00:05:48|   120/  178| bits: 0.21
#   2020-07-19 00:05:48|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:05:52|     0/  178| bits: 0.24
#   2020-07-19 00:05:52|    30/  178| bits: 0.24
#   2020-07-19 00:05:53|    60/  178| bits: 0.23
#   2020-07-19 00:05:53|    90/  178| bits: 0.25
#   2020-07-19 00:05:53|   120/  178| bits: 0.21
#   2020-07-19 00:05:54|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 1
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:05:58|     0/  178| bits: 3.69
#   2020-07-19 00:05:59|    30/  178| bits: 0.32
#   2020-07-19 00:05:59|    60/  178| bits: 0.28
#   2020-07-19 00:05:59|    90/  178| bits: 0.22
#   2020-07-19 00:06:00|   120/  178| bits: 0.29
#   2020-07-19 00:06:00|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:06:04|     0/  178| bits: 0.27
#   2020-07-19 00:06:04|    30/  178| bits: 0.22
#   2020-07-19 00:06:04|    60/  178| bits: 0.23
#   2020-07-19 00:06:05|    90/  178| bits: 0.22
#   2020-07-19 00:06:05|   120/  178| bits: 0.23
#   2020-07-19 00:06:05|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:06:09|     0/  178| bits: 0.22
#   2020-07-19 00:06:10|    30/  178| bits: 0.24
#   2020-07-19 00:06:10|    60/  178| bits: 0.23
#   2020-07-19 00:06:10|    90/  178| bits: 0.22
#   2020-07-19 00:06:11|   120/  178| bits: 0.22
#   2020-07-19 00:06:11|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:06:15|     0/  178| bits: 0.25
#   2020-07-19 00:06:15|    30/  178| bits: 0.28
#   2020-07-19 00:06:15|    60/  178| bits: 0.23
#   2020-07-19 00:06:16|    90/  178| bits: 0.22
#   2020-07-19 00:06:16|   120/  178| bits: 0.28
#   2020-07-19 00:06:16|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:06:20|     0/  178| bits: 0.27
#   2020-07-19 00:06:21|    30/  178| bits: 0.28
#   2020-07-19 00:06:21|    60/  178| bits: 0.26
#   2020-07-19 00:06:21|    90/  178| bits: 0.24
#   2020-07-19 00:06:22|   120/  178| bits: 0.22
#   2020-07-19 00:06:22|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:06:26|     0/  178| bits: 0.23
#   2020-07-19 00:06:26|    30/  178| bits: 0.24
#   2020-07-19 00:06:26|    60/  178| bits: 0.24
#   2020-07-19 00:06:27|    90/  178| bits: 0.25
#   2020-07-19 00:06:27|   120/  178| bits: 0.28
#   2020-07-19 00:06:27|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:06:31|     0/  178| bits: 0.21
#   2020-07-19 00:06:32|    30/  178| bits: 0.26
#   2020-07-19 00:06:32|    60/  178| bits: 0.24
#   2020-07-19 00:06:32|    90/  178| bits: 0.25
#   2020-07-19 00:06:33|   120/  178| bits: 0.26
#   2020-07-19 00:06:33|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:06:37|     0/  178| bits: 0.22
#   2020-07-19 00:06:37|    30/  178| bits: 0.21
#   2020-07-19 00:06:37|    60/  178| bits: 0.21
#   2020-07-19 00:06:38|    90/  178| bits: 0.21
#   2020-07-19 00:06:38|   120/  178| bits: 0.24
#   2020-07-19 00:06:38|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:06:42|     0/  178| bits: 0.25
#   2020-07-19 00:06:43|    30/  178| bits: 0.21
#   2020-07-19 00:06:43|    60/  178| bits: 0.21
#   2020-07-19 00:06:43|    90/  178| bits: 0.21
#   2020-07-19 00:06:44|   120/  178| bits: 0.24
#   2020-07-19 00:06:44|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:06:48|     0/  178| bits: 0.23
#   2020-07-19 00:06:48|    30/  178| bits: 0.24
#   2020-07-19 00:06:48|    60/  178| bits: 0.23
#   2020-07-19 00:06:49|    90/  178| bits: 0.25
#   2020-07-19 00:06:49|   120/  178| bits: 0.23
#   2020-07-19 00:06:49|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:06:53|     0/  178| bits: 0.21
#   2020-07-19 00:06:54|    30/  178| bits: 0.24
#   2020-07-19 00:06:54|    60/  178| bits: 0.22
#   2020-07-19 00:06:54|    90/  178| bits: 0.21
#   2020-07-19 00:06:55|   120/  178| bits: 0.21
#   2020-07-19 00:06:55|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:06:59|     0/  178| bits: 0.23
#   2020-07-19 00:06:59|    30/  178| bits: 0.22
#   2020-07-19 00:06:59|    60/  178| bits: 0.23
#   2020-07-19 00:07:00|    90/  178| bits: 0.22
#   2020-07-19 00:07:00|   120/  178| bits: 0.21
#   2020-07-19 00:07:00|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:07:04|     0/  178| bits: 0.21
#   2020-07-19 00:07:05|    30/  178| bits: 0.22
#   2020-07-19 00:07:05|    60/  178| bits: 0.22
#   2020-07-19 00:07:05|    90/  178| bits: 0.24
#   2020-07-19 00:07:06|   120/  178| bits: 0.20
#   2020-07-19 00:07:06|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:07:10|     0/  178| bits: 0.23
#   2020-07-19 00:07:10|    30/  178| bits: 0.24
#   2020-07-19 00:07:10|    60/  178| bits: 0.22
#   2020-07-19 00:07:11|    90/  178| bits: 0.21
#   2020-07-19 00:07:11|   120/  178| bits: 0.21
#   2020-07-19 00:07:11|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:07:15|     0/  178| bits: 0.22
#   2020-07-19 00:07:16|    30/  178| bits: 0.21
#   2020-07-19 00:07:16|    60/  178| bits: 0.24
#   2020-07-19 00:07:16|    90/  178| bits: 0.22
#   2020-07-19 00:07:17|   120/  178| bits: 0.25
#   2020-07-19 00:07:17|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:07:21|     0/  178| bits: 0.23
#   2020-07-19 00:07:21|    30/  178| bits: 0.23
#   2020-07-19 00:07:21|    60/  178| bits: 0.24
#   2020-07-19 00:07:22|    90/  178| bits: 0.26
#   2020-07-19 00:07:22|   120/  178| bits: 0.23
#   2020-07-19 00:07:22|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:07:26|     0/  178| bits: 0.21
#   2020-07-19 00:07:27|    30/  178| bits: 0.21
#   2020-07-19 00:07:27|    60/  178| bits: 0.23
#   2020-07-19 00:07:27|    90/  178| bits: 0.21
#   2020-07-19 00:07:28|   120/  178| bits: 0.22
#   2020-07-19 00:07:28|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:07:32|     0/  178| bits: 0.22
#   2020-07-19 00:07:32|    30/  178| bits: 0.23
#   2020-07-19 00:07:32|    60/  178| bits: 0.22
#   2020-07-19 00:07:33|    90/  178| bits: 0.21
#   2020-07-19 00:07:33|   120/  178| bits: 0.22
#   2020-07-19 00:07:33|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:07:37|     0/  178| bits: 0.23
#   2020-07-19 00:07:38|    30/  178| bits: 0.23
#   2020-07-19 00:07:38|    60/  178| bits: 0.25
#   2020-07-19 00:07:38|    90/  178| bits: 0.21
#   2020-07-19 00:07:39|   120/  178| bits: 0.24
#   2020-07-19 00:07:39|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:07:43|     0/  178| bits: 0.22
#   2020-07-19 00:07:43|    30/  178| bits: 0.23
#   2020-07-19 00:07:43|    60/  178| bits: 0.24
#   2020-07-19 00:07:44|    90/  178| bits: 0.21
#   2020-07-19 00:07:44|   120/  178| bits: 0.23
#   2020-07-19 00:07:44|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 2
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:07:49|     0/  178| bits: 3.92
#   2020-07-19 00:07:49|    30/  178| bits: 0.32
#   2020-07-19 00:07:50|    60/  178| bits: 0.27
#   2020-07-19 00:07:50|    90/  178| bits: 0.22
#   2020-07-19 00:07:50|   120/  178| bits: 0.22
#   2020-07-19 00:07:51|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:07:54|     0/  178| bits: 0.26
#   2020-07-19 00:07:55|    30/  178| bits: 0.22
#   2020-07-19 00:07:55|    60/  178| bits: 0.26
#   2020-07-19 00:07:55|    90/  178| bits: 0.26
#   2020-07-19 00:07:56|   120/  178| bits: 0.22
#   2020-07-19 00:07:56|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:08:00|     0/  178| bits: 0.29
#   2020-07-19 00:08:00|    30/  178| bits: 0.23
#   2020-07-19 00:08:01|    60/  178| bits: 0.23
#   2020-07-19 00:08:01|    90/  178| bits: 0.21
#   2020-07-19 00:08:01|   120/  178| bits: 0.25
#   2020-07-19 00:08:02|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:08:05|     0/  178| bits: 0.30
#   2020-07-19 00:08:06|    30/  178| bits: 0.22
#   2020-07-19 00:08:06|    60/  178| bits: 0.22
#   2020-07-19 00:08:06|    90/  178| bits: 0.21
#   2020-07-19 00:08:07|   120/  178| bits: 0.23
#   2020-07-19 00:08:07|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:08:11|     0/  178| bits: 0.25
#   2020-07-19 00:08:11|    30/  178| bits: 0.25
#   2020-07-19 00:08:12|    60/  178| bits: 0.22
#   2020-07-19 00:08:12|    90/  178| bits: 0.23
#   2020-07-19 00:08:12|   120/  178| bits: 0.22
#   2020-07-19 00:08:13|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:08:16|     0/  178| bits: 0.29
#   2020-07-19 00:08:17|    30/  178| bits: 0.21
#   2020-07-19 00:08:17|    60/  178| bits: 0.24
#   2020-07-19 00:08:17|    90/  178| bits: 0.24
#   2020-07-19 00:08:18|   120/  178| bits: 0.23
#   2020-07-19 00:08:18|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:08:22|     0/  178| bits: 0.23
#   2020-07-19 00:08:22|    30/  178| bits: 0.25
#   2020-07-19 00:08:23|    60/  178| bits: 0.23
#   2020-07-19 00:08:23|    90/  178| bits: 0.21
#   2020-07-19 00:08:23|   120/  178| bits: 0.21
#   2020-07-19 00:08:24|   150/  178| bits: 0.29
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:08:27|     0/  178| bits: 0.22
#   2020-07-19 00:08:28|    30/  178| bits: 0.24
#   2020-07-19 00:08:28|    60/  178| bits: 0.22
#   2020-07-19 00:08:28|    90/  178| bits: 0.27
#   2020-07-19 00:08:29|   120/  178| bits: 0.24
#   2020-07-19 00:08:29|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:08:33|     0/  178| bits: 0.21
#   2020-07-19 00:08:33|    30/  178| bits: 0.21
#   2020-07-19 00:08:34|    60/  178| bits: 0.21
#   2020-07-19 00:08:34|    90/  178| bits: 0.24
#   2020-07-19 00:08:34|   120/  178| bits: 0.24
#   2020-07-19 00:08:35|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:08:38|     0/  178| bits: 0.22
#   2020-07-19 00:08:39|    30/  178| bits: 0.26
#   2020-07-19 00:08:39|    60/  178| bits: 0.25
#   2020-07-19 00:08:39|    90/  178| bits: 0.26
#   2020-07-19 00:08:40|   120/  178| bits: 0.24
#   2020-07-19 00:08:40|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:08:44|     0/  178| bits: 0.25
#   2020-07-19 00:08:44|    30/  178| bits: 0.22
#   2020-07-19 00:08:45|    60/  178| bits: 0.26
#   2020-07-19 00:08:45|    90/  178| bits: 0.26
#   2020-07-19 00:08:45|   120/  178| bits: 0.22
#   2020-07-19 00:08:46|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:08:49|     0/  178| bits: 0.23
#   2020-07-19 00:08:50|    30/  178| bits: 0.21
#   2020-07-19 00:08:50|    60/  178| bits: 0.28
#   2020-07-19 00:08:50|    90/  178| bits: 0.21
#   2020-07-19 00:08:51|   120/  178| bits: 0.24
#   2020-07-19 00:08:51|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:08:55|     0/  178| bits: 0.22
#   2020-07-19 00:08:55|    30/  178| bits: 0.24
#   2020-07-19 00:08:56|    60/  178| bits: 0.23
#   2020-07-19 00:08:56|    90/  178| bits: 0.21
#   2020-07-19 00:08:56|   120/  178| bits: 0.24
#   2020-07-19 00:08:57|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:09:00|     0/  178| bits: 0.21
#   2020-07-19 00:09:01|    30/  178| bits: 0.24
#   2020-07-19 00:09:01|    60/  178| bits: 0.21
#   2020-07-19 00:09:01|    90/  178| bits: 0.25
#   2020-07-19 00:09:02|   120/  178| bits: 0.23
#   2020-07-19 00:09:02|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:09:06|     0/  178| bits: 0.24
#   2020-07-19 00:09:06|    30/  178| bits: 0.30
#   2020-07-19 00:09:07|    60/  178| bits: 0.21
#   2020-07-19 00:09:07|    90/  178| bits: 0.23
#   2020-07-19 00:09:07|   120/  178| bits: 0.23
#   2020-07-19 00:09:08|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:09:11|     0/  178| bits: 0.21
#   2020-07-19 00:09:12|    30/  178| bits: 0.24
#   2020-07-19 00:09:12|    60/  178| bits: 0.21
#   2020-07-19 00:09:12|    90/  178| bits: 0.22
#   2020-07-19 00:09:13|   120/  178| bits: 0.26
#   2020-07-19 00:09:13|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:09:17|     0/  178| bits: 0.22
#   2020-07-19 00:09:17|    30/  178| bits: 0.21
#   2020-07-19 00:09:18|    60/  178| bits: 0.23
#   2020-07-19 00:09:18|    90/  178| bits: 0.22
#   2020-07-19 00:09:18|   120/  178| bits: 0.27
#   2020-07-19 00:09:19|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:09:22|     0/  178| bits: 0.21
#   2020-07-19 00:09:23|    30/  178| bits: 0.21
#   2020-07-19 00:09:23|    60/  178| bits: 0.22
#   2020-07-19 00:09:23|    90/  178| bits: 0.23
#   2020-07-19 00:09:24|   120/  178| bits: 0.21
#   2020-07-19 00:09:24|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:09:28|     0/  178| bits: 0.21
#   2020-07-19 00:09:28|    30/  178| bits: 0.23
#   2020-07-19 00:09:29|    60/  178| bits: 0.21
#   2020-07-19 00:09:29|    90/  178| bits: 0.21
#   2020-07-19 00:09:29|   120/  178| bits: 0.24
#   2020-07-19 00:09:30|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:09:33|     0/  178| bits: 0.21
#   2020-07-19 00:09:34|    30/  178| bits: 0.22
#   2020-07-19 00:09:34|    60/  178| bits: 0.23
#   2020-07-19 00:09:34|    90/  178| bits: 0.24
#   2020-07-19 00:09:35|   120/  178| bits: 0.24
#   2020-07-19 00:09:35|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 3
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:09:40|     0/  178| bits: 4.13
#   2020-07-19 00:09:40|    30/  178| bits: 0.35
#   2020-07-19 00:09:40|    60/  178| bits: 0.31
#   2020-07-19 00:09:41|    90/  178| bits: 0.24
#   2020-07-19 00:09:41|   120/  178| bits: 0.24
#   2020-07-19 00:09:41|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:09:45|     0/  178| bits: 0.23
#   2020-07-19 00:09:46|    30/  178| bits: 0.26
#   2020-07-19 00:09:46|    60/  178| bits: 0.22
#   2020-07-19 00:09:46|    90/  178| bits: 0.23
#   2020-07-19 00:09:47|   120/  178| bits: 0.25
#   2020-07-19 00:09:47|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:09:51|     0/  178| bits: 0.21
#   2020-07-19 00:09:51|    30/  178| bits: 0.22
#   2020-07-19 00:09:52|    60/  178| bits: 0.21
#   2020-07-19 00:09:52|    90/  178| bits: 0.28
#   2020-07-19 00:09:52|   120/  178| bits: 0.23
#   2020-07-19 00:09:52|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:09:56|     0/  178| bits: 0.24
#   2020-07-19 00:09:57|    30/  178| bits: 0.26
#   2020-07-19 00:09:57|    60/  178| bits: 0.26
#   2020-07-19 00:09:57|    90/  178| bits: 0.24
#   2020-07-19 00:09:58|   120/  178| bits: 0.21
#   2020-07-19 00:09:58|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:10:02|     0/  178| bits: 0.24
#   2020-07-19 00:10:02|    30/  178| bits: 0.28
#   2020-07-19 00:10:02|    60/  178| bits: 0.27
#   2020-07-19 00:10:03|    90/  178| bits: 0.23
#   2020-07-19 00:10:03|   120/  178| bits: 0.24
#   2020-07-19 00:10:03|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:10:07|     0/  178| bits: 0.27
#   2020-07-19 00:10:08|    30/  178| bits: 0.22
#   2020-07-19 00:10:08|    60/  178| bits: 0.21
#   2020-07-19 00:10:08|    90/  178| bits: 0.21
#   2020-07-19 00:10:09|   120/  178| bits: 0.28
#   2020-07-19 00:10:09|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:10:13|     0/  178| bits: 0.24
#   2020-07-19 00:10:13|    30/  178| bits: 0.23
#   2020-07-19 00:10:13|    60/  178| bits: 0.27
#   2020-07-19 00:10:14|    90/  178| bits: 0.24
#   2020-07-19 00:10:14|   120/  178| bits: 0.24
#   2020-07-19 00:10:14|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:10:18|     0/  178| bits: 0.26
#   2020-07-19 00:10:19|    30/  178| bits: 0.21
#   2020-07-19 00:10:19|    60/  178| bits: 0.23
#   2020-07-19 00:10:19|    90/  178| bits: 0.26
#   2020-07-19 00:10:20|   120/  178| bits: 0.21
#   2020-07-19 00:10:20|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:10:24|     0/  178| bits: 0.21
#   2020-07-19 00:10:24|    30/  178| bits: 0.24
#   2020-07-19 00:10:24|    60/  178| bits: 0.23
#   2020-07-19 00:10:25|    90/  178| bits: 0.24
#   2020-07-19 00:10:25|   120/  178| bits: 0.22
#   2020-07-19 00:10:25|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:10:29|     0/  178| bits: 0.22
#   2020-07-19 00:10:30|    30/  178| bits: 0.25
#   2020-07-19 00:10:30|    60/  178| bits: 0.24
#   2020-07-19 00:10:30|    90/  178| bits: 0.22
#   2020-07-19 00:10:31|   120/  178| bits: 0.21
#   2020-07-19 00:10:31|   150/  178| bits: 0.29
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:10:35|     0/  178| bits: 0.25
#   2020-07-19 00:10:35|    30/  178| bits: 0.25
#   2020-07-19 00:10:35|    60/  178| bits: 0.21
#   2020-07-19 00:10:36|    90/  178| bits: 0.23
#   2020-07-19 00:10:36|   120/  178| bits: 0.28
#   2020-07-19 00:10:36|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:10:40|     0/  178| bits: 0.25
#   2020-07-19 00:10:41|    30/  178| bits: 0.21
#   2020-07-19 00:10:41|    60/  178| bits: 0.26
#   2020-07-19 00:10:41|    90/  178| bits: 0.23
#   2020-07-19 00:10:42|   120/  178| bits: 0.26
#   2020-07-19 00:10:42|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:10:46|     0/  178| bits: 0.23
#   2020-07-19 00:10:46|    30/  178| bits: 0.23
#   2020-07-19 00:10:46|    60/  178| bits: 0.23
#   2020-07-19 00:10:47|    90/  178| bits: 0.21
#   2020-07-19 00:10:47|   120/  178| bits: 0.23
#   2020-07-19 00:10:47|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:10:51|     0/  178| bits: 0.23
#   2020-07-19 00:10:52|    30/  178| bits: 0.21
#   2020-07-19 00:10:52|    60/  178| bits: 0.22
#   2020-07-19 00:10:52|    90/  178| bits: 0.24
#   2020-07-19 00:10:53|   120/  178| bits: 0.23
#   2020-07-19 00:10:53|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:10:57|     0/  178| bits: 0.25
#   2020-07-19 00:10:57|    30/  178| bits: 0.22
#   2020-07-19 00:10:57|    60/  178| bits: 0.23
#   2020-07-19 00:10:58|    90/  178| bits: 0.21
#   2020-07-19 00:10:58|   120/  178| bits: 0.23
#   2020-07-19 00:10:58|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:11:02|     0/  178| bits: 0.22
#   2020-07-19 00:11:03|    30/  178| bits: 0.24
#   2020-07-19 00:11:03|    60/  178| bits: 0.21
#   2020-07-19 00:11:03|    90/  178| bits: 0.25
#   2020-07-19 00:11:03|   120/  178| bits: 0.21
#   2020-07-19 00:11:04|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:11:08|     0/  178| bits: 0.23
#   2020-07-19 00:11:08|    30/  178| bits: 0.23
#   2020-07-19 00:11:08|    60/  178| bits: 0.29
#   2020-07-19 00:11:09|    90/  178| bits: 0.26
#   2020-07-19 00:11:09|   120/  178| bits: 0.22
#   2020-07-19 00:11:09|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:11:13|     0/  178| bits: 0.23
#   2020-07-19 00:11:13|    30/  178| bits: 0.23
#   2020-07-19 00:11:14|    60/  178| bits: 0.21
#   2020-07-19 00:11:14|    90/  178| bits: 0.21
#   2020-07-19 00:11:14|   120/  178| bits: 0.24
#   2020-07-19 00:11:15|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:11:19|     0/  178| bits: 0.21
#   2020-07-19 00:11:19|    30/  178| bits: 0.23
#   2020-07-19 00:11:19|    60/  178| bits: 0.25
#   2020-07-19 00:11:20|    90/  178| bits: 0.26
#   2020-07-19 00:11:20|   120/  178| bits: 0.24
#   2020-07-19 00:11:20|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:11:24|     0/  178| bits: 0.23
#   2020-07-19 00:11:24|    30/  178| bits: 0.21
#   2020-07-19 00:11:25|    60/  178| bits: 0.22
#   2020-07-19 00:11:25|    90/  178| bits: 0.24
#   2020-07-19 00:11:25|   120/  178| bits: 0.24
#   2020-07-19 00:11:26|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 4
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:11:30|     0/  178| bits: 3.73
#   2020-07-19 00:11:31|    30/  178| bits: 0.38
#   2020-07-19 00:11:31|    60/  178| bits: 0.27
#   2020-07-19 00:11:31|    90/  178| bits: 0.32
#   2020-07-19 00:11:32|   120/  178| bits: 0.24
#   2020-07-19 00:11:32|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:11:36|     0/  178| bits: 0.25
#   2020-07-19 00:11:36|    30/  178| bits: 0.22
#   2020-07-19 00:11:37|    60/  178| bits: 0.24
#   2020-07-19 00:11:37|    90/  178| bits: 0.24
#   2020-07-19 00:11:37|   120/  178| bits: 0.25
#   2020-07-19 00:11:38|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:11:41|     0/  178| bits: 0.24
#   2020-07-19 00:11:42|    30/  178| bits: 0.22
#   2020-07-19 00:11:42|    60/  178| bits: 0.25
#   2020-07-19 00:11:42|    90/  178| bits: 0.31
#   2020-07-19 00:11:43|   120/  178| bits: 0.29
#   2020-07-19 00:11:43|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:11:47|     0/  178| bits: 0.27
#   2020-07-19 00:11:47|    30/  178| bits: 0.24
#   2020-07-19 00:11:48|    60/  178| bits: 0.22
#   2020-07-19 00:11:48|    90/  178| bits: 0.24
#   2020-07-19 00:11:48|   120/  178| bits: 0.24
#   2020-07-19 00:11:49|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:11:52|     0/  178| bits: 0.24
#   2020-07-19 00:11:53|    30/  178| bits: 0.25
#   2020-07-19 00:11:53|    60/  178| bits: 0.29
#   2020-07-19 00:11:53|    90/  178| bits: 0.25
#   2020-07-19 00:11:54|   120/  178| bits: 0.21
#   2020-07-19 00:11:54|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:11:58|     0/  178| bits: 0.23
#   2020-07-19 00:11:58|    30/  178| bits: 0.22
#   2020-07-19 00:11:59|    60/  178| bits: 0.23
#   2020-07-19 00:11:59|    90/  178| bits: 0.23
#   2020-07-19 00:11:59|   120/  178| bits: 0.24
#   2020-07-19 00:12:00|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:12:03|     0/  178| bits: 0.23
#   2020-07-19 00:12:04|    30/  178| bits: 0.26
#   2020-07-19 00:12:04|    60/  178| bits: 0.29
#   2020-07-19 00:12:04|    90/  178| bits: 0.23
#   2020-07-19 00:12:05|   120/  178| bits: 0.23
#   2020-07-19 00:12:05|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:12:09|     0/  178| bits: 0.22
#   2020-07-19 00:12:09|    30/  178| bits: 0.25
#   2020-07-19 00:12:09|    60/  178| bits: 0.23
#   2020-07-19 00:12:10|    90/  178| bits: 0.22
#   2020-07-19 00:12:10|   120/  178| bits: 0.21
#   2020-07-19 00:12:10|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:12:14|     0/  178| bits: 0.24
#   2020-07-19 00:12:15|    30/  178| bits: 0.23
#   2020-07-19 00:12:15|    60/  178| bits: 0.28
#   2020-07-19 00:12:15|    90/  178| bits: 0.22
#   2020-07-19 00:12:16|   120/  178| bits: 0.23
#   2020-07-19 00:12:16|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:12:20|     0/  178| bits: 0.25
#   2020-07-19 00:12:20|    30/  178| bits: 0.23
#   2020-07-19 00:12:20|    60/  178| bits: 0.25
#   2020-07-19 00:12:21|    90/  178| bits: 0.29
#   2020-07-19 00:12:21|   120/  178| bits: 0.21
#   2020-07-19 00:12:21|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:12:25|     0/  178| bits: 0.26
#   2020-07-19 00:12:26|    30/  178| bits: 0.24
#   2020-07-19 00:12:26|    60/  178| bits: 0.22
#   2020-07-19 00:12:26|    90/  178| bits: 0.21
#   2020-07-19 00:12:27|   120/  178| bits: 0.24
#   2020-07-19 00:12:27|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.23
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:12:31|     0/  178| bits: 0.23
#   2020-07-19 00:12:31|    30/  178| bits: 0.24
#   2020-07-19 00:12:31|    60/  178| bits: 0.24
#   2020-07-19 00:12:32|    90/  178| bits: 0.22
#   2020-07-19 00:12:32|   120/  178| bits: 0.22
#   2020-07-19 00:12:32|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:12:36|     0/  178| bits: 0.21
#   2020-07-19 00:12:37|    30/  178| bits: 0.27
#   2020-07-19 00:12:37|    60/  178| bits: 0.23
#   2020-07-19 00:12:37|    90/  178| bits: 0.21
#   2020-07-19 00:12:38|   120/  178| bits: 0.22
#   2020-07-19 00:12:38|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:12:42|     0/  178| bits: 0.23
#   2020-07-19 00:12:42|    30/  178| bits: 0.21
#   2020-07-19 00:12:42|    60/  178| bits: 0.21
#   2020-07-19 00:12:43|    90/  178| bits: 0.25
#   2020-07-19 00:12:43|   120/  178| bits: 0.24
#   2020-07-19 00:12:43|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:12:47|     0/  178| bits: 0.23
#   2020-07-19 00:12:48|    30/  178| bits: 0.22
#   2020-07-19 00:12:48|    60/  178| bits: 0.26
#   2020-07-19 00:12:48|    90/  178| bits: 0.23
#   2020-07-19 00:12:49|   120/  178| bits: 0.21
#   2020-07-19 00:12:49|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:12:53|     0/  178| bits: 0.21
#   2020-07-19 00:12:53|    30/  178| bits: 0.26
#   2020-07-19 00:12:53|    60/  178| bits: 0.21
#   2020-07-19 00:12:54|    90/  178| bits: 0.21
#   2020-07-19 00:12:54|   120/  178| bits: 0.21
#   2020-07-19 00:12:54|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:12:58|     0/  178| bits: 0.21
#   2020-07-19 00:12:59|    30/  178| bits: 0.24
#   2020-07-19 00:12:59|    60/  178| bits: 0.23
#   2020-07-19 00:12:59|    90/  178| bits: 0.23
#   2020-07-19 00:13:00|   120/  178| bits: 0.21
#   2020-07-19 00:13:00|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:13:04|     0/  178| bits: 0.22
#   2020-07-19 00:13:04|    30/  178| bits: 0.22
#   2020-07-19 00:13:04|    60/  178| bits: 0.21
#   2020-07-19 00:13:05|    90/  178| bits: 0.21
#   2020-07-19 00:13:05|   120/  178| bits: 0.21
#   2020-07-19 00:13:05|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.23
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:13:09|     0/  178| bits: 0.21
#   2020-07-19 00:13:10|    30/  178| bits: 0.22
#   2020-07-19 00:13:10|    60/  178| bits: 0.28
#   2020-07-19 00:13:10|    90/  178| bits: 0.21
#   2020-07-19 00:13:11|   120/  178| bits: 0.21
#   2020-07-19 00:13:11|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:13:15|     0/  178| bits: 0.25
#   2020-07-19 00:13:15|    30/  178| bits: 0.25
#   2020-07-19 00:13:15|    60/  178| bits: 0.26
#   2020-07-19 00:13:16|    90/  178| bits: 0.23
#   2020-07-19 00:13:16|   120/  178| bits: 0.28
#   2020-07-19 00:13:16|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 5
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:13:21|     0/  178| bits: 3.71
#   2020-07-19 00:13:21|    30/  178| bits: 0.32
#   2020-07-19 00:13:22|    60/  178| bits: 0.29
#   2020-07-19 00:13:22|    90/  178| bits: 0.30
#   2020-07-19 00:13:22|   120/  178| bits: 0.27
#   2020-07-19 00:13:23|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:13:27|     0/  178| bits: 0.22
#   2020-07-19 00:13:27|    30/  178| bits: 0.26
#   2020-07-19 00:13:27|    60/  178| bits: 0.21
#   2020-07-19 00:13:28|    90/  178| bits: 0.23
#   2020-07-19 00:13:28|   120/  178| bits: 0.22
#   2020-07-19 00:13:28|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:13:32|     0/  178| bits: 0.21
#   2020-07-19 00:13:32|    30/  178| bits: 0.21
#   2020-07-19 00:13:33|    60/  178| bits: 0.21
#   2020-07-19 00:13:33|    90/  178| bits: 0.21
#   2020-07-19 00:13:33|   120/  178| bits: 0.24
#   2020-07-19 00:13:34|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:13:37|     0/  178| bits: 0.24
#   2020-07-19 00:13:38|    30/  178| bits: 0.25
#   2020-07-19 00:13:38|    60/  178| bits: 0.23
#   2020-07-19 00:13:38|    90/  178| bits: 0.22
#   2020-07-19 00:13:39|   120/  178| bits: 0.22
#   2020-07-19 00:13:39|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:13:43|     0/  178| bits: 0.23
#   2020-07-19 00:13:43|    30/  178| bits: 0.25
#   2020-07-19 00:13:44|    60/  178| bits: 0.27
#   2020-07-19 00:13:44|    90/  178| bits: 0.23
#   2020-07-19 00:13:44|   120/  178| bits: 0.27
#   2020-07-19 00:13:45|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:13:48|     0/  178| bits: 0.21
#   2020-07-19 00:13:49|    30/  178| bits: 0.21
#   2020-07-19 00:13:49|    60/  178| bits: 0.25
#   2020-07-19 00:13:49|    90/  178| bits: 0.21
#   2020-07-19 00:13:50|   120/  178| bits: 0.22
#   2020-07-19 00:13:50|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:13:54|     0/  178| bits: 0.25
#   2020-07-19 00:13:54|    30/  178| bits: 0.23
#   2020-07-19 00:13:55|    60/  178| bits: 0.23
#   2020-07-19 00:13:55|    90/  178| bits: 0.21
#   2020-07-19 00:13:55|   120/  178| bits: 0.21
#   2020-07-19 00:13:56|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:13:59|     0/  178| bits: 0.24
#   2020-07-19 00:14:00|    30/  178| bits: 0.21
#   2020-07-19 00:14:00|    60/  178| bits: 0.22
#   2020-07-19 00:14:00|    90/  178| bits: 0.21
#   2020-07-19 00:14:01|   120/  178| bits: 0.21
#   2020-07-19 00:14:01|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:14:05|     0/  178| bits: 0.23
#   2020-07-19 00:14:05|    30/  178| bits: 0.25
#   2020-07-19 00:14:06|    60/  178| bits: 0.24
#   2020-07-19 00:14:06|    90/  178| bits: 0.21
#   2020-07-19 00:14:06|   120/  178| bits: 0.24
#   2020-07-19 00:14:07|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:14:10|     0/  178| bits: 0.24
#   2020-07-19 00:14:11|    30/  178| bits: 0.27
#   2020-07-19 00:14:11|    60/  178| bits: 0.23
#   2020-07-19 00:14:11|    90/  178| bits: 0.24
#   2020-07-19 00:14:12|   120/  178| bits: 0.23
#   2020-07-19 00:14:12|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:14:16|     0/  178| bits: 0.21
#   2020-07-19 00:14:16|    30/  178| bits: 0.21
#   2020-07-19 00:14:17|    60/  178| bits: 0.23
#   2020-07-19 00:14:17|    90/  178| bits: 0.23
#   2020-07-19 00:14:17|   120/  178| bits: 0.24
#   2020-07-19 00:14:18|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:14:21|     0/  178| bits: 0.21
#   2020-07-19 00:14:22|    30/  178| bits: 0.22
#   2020-07-19 00:14:22|    60/  178| bits: 0.21
#   2020-07-19 00:14:22|    90/  178| bits: 0.25
#   2020-07-19 00:14:23|   120/  178| bits: 0.22
#   2020-07-19 00:14:23|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:14:27|     0/  178| bits: 0.26
#   2020-07-19 00:14:27|    30/  178| bits: 0.21
#   2020-07-19 00:14:28|    60/  178| bits: 0.24
#   2020-07-19 00:14:28|    90/  178| bits: 0.21
#   2020-07-19 00:14:28|   120/  178| bits: 0.21
#   2020-07-19 00:14:29|   150/  178| bits: 0.29
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:14:32|     0/  178| bits: 0.28
#   2020-07-19 00:14:33|    30/  178| bits: 0.23
#   2020-07-19 00:14:33|    60/  178| bits: 0.21
#   2020-07-19 00:14:33|    90/  178| bits: 0.23
#   2020-07-19 00:14:34|   120/  178| bits: 0.24
#   2020-07-19 00:14:34|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:14:38|     0/  178| bits: 0.21
#   2020-07-19 00:14:38|    30/  178| bits: 0.21
#   2020-07-19 00:14:39|    60/  178| bits: 0.24
#   2020-07-19 00:14:39|    90/  178| bits: 0.23
#   2020-07-19 00:14:39|   120/  178| bits: 0.21
#   2020-07-19 00:14:40|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:14:43|     0/  178| bits: 0.21
#   2020-07-19 00:14:44|    30/  178| bits: 0.25
#   2020-07-19 00:14:44|    60/  178| bits: 0.22
#   2020-07-19 00:14:44|    90/  178| bits: 0.21
#   2020-07-19 00:14:45|   120/  178| bits: 0.21
#   2020-07-19 00:14:45|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:14:49|     0/  178| bits: 0.23
#   2020-07-19 00:14:49|    30/  178| bits: 0.24
#   2020-07-19 00:14:50|    60/  178| bits: 0.21
#   2020-07-19 00:14:50|    90/  178| bits: 0.22
#   2020-07-19 00:14:50|   120/  178| bits: 0.26
#   2020-07-19 00:14:51|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:14:54|     0/  178| bits: 0.21
#   2020-07-19 00:14:55|    30/  178| bits: 0.24
#   2020-07-19 00:14:55|    60/  178| bits: 0.21
#   2020-07-19 00:14:55|    90/  178| bits: 0.25
#   2020-07-19 00:14:56|   120/  178| bits: 0.21
#   2020-07-19 00:14:56|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:15:00|     0/  178| bits: 0.21
#   2020-07-19 00:15:00|    30/  178| bits: 0.23
#   2020-07-19 00:15:01|    60/  178| bits: 0.24
#   2020-07-19 00:15:01|    90/  178| bits: 0.21
#   2020-07-19 00:15:01|   120/  178| bits: 0.24
#   2020-07-19 00:15:02|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:15:05|     0/  178| bits: 0.23
#   2020-07-19 00:15:06|    30/  178| bits: 0.23
#   2020-07-19 00:15:06|    60/  178| bits: 0.23
#   2020-07-19 00:15:06|    90/  178| bits: 0.21
#   2020-07-19 00:15:07|   120/  178| bits: 0.21
#   2020-07-19 00:15:07|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 6
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:15:12|     0/  178| bits: 3.65
#   2020-07-19 00:15:12|    30/  178| bits: 0.30
#   2020-07-19 00:15:12|    60/  178| bits: 0.27
#   2020-07-19 00:15:13|    90/  178| bits: 0.22
#   2020-07-19 00:15:13|   120/  178| bits: 0.24
#   2020-07-19 00:15:13|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:15:17|     0/  178| bits: 0.22
#   2020-07-19 00:15:18|    30/  178| bits: 0.21
#   2020-07-19 00:15:18|    60/  178| bits: 0.26
#   2020-07-19 00:15:18|    90/  178| bits: 0.22
#   2020-07-19 00:15:19|   120/  178| bits: 0.23
#   2020-07-19 00:15:19|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# ...
#   2020-07-19 00:18:54|    60/  178| bits: 0.31
#   2020-07-19 00:18:54|    90/  178| bits: 0.30
#   2020-07-19 00:18:54|   120/  178| bits: 0.24
#   2020-07-19 00:18:55|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.23
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:18:58|     0/  178| bits: 0.23
#   2020-07-19 00:18:59|    30/  178| bits: 0.25
#   2020-07-19 00:18:59|    60/  178| bits: 0.22
#   2020-07-19 00:18:59|    90/  178| bits: 0.25
#   2020-07-19 00:19:00|   120/  178| bits: 0.21
#   2020-07-19 00:19:00|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:19:04|     0/  178| bits: 0.25
#   2020-07-19 00:19:04|    30/  178| bits: 0.25
#   2020-07-19 00:19:05|    60/  178| bits: 0.21
#   2020-07-19 00:19:05|    90/  178| bits: 0.24
#   2020-07-19 00:19:05|   120/  178| bits: 0.21
#   2020-07-19 00:19:06|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:19:09|     0/  178| bits: 0.26
#   2020-07-19 00:19:10|    30/  178| bits: 0.25
#   2020-07-19 00:19:10|    60/  178| bits: 0.25
#   2020-07-19 00:19:10|    90/  178| bits: 0.26
#   2020-07-19 00:19:11|   120/  178| bits: 0.25
#   2020-07-19 00:19:11|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:19:15|     0/  178| bits: 0.24
#   2020-07-19 00:19:15|    30/  178| bits: 0.24
#   2020-07-19 00:19:16|    60/  178| bits: 0.22
#   2020-07-19 00:19:16|    90/  178| bits: 0.23
#   2020-07-19 00:19:16|   120/  178| bits: 0.25
#   2020-07-19 00:19:17|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:19:20|     0/  178| bits: 0.24
#   2020-07-19 00:19:21|    30/  178| bits: 0.21
#   2020-07-19 00:19:21|    60/  178| bits: 0.30
#   2020-07-19 00:19:21|    90/  178| bits: 0.24
#   2020-07-19 00:19:22|   120/  178| bits: 0.21
#   2020-07-19 00:19:22|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:19:26|     0/  178| bits: 0.21
#   2020-07-19 00:19:26|    30/  178| bits: 0.23
#   2020-07-19 00:19:26|    60/  178| bits: 0.25
#   2020-07-19 00:19:27|    90/  178| bits: 0.21
#   2020-07-19 00:19:27|   120/  178| bits: 0.22
#   2020-07-19 00:19:27|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:19:31|     0/  178| bits: 0.22
#   2020-07-19 00:19:32|    30/  178| bits: 0.24
#   2020-07-19 00:19:32|    60/  178| bits: 0.25
#   2020-07-19 00:19:32|    90/  178| bits: 0.23
#   2020-07-19 00:19:33|   120/  178| bits: 0.22
#   2020-07-19 00:19:33|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:19:37|     0/  178| bits: 0.25
#   2020-07-19 00:19:37|    30/  178| bits: 0.24
#   2020-07-19 00:19:37|    60/  178| bits: 0.30
#   2020-07-19 00:19:38|    90/  178| bits: 0.22
#   2020-07-19 00:19:38|   120/  178| bits: 0.29
#   2020-07-19 00:19:38|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:19:42|     0/  178| bits: 0.22
#   2020-07-19 00:19:43|    30/  178| bits: 0.24
#   2020-07-19 00:19:43|    60/  178| bits: 0.24
#   2020-07-19 00:19:43|    90/  178| bits: 0.23
#   2020-07-19 00:19:44|   120/  178| bits: 0.30
#   2020-07-19 00:19:44|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:19:48|     0/  178| bits: 0.21
#   2020-07-19 00:19:48|    30/  178| bits: 0.25
#   2020-07-19 00:19:48|    60/  178| bits: 0.22
#   2020-07-19 00:19:49|    90/  178| bits: 0.24
#   2020-07-19 00:19:49|   120/  178| bits: 0.24
#   2020-07-19 00:19:49|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:19:53|     0/  178| bits: 0.22
#   2020-07-19 00:19:54|    30/  178| bits: 0.23
#   2020-07-19 00:19:54|    60/  178| bits: 0.25
#   2020-07-19 00:19:54|    90/  178| bits: 0.21
#   2020-07-19 00:19:55|   120/  178| bits: 0.21
#   2020-07-19 00:19:55|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:19:59|     0/  178| bits: 0.24
#   2020-07-19 00:19:59|    30/  178| bits: 0.22
#   2020-07-19 00:19:59|    60/  178| bits: 0.23
#   2020-07-19 00:20:00|    90/  178| bits: 0.24
#   2020-07-19 00:20:00|   120/  178| bits: 0.22
#   2020-07-19 00:20:00|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:20:04|     0/  178| bits: 0.22
#   2020-07-19 00:20:05|    30/  178| bits: 0.25
#   2020-07-19 00:20:05|    60/  178| bits: 0.24
#   2020-07-19 00:20:05|    90/  178| bits: 0.24
#   2020-07-19 00:20:06|   120/  178| bits: 0.22
#   2020-07-19 00:20:06|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:20:10|     0/  178| bits: 0.21
#   2020-07-19 00:20:10|    30/  178| bits: 0.21
#   2020-07-19 00:20:10|    60/  178| bits: 0.22
#   2020-07-19 00:20:11|    90/  178| bits: 0.26
#   2020-07-19 00:20:11|   120/  178| bits: 0.25
#   2020-07-19 00:20:11|   150/  178| bits: 0.30
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:20:15|     0/  178| bits: 0.21
#   2020-07-19 00:20:16|    30/  178| bits: 0.23
#   2020-07-19 00:20:16|    60/  178| bits: 0.24
#   2020-07-19 00:20:16|    90/  178| bits: 0.22
#   2020-07-19 00:20:16|   120/  178| bits: 0.21
#   2020-07-19 00:20:17|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:20:21|     0/  178| bits: 0.27
#   2020-07-19 00:20:21|    30/  178| bits: 0.21
#   2020-07-19 00:20:21|    60/  178| bits: 0.23
#   2020-07-19 00:20:22|    90/  178| bits: 0.21
#   2020-07-19 00:20:22|   120/  178| bits: 0.21
#   2020-07-19 00:20:22|   150/  178| bits: 0.27
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:20:26|     0/  178| bits: 0.24
#   2020-07-19 00:20:26|    30/  178| bits: 0.21
#   2020-07-19 00:20:27|    60/  178| bits: 0.21
#   2020-07-19 00:20:27|    90/  178| bits: 0.22
#   2020-07-19 00:20:27|   120/  178| bits: 0.22
#   2020-07-19 00:20:28|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:20:32|     0/  178| bits: 0.21
#   2020-07-19 00:20:32|    30/  178| bits: 0.24
#   2020-07-19 00:20:32|    60/  178| bits: 0.22
#   2020-07-19 00:20:33|    90/  178| bits: 0.21
#   2020-07-19 00:20:33|   120/  178| bits: 0.21
#   2020-07-19 00:20:33|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:20:37|     0/  178| bits: 0.22
#   2020-07-19 00:20:37|    30/  178| bits: 0.21
#   2020-07-19 00:20:38|    60/  178| bits: 0.21
#   2020-07-19 00:20:38|    90/  178| bits: 0.23
#   2020-07-19 00:20:38|   120/  178| bits: 0.21
#   2020-07-19 00:20:39|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# 9
# --------------------------------------------------
# Epoch   1/ 20
#   2020-07-19 00:20:43|     0/  178| bits: 3.86
#   2020-07-19 00:20:44|    30/  178| bits: 0.33
#   2020-07-19 00:20:44|    60/  178| bits: 0.30
#   2020-07-19 00:20:44|    90/  178| bits: 0.27
#   2020-07-19 00:20:45|   120/  178| bits: 0.24
#   2020-07-19 00:20:45|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   2/ 20
#   2020-07-19 00:20:49|     0/  178| bits: 0.24
#   2020-07-19 00:20:49|    30/  178| bits: 0.27
#   2020-07-19 00:20:50|    60/  178| bits: 0.21
#   2020-07-19 00:20:50|    90/  178| bits: 0.23
#   2020-07-19 00:20:50|   120/  178| bits: 0.23
#   2020-07-19 00:20:51|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   3/ 20
#   2020-07-19 00:20:54|     0/  178| bits: 0.24
#   2020-07-19 00:20:55|    30/  178| bits: 0.21
#   2020-07-19 00:20:55|    60/  178| bits: 0.30
#   2020-07-19 00:20:55|    90/  178| bits: 0.24
#   2020-07-19 00:20:56|   120/  178| bits: 0.22
#   2020-07-19 00:20:56|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   4/ 20
#   2020-07-19 00:21:00|     0/  178| bits: 0.25
#   2020-07-19 00:21:00|    30/  178| bits: 0.21
#   2020-07-19 00:21:01|    60/  178| bits: 0.21
#   2020-07-19 00:21:01|    90/  178| bits: 0.25
#   2020-07-19 00:21:01|   120/  178| bits: 0.27
#   2020-07-19 00:21:02|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   5/ 20
#   2020-07-19 00:21:05|     0/  178| bits: 0.25
#   2020-07-19 00:21:06|    30/  178| bits: 0.25
#   2020-07-19 00:21:06|    60/  178| bits: 0.22
#   2020-07-19 00:21:06|    90/  178| bits: 0.24
#   2020-07-19 00:21:07|   120/  178| bits: 0.29
#   2020-07-19 00:21:07|   150/  178| bits: 0.26
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   6/ 20
#   2020-07-19 00:21:11|     0/  178| bits: 0.21
#   2020-07-19 00:21:11|    30/  178| bits: 0.23
#   2020-07-19 00:21:12|    60/  178| bits: 0.21
#   2020-07-19 00:21:12|    90/  178| bits: 0.28
#   2020-07-19 00:21:12|   120/  178| bits: 0.24
#   2020-07-19 00:21:13|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   7/ 20
#   2020-07-19 00:21:16|     0/  178| bits: 0.24
#   2020-07-19 00:21:17|    30/  178| bits: 0.21
#   2020-07-19 00:21:17|    60/  178| bits: 0.21
#   2020-07-19 00:21:17|    90/  178| bits: 0.24
#   2020-07-19 00:21:18|   120/  178| bits: 0.21
#   2020-07-19 00:21:18|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.23
# --------------------------------------------------
# Epoch   8/ 20
#   2020-07-19 00:21:22|     0/  178| bits: 0.24
#   2020-07-19 00:21:22|    30/  178| bits: 0.21
#   2020-07-19 00:21:23|    60/  178| bits: 0.25
#   2020-07-19 00:21:23|    90/  178| bits: 0.22
#   2020-07-19 00:21:23|   120/  178| bits: 0.25
#   2020-07-19 00:21:24|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch   9/ 20
#   2020-07-19 00:21:27|     0/  178| bits: 0.21
#   2020-07-19 00:21:28|    30/  178| bits: 0.23
#   2020-07-19 00:21:28|    60/  178| bits: 0.22
#   2020-07-19 00:21:28|    90/  178| bits: 0.22
#   2020-07-19 00:21:29|   120/  178| bits: 0.21
#   2020-07-19 00:21:29|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  10/ 20
#   2020-07-19 00:21:33|     0/  178| bits: 0.27
#   2020-07-19 00:21:33|    30/  178| bits: 0.25
#   2020-07-19 00:21:34|    60/  178| bits: 0.24
#   2020-07-19 00:21:34|    90/  178| bits: 0.23
#   2020-07-19 00:21:34|   120/  178| bits: 0.29
#   2020-07-19 00:21:35|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  11/ 20
#   2020-07-19 00:21:38|     0/  178| bits: 0.24
#   2020-07-19 00:21:39|    30/  178| bits: 0.22
#   2020-07-19 00:21:39|    60/  178| bits: 0.21
#   2020-07-19 00:21:39|    90/  178| bits: 0.21
#   2020-07-19 00:21:40|   120/  178| bits: 0.23
#   2020-07-19 00:21:40|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.22
# --------------------------------------------------
# Epoch  12/ 20
#   2020-07-19 00:21:44|     0/  178| bits: 0.22
#   2020-07-19 00:21:44|    30/  178| bits: 0.22
#   2020-07-19 00:21:45|    60/  178| bits: 0.24
#   2020-07-19 00:21:45|    90/  178| bits: 0.21
#   2020-07-19 00:21:45|   120/  178| bits: 0.21
#   2020-07-19 00:21:46|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  13/ 20
#   2020-07-19 00:21:49|     0/  178| bits: 0.23
#   2020-07-19 00:21:50|    30/  178| bits: 0.25
#   2020-07-19 00:21:50|    60/  178| bits: 0.27
#   2020-07-19 00:21:50|    90/  178| bits: 0.22
#   2020-07-19 00:21:51|   120/  178| bits: 0.23
#   2020-07-19 00:21:51|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  14/ 20
#   2020-07-19 00:21:55|     0/  178| bits: 0.21
#   2020-07-19 00:21:55|    30/  178| bits: 0.22
#   2020-07-19 00:21:55|    60/  178| bits: 0.25
#   2020-07-19 00:21:56|    90/  178| bits: 0.24
#   2020-07-19 00:21:56|   120/  178| bits: 0.22
#   2020-07-19 00:21:56|   150/  178| bits: 0.24
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  15/ 20
#   2020-07-19 00:22:00|     0/  178| bits: 0.22
#   2020-07-19 00:22:01|    30/  178| bits: 0.21
#   2020-07-19 00:22:01|    60/  178| bits: 0.24
#   2020-07-19 00:22:01|    90/  178| bits: 0.24
#   2020-07-19 00:22:02|   120/  178| bits: 0.23
#   2020-07-19 00:22:02|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  16/ 20
#   2020-07-19 00:22:06|     0/  178| bits: 0.25
#   2020-07-19 00:22:06|    30/  178| bits: 0.21
#   2020-07-19 00:22:06|    60/  178| bits: 0.21
#   2020-07-19 00:22:07|    90/  178| bits: 0.21
#   2020-07-19 00:22:07|   120/  178| bits: 0.23
#   2020-07-19 00:22:07|   150/  178| bits: 0.23
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  17/ 20
#   2020-07-19 00:22:11|     0/  178| bits: 0.23
#   2020-07-19 00:22:12|    30/  178| bits: 0.21
#   2020-07-19 00:22:12|    60/  178| bits: 0.27
#   2020-07-19 00:22:12|    90/  178| bits: 0.21
#   2020-07-19 00:22:13|   120/  178| bits: 0.23
#   2020-07-19 00:22:13|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  18/ 20
#   2020-07-19 00:22:17|     0/  178| bits: 0.22
#   2020-07-19 00:22:17|    30/  178| bits: 0.23
#   2020-07-19 00:22:17|    60/  178| bits: 0.22
#   2020-07-19 00:22:18|    90/  178| bits: 0.23
#   2020-07-19 00:22:18|   120/  178| bits: 0.21
#   2020-07-19 00:22:18|   150/  178| bits: 0.25
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  19/ 20
#   2020-07-19 00:22:22|     0/  178| bits: 0.21
#   2020-07-19 00:22:23|    30/  178| bits: 0.23
#   2020-07-19 00:22:23|    60/  178| bits: 0.22
#   2020-07-19 00:22:23|    90/  178| bits: 0.24
#   2020-07-19 00:22:24|   120/  178| bits: 0.24
#   2020-07-19 00:22:24|   150/  178| bits: 0.21
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# --------------------------------------------------
# Epoch  20/ 20
#   2020-07-19 00:22:28|     0/  178| bits: 0.23
#   2020-07-19 00:22:28|    30/  178| bits: 0.21
#   2020-07-19 00:22:28|    60/  178| bits: 0.21
#   2020-07-19 00:22:29|    90/  178| bits: 0.21
#   2020-07-19 00:22:29|   120/  178| bits: 0.21
#   2020-07-19 00:22:29|   150/  178| bits: 0.22
# Elapsed time: 0h 0m 3s
# Validation| bits: 0.21
# [39.385013223192736, 32.783734138527606, 31.265073957068566, 50.0308227315789, 49.480882478027056, 28.98373152810813, 34.71578512307254, 42.58867038168691, 58.5156932802965, 45.91101482440632]
# 41.36604216659653 9.134269352715828
# [39.385013223192736, 32.783734138527606, 31.265073957068566, 50.0308227315789, 49.480882478027056, 34.71578512307254, 42.58867038168691, 45.91101482440632]
# 40.77012460719508 6.928885860197499
